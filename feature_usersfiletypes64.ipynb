# %%
import os
import random
from collections import Counter
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cm = 1/2.54

# force GPU device
os.environ["CUDA_VISIBLE_DEVICES"]='1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

from keras.src.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.src.layers import SimpleRNN, LSTM, Dense, Dropout, Bidirectional
from keras import Sequential, Input
from keras.losses import CategoricalCrossentropy, CategoricalFocalCrossentropy
from keras.optimizers import Adam
from keras.models import load_model
from keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils import shuffle
from sklearn.utils.class_weight import compute_class_weight

# %%
max_sequence_length = 100
experiment_name = 'baseline4_userfiletypes_64'
top_k = 3

# %%
checkpoint_path = f'saves/rnn/{max_sequence_length}_{experiment_name}'
model_path = f'{checkpoint_path}/model.keras'
log_path = f'{checkpoint_path}/log.csv'
history_path = f'{checkpoint_path}/history.npy'

# ensure directory exists
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# %%
data_directory = '/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes/'
unusable_threshold = 10
rare_threshold = 50
splits = (0.7, 0.15, 0.15)

max_sequence_length = 100

assert(sum(splits) == 1)

print(f'experiment parameters: \n{data_directory=} \n{unusable_threshold=} \n{rare_threshold=} \n{splits=} \n{max_sequence_length=}')
# Out:
# experiment parameters:
# data_directory='/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes/'
# unusable_threshold=10
# rare_threshold=50
# splits=(0.7, 0.15, 0.15)
# max_sequence_length=100

# %%
def class_from_filename(filename):
    if filename.count('_') == 2:
        label, _, _ = filename.split('_')
    elif filename.count('_') == 3:
        # pwd_mkdb
        label, tmp, _, _ = filename.split('_')
        label += '_' + tmp
    else:
        print(f'Unknown file name format: {filename}')
        raise ValueError()
    return label

# %%
total_classes = 0

# unusable classes will be removed from the dataset
unusable_classes = []
# rare classes will be oversampled
rare_classes = []

# all classes in training data (all classes - unusable classes)
classes = []

# walk all files, build unusable_classes, rare_classes
classes_occurrences = Counter()
for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    classes_occurrences[label] += 1

total_classes = len(classes_occurrences)
for label, count in classes_occurrences.items():
    if count < unusable_threshold:
        unusable_classes.append(label)
    elif count < rare_threshold:
        rare_classes.append(label)
        classes.append(label)
    else:
        classes.append(label)

print(f'Total classes: {total_classes}')
print(f'Unusable classes: {len(unusable_classes)}')
print(f'\t{unusable_classes}')
print(f'Rare classes: {len(rare_classes)}')
print(f'\t{rare_classes}')

labels_cardinality = len(set(classes))
print(f'Usable classes: {labels_cardinality}')
# Out:
# Total classes: 118
# Unusable classes: 51
# 	['ping', 'pwd_mkdb', 'vi', 'tr', 'uname', 'msgs', 'screen', 'pw', 'bzip2', 'bzcat', 'nginx', 'stat', 'tail', 'smtp', 'kenv', 'nawk', 'ssh', 'chown', 'cut', 'php-fpm', 'jot', 'xz', 'diff', 'bounce', 'links', 'ipfw', 'touch', 'env', 'pfctl', 'minions', 'csh', 'kldstat', 'su', 'nohup', 'stty', 'df', 'limits', 'id', 'postmap', 'ifconfig', 'chkgrp', 'ipfstat', 'locale', 'devd', 'uniq', 'XIM', 'getty', 'which', 'init', 'test', 'nice']
# Rare classes: 20
# 	['wc', 'grep', 'mktemp', 'less', 'tty', 'mailwrapper', 'kill', 'lockf', 'mount', 'tee', 'expr', 'ps', 'route', 'sed', 'cmp', 'egrep', 'sort', 'basename', 'awk', 'mail']
# Usable classes: 67

# %%
# split into train, validation, test
labels_set = set()

filenames_all = []

filenames_train = []
filenames_val = []
filenames_test = []

for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    if label in unusable_classes:
        continue
    labels_set.add(label)
    filenames_all.append(filename)

# stratisfied split
test_vs_val = splits[2] / (splits[1] + splits[2])
filenames_train, filenames_val_test = train_test_split(filenames_all, test_size=splits[1]+splits[2], stratify=[class_from_filename(f) for f in filenames_all], random_state=42)
filenames_val, filenames_test = train_test_split(filenames_val_test, test_size=test_vs_val, stratify=[class_from_filename(f) for f in filenames_val_test], random_state=42)

print(f'Train: {len(filenames_train)}')
print(f'Validation: {len(filenames_val)}')
print(f'Test: {len(filenames_test)}')

# build labels_map in alphabetical order
labels_map = {}
for i, label in enumerate(sorted(labels_set)):
    labels_map[label] = i
# Out:
# Train: 150475
# Validation: 32245
# Test: 32245

# %%
# load data
# in preparation, load all data and build sets of unique features for later one-hot encoding, simultaneously vectorize labels and features
event_types_map = {}
users_map = {}
filetypes_map = {}

def parse_line(line):
    """
    Parse a line from the dataset and return the vectorized values. Not a pure function (builds distinct_* maps)!
    """
    event, user, filetype1, filetype2 = line.strip().split(',')
    # vectorize
    event = event_types_map.setdefault(event, len(event_types_map))
    user = users_map.setdefault(user, len(users_map))
    filetype1 = filetypes_map.setdefault(filetype1, len(filetypes_map))
    filetype2 = filetypes_map.setdefault(filetype2, len(filetypes_map))
    return event, user, filetype1, filetype2

count_files_read = 0
count_sequences_split = 0
count_splits = 0

def parse_file(filename) -> tuple[list[int], list[list[int]]]:
    """
    Parse a file and return the vectorized data. Not a pure function (calls parse_line)!
    """
    global count_files_read, count_sequences_split, count_splits

    y_list: list[int] = []
    X_list: list[list[int]] = []
    y = class_from_filename(filename)
    y = labels_map[y]
    with open(os.path.join(data_directory, filename), 'r') as f:
        lines = f.readlines()
        count_files_read += 1
    if count_files_read % 50000 == 0:
        print(f'Files read: {count_files_read}')
    X = []
    for line in lines:
        event, user, ft1, ft2 = parse_line(line)
        X.append((event, user, ft1, ft2))

    # check if sequence needs to be split
    if len(X) > max_sequence_length:
        count_sequences_split += 1
        count_splits += len(X) // max_sequence_length
        for i in range(0, len(X), max_sequence_length):
            y_list.append(y)
            X_list.append(X[i:i+max_sequence_length])
        assert len(X_list[0]) == max_sequence_length
    else:
        y_list.append(y)
        X_list.append(X)

    # transform elements to numpy arrays
    y_list = np.array(y_list)
    X_list = [np.array(x) for x in X_list]

    assert len(y_list) == len(X_list)
    return y_list, X_list


y_train = []
X_train = []
y_val = []
X_val = []
y_test = []
X_test = []

for filename in filenames_train:
    y_list, X_list = parse_file(filename)
    y_train.extend(y_list)
    X_train.extend(X_list)

for filename in filenames_val:
    y_list, X_list = parse_file(filename)
    y_val.extend(y_list)
    X_val.extend(X_list)

for filename in filenames_test:
    y_list, X_list = parse_file(filename)
    y_test.extend(y_list)
    X_test.extend(X_list)

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)

print(f'Files read: {count_files_read}')
print(f'Sequences split: {count_sequences_split}')
print(f'Splits: {count_splits}')

event_types_cardinality = len(event_types_map)
users_cardinality = len(users_map)
filetypes_cardinality = len(filetypes_map)

print(f'Event types: {event_types_cardinality}')
print(f'Users: {users_cardinality}')
print(f'Filetypes: {filetypes_cardinality}')

# print lengths
print(f'Train: {len(y_train)}')
print(f'Validation: {len(y_val)}')
print(f'Test: {len(y_test)}')
# Out:
# Files read: 50000
# Files read: 100000
# Files read: 150000
# Files read: 200000
# Files read: 214965
# Sequences split: 22897
# Splits: 132960
# Event types: 29
# Users: 16
# Filetypes: 7
# Train: 247249
# Validation: 48541
# Test: 52084

# %%
# turn labels map into bidirectional map
for k, v in labels_map.copy().items():
    labels_map[v] = k

# turn feature maps into bidirectional maps
for k, v in event_types_map.copy().items():
    event_types_map[v] = k

for k, v in users_map.copy().items():
    users_map[v] = k

for k, v in filetypes_map.copy().items():
    filetypes_map[v] = k

# %%
# print distributions in all 3 sets
train_distribution = Counter(y_train)
val_distribution = Counter(y_val)
test_distribution = Counter(y_test)

# plot 3 pie plots, use same colors for same classes
colors = plt.cm.tab20.colors
colors = [ colors[i % 20] for i in range(labels_cardinality) ]

# sort labels by occurence in training set
sorted_labels = sorted(train_distribution, key=train_distribution.get, reverse=True)

# sort all distributions by sorted_labels
train_distribution = [train_distribution[label] for label in sorted_labels]
val_distribution = [val_distribution[label] for label in sorted_labels]
test_distribution = [test_distribution[label] for label in sorted_labels]

# transform labels to names
sorted_labels = [labels_map[label] for label in sorted_labels]

fig, axs = plt.subplots(1, 3, figsize=(30*cm, 10*cm))
axs[0].pie(train_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[0].set_title('Train')
axs[1].pie(val_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[1].set_title('Validation')
axs[2].pie(test_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[2].set_title('Test')
plt.savefig(f'{checkpoint_path}/distributions.png')
plt.show()

# %%
# one-hot encode labels
y_train = np.eye(labels_cardinality)[y_train]
y_val = np.eye(labels_cardinality)[y_val]
y_test = np.eye(labels_cardinality)[y_test]

# %%
# one-hot encode features
# at this point, X_* are lists of tuples of vectorized features

def encode_features(sequence: tuple) -> np.ndarray:
    seq = []
    for feature_vector in sequence:
        event = feature_vector[0]
        event = np.eye(event_types_cardinality)[event]
        user = feature_vector[1]
        user = np.eye(users_cardinality)[user]
        filetype1 = feature_vector[2]
        filetype1 = np.eye(filetypes_cardinality)[filetype1]
        filetype2 = feature_vector[3]
        filetype2 = np.eye(filetypes_cardinality)[filetype2]

        # combine all features, i.e. turn shapes (a,) (b,) (c,) (d,) into (a+b+c+d,)
        # features = np.concatenate((event, user, filetype1, filetype2))
        features = np.concatenate((event, user, filetype1, filetype2))
        seq.append(features)
        #seq.append(event)

    return np.array(seq)

X_train = [ encode_features(x) for x in X_train ]
X_val = [ encode_features(x) for x in X_val ]
X_test = [ encode_features(x) for x in X_test ]

# %%
feature_vector_cardinality = X_train[0].shape[1]

print(f'Feature vector cardinality: {feature_vector_cardinality}')
# Out:
# Feature vector cardinality: 59

# %%
X_train, y_train = shuffle(X_train, y_train, random_state=42)
X_val, y_val = shuffle(X_val, y_val, random_state=42)
X_test, y_test = shuffle(X_test, y_test, random_state=42)

# %%
class Generator(tf.keras.utils.Sequence):
    def __init__(self, X, y, batch_size, fixed_length, **kwargs):
        # valid **kwargs: workers, use_multiprocessing, max_queue_size
        super().__init__()
        self.X = X
        self.y = y
        self.batch_size = batch_size
        self.fixed_length = fixed_length
        self.no_samples = len(X)
        self.no_batches = int(np.ceil(self.no_samples / self.batch_size))

    def __len__(self):
        return self.no_batches

    def __getitem__(self, index):
        start = index * self.batch_size
        end = min(start + self.batch_size, self.no_samples)

        # Get the batch data
        X_batch = self.X[start:end]
        y_batch = self.y[start:end]

        # Pad or truncate each sequence in X_batch to the fixed length
        X_batch_fixed = [self._pad_or_truncate(x, self.fixed_length) for x in X_batch]

        # Convert to numpy arrays
        X_batch_fixed = np.array(X_batch_fixed)
        y_batch = np.array(y_batch)

        return X_batch_fixed, y_batch

    def _pad_or_truncate(self, sequence, length):
        return np.pad(sequence, ((0, length - len(sequence)), (0, 0)), mode='constant', constant_values=0)

    def on_epoch_end(self):
        # shuffle data
        self.X, self.y = shuffle(self.X, self.y, random_state=42)

# %% [markdown]
# build model

# %%
model = Sequential(layers=[
    Input(shape=(None, feature_vector_cardinality)),
    SimpleRNN(64, return_sequences=True),
    SimpleRNN(64, return_sequences=True),
    SimpleRNN(64, return_sequences=False),
    Dense(labels_cardinality, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_12 (SimpleRNN)       │ (None, None, 64)       │         7,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_13 (SimpleRNN)       │ (None, None, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_14 (SimpleRNN)       │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 67)             │         4,355 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,803 (112.51 KB)
#  Trainable params: 28,803 (112.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1,
        mode='auto'
    ),
    ModelCheckpoint(
        filepath=model_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        verbose=1,
        mode='auto',
        min_lr=1e-7
    ),
    CSVLogger(
        filename=log_path,
        append=True
    )
]

loss = CategoricalCrossentropy()
optimizer = Adam(learning_rate=0.0001)

# class weights
y_train_int = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)
class_weights_dict = dict(enumerate(class_weights))

metrics = [
    CategoricalAccuracy(name='categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'top_{top_k}_categorical_accuracy'),
]

weighted_metrics = [
    CategoricalAccuracy(name='w_categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'w_top_{top_k}_categorical_accuracy'),
]

# 'categorical_focal_crossentropy'
# 'categorical_crossentropy'
model.compile(
    loss=loss,
    optimizer=optimizer,
    metrics=metrics,
    weighted_metrics=weighted_metrics,
)

# %% [markdown]
# train model

# %%
history = model.fit(
    x=Generator(X_train, y_train, 128, max_sequence_length),
    validation_data=Generator(X_val, y_val, 128, max_sequence_length),
    epochs=200,
    callbacks=callbacks,
    class_weight=class_weights_dict
)

# save history to file
with open(history_path, 'wb') as f:
    np.save(f, history.history)
# Out:
# Epoch 1/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.3488 - loss: 3.4837 - top_3_categorical_accuracy: 0.4601 - w_categorical_accuracy: 0.2912 - w_top_3_categorical_accuracy: 0.4006
# Epoch 1: val_loss improved from inf to 1.82936, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 76s 38ms/step - categorical_accuracy: 0.3491 - loss: 3.4833 - top_3_categorical_accuracy: 0.4604 - w_categorical_accuracy: 0.2914 - w_top_3_categorical_accuracy: 0.4008 - val_categorical_accuracy: 0.7558 - val_loss: 1.8294 - val_top_3_categorical_accuracy: 0.8337 - val_w_categorical_accuracy: 0.7558 - val_w_top_3_categorical_accuracy: 0.8337 - learning_rate: 1.0000e-04
# Epoch 2/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8381 - loss: 2.1288 - top_3_categorical_accuracy: 0.8965 - w_categorical_accuracy: 0.5693 - w_top_3_categorical_accuracy: 0.7294
# Epoch 2: val_loss improved from 1.82936 to 1.14955, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.8381 - loss: 2.1285 - top_3_categorical_accuracy: 0.8965 - w_categorical_accuracy: 0.5694 - w_top_3_categorical_accuracy: 0.7295 - val_categorical_accuracy: 0.8125 - val_loss: 1.1496 - val_top_3_categorical_accuracy: 0.8735 - val_w_categorical_accuracy: 0.8125 - val_w_top_3_categorical_accuracy: 0.8735 - learning_rate: 1.0000e-04
# Epoch 3/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8745 - loss: 1.4273 - top_3_categorical_accuracy: 0.9217 - w_categorical_accuracy: 0.7147 - w_top_3_categorical_accuracy: 0.8516
# Epoch 3: val_loss improved from 1.14955 to 1.02273, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 36ms/step - categorical_accuracy: 0.8745 - loss: 1.4273 - top_3_categorical_accuracy: 0.9217 - w_categorical_accuracy: 0.7147 - w_top_3_categorical_accuracy: 0.8516 - val_categorical_accuracy: 0.8196 - val_loss: 1.0227 - val_top_3_categorical_accuracy: 0.8767 - val_w_categorical_accuracy: 0.8196 - val_w_top_3_categorical_accuracy: 0.8767 - learning_rate: 1.0000e-04
# Epoch 4/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8832 - loss: 1.1414 - top_3_categorical_accuracy: 0.9301 - w_categorical_accuracy: 0.7617 - w_top_3_categorical_accuracy: 0.8905
# Epoch 4: val_loss improved from 1.02273 to 0.90770, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.8832 - loss: 1.1414 - top_3_categorical_accuracy: 0.9301 - w_categorical_accuracy: 0.7616 - w_top_3_categorical_accuracy: 0.8905 - val_categorical_accuracy: 0.8315 - val_loss: 0.9077 - val_top_3_categorical_accuracy: 0.8959 - val_w_categorical_accuracy: 0.8315 - val_w_top_3_categorical_accuracy: 0.8959 - learning_rate: 1.0000e-04
# Epoch 5/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8869 - loss: 0.9682 - top_3_categorical_accuracy: 0.9416 - w_categorical_accuracy: 0.7881 - w_top_3_categorical_accuracy: 0.8976
# Epoch 5: val_loss improved from 0.90770 to 0.80264, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.8869 - loss: 0.9682 - top_3_categorical_accuracy: 0.9416 - w_categorical_accuracy: 0.7881 - w_top_3_categorical_accuracy: 0.8976 - val_categorical_accuracy: 0.8419 - val_loss: 0.8026 - val_top_3_categorical_accuracy: 0.8981 - val_w_categorical_accuracy: 0.8419 - val_w_top_3_categorical_accuracy: 0.8981 - learning_rate: 1.0000e-04
# Epoch 6/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8950 - loss: 0.8114 - top_3_categorical_accuracy: 0.9447 - w_categorical_accuracy: 0.8146 - w_top_3_categorical_accuracy: 0.9200
# Epoch 6: val_loss improved from 0.80264 to 0.78404, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 69s 36ms/step - categorical_accuracy: 0.8950 - loss: 0.8114 - top_3_categorical_accuracy: 0.9447 - w_categorical_accuracy: 0.8146 - w_top_3_categorical_accuracy: 0.9200 - val_categorical_accuracy: 0.8418 - val_loss: 0.7840 - val_top_3_categorical_accuracy: 0.9024 - val_w_categorical_accuracy: 0.8418 - val_w_top_3_categorical_accuracy: 0.9024 - learning_rate: 1.0000e-04
# Epoch 7/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.9004 - loss: 0.6885 - top_3_categorical_accuracy: 0.9496 - w_categorical_accuracy: 0.8436 - w_top_3_categorical_accuracy: 0.9331
# Epoch 7: val_loss improved from 0.78404 to 0.76543, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 37ms/step - categorical_accuracy: 0.9004 - loss: 0.6885 - top_3_categorical_accuracy: 0.9496 - w_categorical_accuracy: 0.8436 - w_top_3_categorical_accuracy: 0.9331 - val_categorical_accuracy: 0.8523 - val_loss: 0.7654 - val_top_3_categorical_accuracy: 0.9054 - val_w_categorical_accuracy: 0.8523 - val_w_top_3_categorical_accuracy: 0.9054 - learning_rate: 1.0000e-04
# Epoch 8/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9072 - loss: 0.6266 - top_3_categorical_accuracy: 0.9526 - w_categorical_accuracy: 0.8416 - w_top_3_categorical_accuracy: 0.9416
# Epoch 8: val_loss improved from 0.76543 to 0.70801, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9072 - loss: 0.6266 - top_3_categorical_accuracy: 0.9526 - w_categorical_accuracy: 0.8416 - w_top_3_categorical_accuracy: 0.9416 - val_categorical_accuracy: 0.8625 - val_loss: 0.7080 - val_top_3_categorical_accuracy: 0.9105 - val_w_categorical_accuracy: 0.8625 - val_w_top_3_categorical_accuracy: 0.9105 - learning_rate: 1.0000e-04
# Epoch 9/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9090 - loss: 0.5807 - top_3_categorical_accuracy: 0.9542 - w_categorical_accuracy: 0.8454 - w_top_3_categorical_accuracy: 0.9420
# Epoch 9: val_loss improved from 0.70801 to 0.68195, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9090 - loss: 0.5807 - top_3_categorical_accuracy: 0.9542 - w_categorical_accuracy: 0.8454 - w_top_3_categorical_accuracy: 0.9420 - val_categorical_accuracy: 0.8688 - val_loss: 0.6819 - val_top_3_categorical_accuracy: 0.9139 - val_w_categorical_accuracy: 0.8688 - val_w_top_3_categorical_accuracy: 0.9139 - learning_rate: 1.0000e-04
# Epoch 10/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9160 - loss: 0.4929 - top_3_categorical_accuracy: 0.9610 - w_categorical_accuracy: 0.8637 - w_top_3_categorical_accuracy: 0.9574
# Epoch 10: val_loss did not improve from 0.68195
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9160 - loss: 0.4929 - top_3_categorical_accuracy: 0.9610 - w_categorical_accuracy: 0.8637 - w_top_3_categorical_accuracy: 0.9574 - val_categorical_accuracy: 0.8612 - val_loss: 0.7100 - val_top_3_categorical_accuracy: 0.9104 - val_w_categorical_accuracy: 0.8612 - val_w_top_3_categorical_accuracy: 0.9104 - learning_rate: 1.0000e-04
# Epoch 11/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9179 - loss: 0.4937 - top_3_categorical_accuracy: 0.9630 - w_categorical_accuracy: 0.8613 - w_top_3_categorical_accuracy: 0.9567
# Epoch 11: val_loss improved from 0.68195 to 0.65453, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9179 - loss: 0.4937 - top_3_categorical_accuracy: 0.9630 - w_categorical_accuracy: 0.8613 - w_top_3_categorical_accuracy: 0.9567 - val_categorical_accuracy: 0.8708 - val_loss: 0.6545 - val_top_3_categorical_accuracy: 0.9129 - val_w_categorical_accuracy: 0.8708 - val_w_top_3_categorical_accuracy: 0.9129 - learning_rate: 1.0000e-04
# Epoch 12/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9209 - loss: 0.4315 - top_3_categorical_accuracy: 0.9660 - w_categorical_accuracy: 0.8807 - w_top_3_categorical_accuracy: 0.9658
# Epoch 12: val_loss improved from 0.65453 to 0.64065, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 37ms/step - categorical_accuracy: 0.9209 - loss: 0.4315 - top_3_categorical_accuracy: 0.9660 - w_categorical_accuracy: 0.8807 - w_top_3_categorical_accuracy: 0.9658 - val_categorical_accuracy: 0.8716 - val_loss: 0.6407 - val_top_3_categorical_accuracy: 0.9240 - val_w_categorical_accuracy: 0.8716 - val_w_top_3_categorical_accuracy: 0.9240 - learning_rate: 1.0000e-04
# Epoch 13/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9202 - loss: 0.4459 - top_3_categorical_accuracy: 0.9698 - w_categorical_accuracy: 0.8553 - w_top_3_categorical_accuracy: 0.9680
# Epoch 13: val_loss improved from 0.64065 to 0.59390, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9202 - loss: 0.4459 - top_3_categorical_accuracy: 0.9698 - w_categorical_accuracy: 0.8553 - w_top_3_categorical_accuracy: 0.9680 - val_categorical_accuracy: 0.8821 - val_loss: 0.5939 - val_top_3_categorical_accuracy: 0.9315 - val_w_categorical_accuracy: 0.8821 - val_w_top_3_categorical_accuracy: 0.9315 - learning_rate: 1.0000e-04
# Epoch 14/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9239 - loss: 0.3921 - top_3_categorical_accuracy: 0.9712 - w_categorical_accuracy: 0.8839 - w_top_3_categorical_accuracy: 0.9676
# Epoch 14: val_loss improved from 0.59390 to 0.57743, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9239 - loss: 0.3921 - top_3_categorical_accuracy: 0.9712 - w_categorical_accuracy: 0.8839 - w_top_3_categorical_accuracy: 0.9676 - val_categorical_accuracy: 0.8847 - val_loss: 0.5774 - val_top_3_categorical_accuracy: 0.9301 - val_w_categorical_accuracy: 0.8847 - val_w_top_3_categorical_accuracy: 0.9301 - learning_rate: 1.0000e-04
# Epoch 15/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9265 - loss: 0.4068 - top_3_categorical_accuracy: 0.9723 - w_categorical_accuracy: 0.8694 - w_top_3_categorical_accuracy: 0.9692
# Epoch 15: val_loss did not improve from 0.57743
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9265 - loss: 0.4068 - top_3_categorical_accuracy: 0.9723 - w_categorical_accuracy: 0.8694 - w_top_3_categorical_accuracy: 0.9692 - val_categorical_accuracy: 0.8756 - val_loss: 0.6182 - val_top_3_categorical_accuracy: 0.9268 - val_w_categorical_accuracy: 0.8756 - val_w_top_3_categorical_accuracy: 0.9268 - learning_rate: 1.0000e-04
# Epoch 16/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9123 - loss: 0.4469 - top_3_categorical_accuracy: 0.9667 - w_categorical_accuracy: 0.8571 - w_top_3_categorical_accuracy: 0.9581
# Epoch 16: val_loss improved from 0.57743 to 0.56771, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 37ms/step - categorical_accuracy: 0.9123 - loss: 0.4468 - top_3_categorical_accuracy: 0.9667 - w_categorical_accuracy: 0.8571 - w_top_3_categorical_accuracy: 0.9581 - val_categorical_accuracy: 0.8897 - val_loss: 0.5677 - val_top_3_categorical_accuracy: 0.9331 - val_w_categorical_accuracy: 0.8897 - val_w_top_3_categorical_accuracy: 0.9331 - learning_rate: 1.0000e-04
# Epoch 17/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9333 - loss: 0.3345 - top_3_categorical_accuracy: 0.9778 - w_categorical_accuracy: 0.8902 - w_top_3_categorical_accuracy: 0.9769
# Epoch 17: val_loss did not improve from 0.56771
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9333 - loss: 0.3345 - top_3_categorical_accuracy: 0.9778 - w_categorical_accuracy: 0.8902 - w_top_3_categorical_accuracy: 0.9769 - val_categorical_accuracy: 0.8417 - val_loss: 1.0395 - val_top_3_categorical_accuracy: 0.9105 - val_w_categorical_accuracy: 0.8417 - val_w_top_3_categorical_accuracy: 0.9105 - learning_rate: 1.0000e-04
# Epoch 18/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9316 - loss: 0.3489 - top_3_categorical_accuracy: 0.9746 - w_categorical_accuracy: 0.8924 - w_top_3_categorical_accuracy: 0.9739
# Epoch 18: val_loss did not improve from 0.56771
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 37ms/step - categorical_accuracy: 0.9316 - loss: 0.3489 - top_3_categorical_accuracy: 0.9746 - w_categorical_accuracy: 0.8924 - w_top_3_categorical_accuracy: 0.9739 - val_categorical_accuracy: 0.8923 - val_loss: 0.5746 - val_top_3_categorical_accuracy: 0.9361 - val_w_categorical_accuracy: 0.8923 - val_w_top_3_categorical_accuracy: 0.9361 - learning_rate: 1.0000e-04
# Epoch 19/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9361 - loss: 0.3174 - top_3_categorical_accuracy: 0.9788 - w_categorical_accuracy: 0.9070 - w_top_3_categorical_accuracy: 0.9747
# Epoch 19: val_loss did not improve from 0.56771
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9361 - loss: 0.3174 - top_3_categorical_accuracy: 0.9788 - w_categorical_accuracy: 0.9070 - w_top_3_categorical_accuracy: 0.9747 - val_categorical_accuracy: 0.8950 - val_loss: 0.5767 - val_top_3_categorical_accuracy: 0.9353 - val_w_categorical_accuracy: 0.8950 - val_w_top_3_categorical_accuracy: 0.9353 - learning_rate: 1.0000e-04
# Epoch 20/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9435 - loss: 0.2880 - top_3_categorical_accuracy: 0.9789 - w_categorical_accuracy: 0.9013 - w_top_3_categorical_accuracy: 0.9799
# Epoch 20: val_loss improved from 0.56771 to 0.53041, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9435 - loss: 0.2880 - top_3_categorical_accuracy: 0.9789 - w_categorical_accuracy: 0.9013 - w_top_3_categorical_accuracy: 0.9799 - val_categorical_accuracy: 0.9025 - val_loss: 0.5304 - val_top_3_categorical_accuracy: 0.9401 - val_w_categorical_accuracy: 0.9025 - val_w_top_3_categorical_accuracy: 0.9401 - learning_rate: 1.0000e-05
# Epoch 21/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9468 - loss: 0.2433 - top_3_categorical_accuracy: 0.9829 - w_categorical_accuracy: 0.9172 - w_top_3_categorical_accuracy: 0.9832
# Epoch 21: val_loss did not improve from 0.53041
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9468 - loss: 0.2433 - top_3_categorical_accuracy: 0.9829 - w_categorical_accuracy: 0.9172 - w_top_3_categorical_accuracy: 0.9832 - val_categorical_accuracy: 0.9029 - val_loss: 0.5312 - val_top_3_categorical_accuracy: 0.9408 - val_w_categorical_accuracy: 0.9029 - val_w_top_3_categorical_accuracy: 0.9408 - learning_rate: 1.0000e-05
# Epoch 22/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9461 - loss: 0.2723 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9032 - w_top_3_categorical_accuracy: 0.9783
# Epoch 22: val_loss improved from 0.53041 to 0.52935, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9461 - loss: 0.2723 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9032 - w_top_3_categorical_accuracy: 0.9783 - val_categorical_accuracy: 0.9026 - val_loss: 0.5294 - val_top_3_categorical_accuracy: 0.9379 - val_w_categorical_accuracy: 0.9026 - val_w_top_3_categorical_accuracy: 0.9379 - learning_rate: 1.0000e-05
# Epoch 23/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9473 - loss: 0.2633 - top_3_categorical_accuracy: 0.9825 - w_categorical_accuracy: 0.9036 - w_top_3_categorical_accuracy: 0.9827
# Epoch 23: val_loss did not improve from 0.52935
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9473 - loss: 0.2633 - top_3_categorical_accuracy: 0.9825 - w_categorical_accuracy: 0.9036 - w_top_3_categorical_accuracy: 0.9827 - val_categorical_accuracy: 0.9030 - val_loss: 0.5313 - val_top_3_categorical_accuracy: 0.9379 - val_w_categorical_accuracy: 0.9030 - val_w_top_3_categorical_accuracy: 0.9379 - learning_rate: 1.0000e-05
# Epoch 24/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9472 - loss: 0.2553 - top_3_categorical_accuracy: 0.9808 - w_categorical_accuracy: 0.9104 - w_top_3_categorical_accuracy: 0.9826
# Epoch 24: val_loss improved from 0.52935 to 0.52449, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9472 - loss: 0.2553 - top_3_categorical_accuracy: 0.9808 - w_categorical_accuracy: 0.9104 - w_top_3_categorical_accuracy: 0.9826 - val_categorical_accuracy: 0.9034 - val_loss: 0.5245 - val_top_3_categorical_accuracy: 0.9382 - val_w_categorical_accuracy: 0.9034 - val_w_top_3_categorical_accuracy: 0.9382 - learning_rate: 1.0000e-05
# Epoch 25/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9485 - loss: 0.2535 - top_3_categorical_accuracy: 0.9815 - w_categorical_accuracy: 0.8983 - w_top_3_categorical_accuracy: 0.9816
# Epoch 25: val_loss improved from 0.52449 to 0.52281, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9485 - loss: 0.2535 - top_3_categorical_accuracy: 0.9815 - w_categorical_accuracy: 0.8983 - w_top_3_categorical_accuracy: 0.9816 - val_categorical_accuracy: 0.9041 - val_loss: 0.5228 - val_top_3_categorical_accuracy: 0.9386 - val_w_categorical_accuracy: 0.9041 - val_w_top_3_categorical_accuracy: 0.9386 - learning_rate: 1.0000e-05
# Epoch 26/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9473 - loss: 0.2328 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9213 - w_top_3_categorical_accuracy: 0.9821
# Epoch 26: val_loss improved from 0.52281 to 0.51584, saving model to saves/rnn/100_baseline4_userfiletypes_64/model.keras
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9473 - loss: 0.2328 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9213 - w_top_3_categorical_accuracy: 0.9821 - val_categorical_accuracy: 0.9040 - val_loss: 0.5158 - val_top_3_categorical_accuracy: 0.9386 - val_w_categorical_accuracy: 0.9040 - val_w_top_3_categorical_accuracy: 0.9386 - learning_rate: 1.0000e-05
# Epoch 27/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9480 - loss: 0.2386 - top_3_categorical_accuracy: 0.9816 - w_categorical_accuracy: 0.9181 - w_top_3_categorical_accuracy: 0.9824
# Epoch 27: val_loss did not improve from 0.51584
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9480 - loss: 0.2386 - top_3_categorical_accuracy: 0.9816 - w_categorical_accuracy: 0.9181 - w_top_3_categorical_accuracy: 0.9824 - val_categorical_accuracy: 0.9048 - val_loss: 0.5206 - val_top_3_categorical_accuracy: 0.9388 - val_w_categorical_accuracy: 0.9048 - val_w_top_3_categorical_accuracy: 0.9388 - learning_rate: 1.0000e-05
# Epoch 28/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9485 - loss: 0.2553 - top_3_categorical_accuracy: 0.9819 - w_categorical_accuracy: 0.9099 - w_top_3_categorical_accuracy: 0.9830
# Epoch 28: val_loss did not improve from 0.51584
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 71s 36ms/step - categorical_accuracy: 0.9485 - loss: 0.2552 - top_3_categorical_accuracy: 0.9819 - w_categorical_accuracy: 0.9099 - w_top_3_categorical_accuracy: 0.9830 - val_categorical_accuracy: 0.9041 - val_loss: 0.5288 - val_top_3_categorical_accuracy: 0.9387 - val_w_categorical_accuracy: 0.9041 - val_w_top_3_categorical_accuracy: 0.9387 - learning_rate: 1.0000e-05
# Epoch 29/200
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9492 - loss: 0.2278 - top_3_categorical_accuracy: 0.9824 - w_categorical_accuracy: 0.9238 - w_top_3_categorical_accuracy: 0.9837
# Epoch 29: val_loss did not improve from 0.51584
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9492 - loss: 0.2278 - top_3_categorical_accuracy: 0.9824 - w_categorical_accuracy: 0.9238 - w_top_3_categorical_accuracy: 0.9837 - val_categorical_accuracy: 0.9052 - val_loss: 0.5235 - val_top_3_categorical_accuracy: 0.9388 - val_w_categorical_accuracy: 0.9052 - val_w_top_3_categorical_accuracy: 0.9388 - learning_rate: 1.0000e-05
# Epoch 30/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9487 - loss: 0.2540 - top_3_categorical_accuracy: 0.9810 - w_categorical_accuracy: 0.8969 - w_top_3_categorical_accuracy: 0.9815
# Epoch 30: val_loss did not improve from 0.51584
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9487 - loss: 0.2539 - top_3_categorical_accuracy: 0.9810 - w_categorical_accuracy: 0.8970 - w_top_3_categorical_accuracy: 0.9815 - val_categorical_accuracy: 0.9053 - val_loss: 0.5254 - val_top_3_categorical_accuracy: 0.9389 - val_w_categorical_accuracy: 0.9053 - val_w_top_3_categorical_accuracy: 0.9389 - learning_rate: 1.0000e-06
# Epoch 31/200
# 1931/1932 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.9490 - loss: 0.2442 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9181 - w_top_3_categorical_accuracy: 0.9830
# Epoch 31: val_loss did not improve from 0.51584
# 1932/1932 ━━━━━━━━━━━━━━━━━━━━ 70s 36ms/step - categorical_accuracy: 0.9490 - loss: 0.2442 - top_3_categorical_accuracy: 0.9817 - w_categorical_accuracy: 0.9181 - w_top_3_categorical_accuracy: 0.9830 - val_categorical_accuracy: 0.9053 - val_loss: 0.5265 - val_top_3_categorical_accuracy: 0.9389 - val_w_categorical_accuracy: 0.9053 - val_w_top_3_categorical_accuracy: 0.9389 - learning_rate: 1.0000e-06
# Epoch 31: early stopping

# %%
print(log_path)
# Out:
# saves/rnn/100_baseline4_userfiletypes_64/log.csv

# %%
log = pd.read_csv(log_path)

fig, ax = plt.subplots(figsize=(15*cm, 9*cm))

# categorical_accuracy, top_k_categorical_accuracy
# val_categorical_accuracy ,val_top_k_categorical_accuracy
# val_weighted_categorical_accuracy,weighted_categorical_accuracy


ax.plot(log['epoch'], log['categorical_accuracy'], label='categorical_accuracy', color='red')
ax.plot(log['epoch'], log['val_categorical_accuracy'], label='val_categorical_accuracy', color='orange')
ax.plot(log['epoch'], log[f'top_{top_k}_categorical_accuracy'], label=f'top_{top_k}_categorical_accuracy', color='royalblue')
ax.plot(log['epoch'], log[f'val_top_{top_k}_categorical_accuracy'], label=f'val_top_{top_k}_categorical_accuracy', color='navy')
#ax.plot(log['epoch'], log['w_categorical_accuracy'], label='w_categorical_accuracy', color='green')
#ax.plot(log['epoch'], log['val_w_categorical_accuracy'], label='val_w_weighted_categorical_accuracy', color='lime')
#ax.plot(log['epoch'], log[f'w_top_{top_k}_categorical_accuracy'], label=f'w_top_{top_k}_categorical_accuracy', color='purple')
#ax.plot(log['epoch'], log[f'val_w_top_{top_k}_categorical_accuracy'], label=f'val_w_top_{top_k}_categorical_accuracy', color='magenta')
ax.set_title('accuracy')
ax.set_xlabel('epoch')
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig(f'{checkpoint_path}/metrics.svg')
plt.show()

fig, ax = plt.subplots(figsize=(15*cm, 9*cm))
ax.plot(log['epoch'], log['loss'], label='loss')
ax.plot(log['epoch'], log['val_loss'], label='val_loss')
ax.set_title('loss')
ax.set_xlabel('epoch')
# print legend outside of plot
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.savefig(f'{checkpoint_path}/loss.svg')
plt.show()

# %%
log = pd.read_csv(log_path)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20*cm, 15*cm))

ax1.plot(log['epoch'], log['categorical_accuracy'], label='categorical_accuracy', color='red')
ax1.plot(log['epoch'], log['val_categorical_accuracy'], label='val_categorical_accuracy', color='orange')
ax1.plot(log['epoch'], log[f'top_{top_k}_categorical_accuracy'], label=f'top_{top_k}_categorical_accuracy', color='royalblue')
ax1.plot(log['epoch'], log[f'val_top_{top_k}_categorical_accuracy'], label=f'val_top_{top_k}_categorical_accuracy', color='navy')
ax1.set_title('training metrics')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1)  # Legend below the plot

ax2.plot(log['epoch'], log['loss'], label='loss')
ax2.plot(log['epoch'], log['val_loss'], label='val_loss')
ax2.set_title('loss')
ax2.set_xlabel('epoch')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)  # Legend below the plot

fig.tight_layout(rect=[0, 0.1, 1, 1])

plt.savefig(f'{checkpoint_path}/metrics_loss.svg')
plt.show()

# %%
# load old model
model = load_model(model_path)

# %%
# evaluate model
score = model.evaluate(x=Generator(X_test, y_test, 128, max_sequence_length))
print(f'Test loss: {score[0]}')
print(f'Test accuracy: {score[1]}')
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - categorical_accuracy: 0.9340 - loss: 0.2403 - top_3_categorical_accuracy: 0.9729 - w_categorical_accuracy: 0.9340 - w_top_3_categorical_accuracy: 0.9729
# Test loss: 0.24187071621418
# Test accuracy: 0.9343752264976501

# %%
# print classification report
y_pred = model.predict(x=Generator(X_test, y_test, 128, max_sequence_length))
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

print(classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan))
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
#                  precision    recall  f1-score   support
#
#       adjkerntz       0.44      1.00      0.61        11
#          alpine       0.86      0.93      0.89       560
#           anvil       0.55      0.58      0.57       378
#           atrun       1.00      1.00      1.00       237
#             awk       0.83      1.00      0.91         5
#        basename        nan      0.00      0.00         2
#            bash       1.00      0.98      0.99     12512
#             cat       0.86      0.96      0.91        26
#         cleanup       0.24      0.96      0.38       276
#             cmp       1.00      1.00      1.00         5
#              cp       1.00      1.00      1.00        30
#            cron       0.97      1.00      0.98       624
#            date       1.00      1.00      1.00      1218
#              dd       1.00      0.99      1.00       125
#        dhclient       0.00      0.00      0.00        17
#           dmesg       0.75      1.00      0.86        15
#           egrep       0.25      0.50      0.33         2
#            expr        nan      0.00      0.00         2
#            find       1.00      1.00      1.00      4006
#         fortune       0.99      1.00      0.99        91
#            grep       0.13      0.80      0.22         5
#            head       1.00      1.00      1.00      1219
#        hostname       0.71      1.00      0.83        10
#           imapd       0.99      0.82      0.90      2469
#           inetd       1.00      1.00      1.00       291
#            kill       1.00      1.00      1.00         2
#            less       0.00      0.00      0.00         3
#           local       0.92      0.60      0.72       868
#           lockf       0.33      1.00      0.50         3
#              ls       0.54      0.58      0.56        12
#            lsof       1.00      0.99      1.00      8568
#            mail       0.14      0.50      0.22         2
#     mailwrapper       0.67      0.67      0.67         3
#          master       0.78      1.00      0.88       580
#           mkdir       0.95      1.00      0.97        18
#          mktemp       0.29      1.00      0.44         6
#           mlock       1.00      1.00      1.00       506
#           mount       0.40      1.00      0.57         2
#              mv       1.00      1.00      1.00       860
#         netstat       0.62      0.90      0.73        58
#       newsyslog       1.00      0.89      0.94        18
#          pickup       1.00      0.83      0.90       143
#             pkg       0.99      0.72      0.83      1701
#        proxymap       0.87      0.50      0.63       331
#              ps       0.19      1.00      0.31         5
#       python2.7       0.00      0.00      0.00       841
#       resizewin       0.83      1.00      0.91        91
#              rm       0.92      0.64      0.75        36
#           route       1.00      1.00      1.00         7
#             sed       0.00      0.00      0.00         2
#        sendmail       0.28      0.81      0.41        21
#              sh       1.00      0.89      0.94      1987
#           sleep       1.00      1.00      1.00      4889
#           smtpd       0.87      0.84      0.85       818
#            sort       0.11      1.00      0.20         1
#            sshd       0.92      0.99      0.95       427
#            sudo       0.52      0.92      0.67        26
#          sysctl       0.98      1.00      0.99       129
#             tee       0.56      0.83      0.67         6
#             top       0.98      0.99      0.99      1913
# trivial-rewrite       0.68      0.53      0.60       377
#             tty       1.00      1.00      1.00         2
#          unlink       0.98      1.00      0.99       123
#          uptime       0.93      1.00      0.97        14
#          vmstat       1.00      1.00      1.00      2468
#              wc       0.70      1.00      0.82         7
#            wget       0.69      0.86      0.77        74
#
#        accuracy                           0.93     52084
#       macro avg       0.73      0.82      0.73     52084
#    weighted avg       0.96      0.93      0.94     52084

# %%
# print confusion matrix
# labels explicitly set, because current model may not predict all labels
conf_matrix = confusion_matrix(y_true, y_pred, labels=range(labels_cardinality), normalize='true')

# Replace all NaN values with 0
conf_matrix = np.nan_to_num(conf_matrix)

# Verify the distinct labels align correctly
distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(20*cm, 20*cm))

ax.matshow(conf_matrix, cmap='cividis', aspect='auto')

# Set class names on axes
ax.set_xticks(range(len(distinct_labels)))
ax.set_yticks(range(len(distinct_labels)))
ax.set_xticklabels(distinct_labels, rotation=90, fontsize=8)
ax.set_yticklabels(distinct_labels, fontsize=8)

# Set axis labels "predicted" and "actual"
ax.set_xlabel('predicted label')
ax.set_ylabel('true label')
# y-axis label right side
ax.yaxis.set_label_position('right')

# set figsize
plt.savefig(f'{checkpoint_path}/confusion_matrix.svg')
plt.show()

# %%
unique_in_y_pred = [ labels_map[i] for i in np.unique(y_pred) ]
#print("Unique labels in y_pred:", unique_in_y_pred)

unique_not_in_y_pred = [ label for label in distinct_labels if label not in unique_in_y_pred ]
print("Unique labels not in y_pred:", unique_not_in_y_pred)
# Out:
# Unique labels not in y_pred: ['basename', 'expr']
