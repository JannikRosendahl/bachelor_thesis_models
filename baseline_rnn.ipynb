# %%
import os
import re
from collections import Counter
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cm = 1/2.54

# force GPU device
os.environ["CUDA_VISIBLE_DEVICES"]='1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

from keras.src.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.src.layers import SimpleRNN, LSTM, Dense, Dropout, Bidirectional
from keras import Sequential, Input
from keras.losses import CategoricalCrossentropy, CategoricalFocalCrossentropy
from keras.optimizers import Adam
from keras.models import load_model
from keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

from utils import *

# %%
max_sequence_length = 100
experiment_name = 'baseline'
top_k = 3

# %%
checkpoint_path = f'saves/{experiment_name}'
model_path = f'{checkpoint_path}/model.keras'
log_path = f'{checkpoint_path}/log.csv'
history_path = f'{checkpoint_path}/history.npy'

# ensure directory exists
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# %%
data_directory = '/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
unusable_threshold = 10
rare_threshold = 50
splits = (0.7, 0.15, 0.15)

max_sequence_length = 100

assert(sum(splits) == 1)

print(f'experiment parameters: \n{data_directory=} \n{unusable_threshold=} \n{rare_threshold=} \n{splits=} \n{max_sequence_length=}')
# Out:
# experiment parameters:
# data_directory='/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
# unusable_threshold=10
# rare_threshold=50
# splits=(0.7, 0.15, 0.15)
# max_sequence_length=100

# %%
total_classes = 0

# unusable classes will be removed from the dataset
unusable_classes = []
# rare classes will be oversampled
rare_classes = []

# all classes in training data (all classes - unusable classes)
classes = []

# walk all files, build unusable_classes, rare_classes
classes_occurrences = Counter()
for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    classes_occurrences[label] += 1

total_classes = len(classes_occurrences)
for label, count in classes_occurrences.items():
    if count < unusable_threshold:
        unusable_classes.append(label)
    elif count < rare_threshold:
        rare_classes.append(label)
        classes.append(label)
    else:
        classes.append(label)

print(f'Total classes: {total_classes}')
print(f'Unusable classes: {len(unusable_classes)}')
print(f'\t{unusable_classes}')
print(f'Rare classes: {len(rare_classes)}')
print(f'\t{rare_classes}')

labels_cardinality = len(set(classes))
print(f'Usable classes: {labels_cardinality}')
# Out:
# Total classes: 118
# Unusable classes: 51
# 	['ping', 'pwd_mkdb', 'vi', 'tr', 'uname', 'msgs', 'screen', 'pw', 'bzip2', 'bzcat', 'nginx', 'stat', 'tail', 'smtp', 'kenv', 'nawk', 'ssh', 'chown', 'cut', 'php-fpm', 'jot', 'xz', 'diff', 'bounce', 'links', 'ipfw', 'touch', 'env', 'pfctl', 'minions', 'csh', 'kldstat', 'su', 'nohup', 'stty', 'df', 'limits', 'id', 'postmap', 'ifconfig', 'chkgrp', 'ipfstat', 'locale', 'devd', 'uniq', 'XIM', 'getty', 'which', 'init', 'test', 'nice']
# Rare classes: 20
# 	['wc', 'grep', 'mktemp', 'less', 'tty', 'mailwrapper', 'kill', 'lockf', 'mount', 'tee', 'expr', 'ps', 'route', 'sed', 'cmp', 'egrep', 'sort', 'basename', 'awk', 'mail']
# Usable classes: 67

# %%
# split into train, validation, test
labels_set = set()

filenames_all = []

filenames_train = []
filenames_val = []
filenames_test = []

for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    if label in unusable_classes:
        continue
    labels_set.add(label)
    filenames_all.append(filename)

# stratisfied split
test_vs_val = splits[2] / (splits[1] + splits[2])
filenames_train, filenames_val_test = train_test_split(filenames_all, test_size=splits[1]+splits[2], stratify=[class_from_filename(f) for f in filenames_all])
filenames_val, filenames_test = train_test_split(filenames_val_test, test_size=test_vs_val, stratify=[class_from_filename(f) for f in filenames_val_test])

print(f'Train: {len(filenames_train)}')
print(f'Validation: {len(filenames_val)}')
print(f'Test: {len(filenames_test)}')

# build labels_map in alphabetical order
labels_map = {}
for i, label in enumerate(sorted(labels_set)):
    labels_map[label] = i
# Out:
# Train: 150475
# Validation: 32245
# Test: 32245

# %%
# load data
count_files_read = 0
count_sequences_split = 0
count_splits = 0

preprocessor = Preprocessor(['TYPE'])

def parse_file(filename) -> tuple[list[int], list[list[int]]]:
    """
    Parse a file and return the vectorized data. Not a pure function (calls parse_line)!
    """
    global count_files_read, count_sequences_split, count_splits

    y_list: list[int] = []
    X_list: list[list[int]] = []
    y = class_from_filename(filename)
    y = labels_map[y]
    with open(os.path.join(data_directory, filename), 'r') as f:
        lines = f.readlines()
        count_files_read += 1
    if count_files_read % 50000 == 0:
        print(f'Files read: {count_files_read}')
    X = []
    for line in lines:
        line_res = preprocessor.process(line)
        event = line_res['TYPE']
        X.append((event,))

    # check if sequence needs to be split
    if len(X) > max_sequence_length:
        count_sequences_split += 1
        count_splits += len(X) // max_sequence_length
        for i in range(0, len(X), max_sequence_length):
            y_list.append(y)
            X_list.append(X[i:i+max_sequence_length])
        assert len(X_list[0]) == max_sequence_length
    else:
        y_list.append(y)
        X_list.append(X)

    # transform elements to numpy arrays
    y_list = np.array(y_list)
    X_list = [np.array(x) for x in X_list]

    assert len(y_list) == len(X_list)
    return y_list, X_list


y_train = []
X_train = []
y_val = []
X_val = []
y_test = []
X_test = []

for filename in filenames_train:
    try:
        y_list, X_list = parse_file(filename)
    except Exception as e:
        print(f'Error parsing file: {filename}')
        raise e
    y_train.extend(y_list)
    X_train.extend(X_list)

for filename in filenames_val:
    y_list, X_list = parse_file(filename)
    y_val.extend(y_list)
    X_val.extend(X_list)

for filename in filenames_test:
    y_list, X_list = parse_file(filename)
    y_test.extend(y_list)
    X_test.extend(X_list)

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)

print(f'Files read: {count_files_read}')
print(f'Sequences split: {count_sequences_split}')
print(f'Splits: {count_splits}')


event_types_map = preprocessor.event_types_map

event_types_cardinality = len(event_types_map)

print(f'Event types: {event_types_cardinality}')

# print lengths
print(f'Train: {len(y_train)}')
print(f'Validation: {len(y_val)}')
print(f'Test: {len(y_test)}')
# Out:
# Files read: 50000
# Files read: 100000
# Files read: 150000
# Files read: 200000
# Files read: 214965
# Sequences split: 22897
# Splits: 132960
# Event types: 29
# Train: 247249
# Validation: 48541
# Test: 52084

# %%
# debug print all maps (sorted)
print('Event types:')
for k, v in sorted(event_types_map.items(), key=lambda x: x[1]):
    print(f'{v}: {k}', end=', ')
print()
# Out:
# Event types:
# 0: EVENT_EXECUTE, 1: EVENT_OPEN, 2: EVENT_READ, 3: EVENT_CLOSE, 4: EVENT_MMAP, 5: EVENT_WRITE, 6: EVENT_EXIT, 7: EVENT_CONNECT, 8: EVENT_SENDTO, 9: EVENT_LSEEK, 10: EVENT_CHANGE_PRINCIPAL, 11: EVENT_LOGIN, 12: EVENT_MODIFY_PROCESS, 13: EVENT_FCNTL, 14: EVENT_RECVFROM, 15: EVENT_MPROTECT, 16: EVENT_CREATE_OBJECT, 17: EVENT_ACCEPT, 18: EVENT_UNLINK, 19: EVENT_FORK, 20: EVENT_MODIFY_FILE_ATTRIBUTES, 21: EVENT_LINK, 22: EVENT_RENAME, 23: EVENT_TRUNCATE, 24: EVENT_SIGNAL, 25: EVENT_OTHER, 26: EVENT_SENDMSG, 27: EVENT_RECVMSG, 28: EVENT_BIND,

# %%
# turn labels map into bidirectional map
for k, v in labels_map.copy().items():
    labels_map[v] = k

# turn feature maps into bidirectional maps
for k, v in event_types_map.copy().items():
    event_types_map[v] = k

# %%
# print distributions in all 3 sets
train_distribution = Counter(y_train)
val_distribution = Counter(y_val)
test_distribution = Counter(y_test)

# plot 3 pie plots, use same colors for same classes
colors = plt.cm.tab20.colors
colors = [ colors[i % 20] for i in range(labels_cardinality) ]

# sort labels by occurence in training set
sorted_labels = sorted(train_distribution, key=train_distribution.get, reverse=True)

# sort all distributions by sorted_labels
train_distribution = [train_distribution[label] for label in sorted_labels]
val_distribution = [val_distribution[label] for label in sorted_labels]
test_distribution = [test_distribution[label] for label in sorted_labels]

# transform labels to names
sorted_labels = [labels_map[label] for label in sorted_labels]

fig, axs = plt.subplots(1, 3, figsize=(30*cm, 10*cm))
axs[0].pie(train_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[0].set_title('Train')
axs[1].pie(val_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[1].set_title('Validation')
axs[2].pie(test_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[2].set_title('Test')
plt.savefig(f'{checkpoint_path}/distributions.png')
plt.show()

# %%
# one-hot encode labels
y_train = np.eye(labels_cardinality)[y_train]
y_val = np.eye(labels_cardinality)[y_val]
y_test = np.eye(labels_cardinality)[y_test]

# %%
# one-hot encode features
# at this point, X_* are lists of tuples of vectorized features
def encode_features(sequence: np.ndarray) -> np.ndarray:
    # Precompute identity matrices
    event_eye = np.eye(event_types_cardinality)

    # Initialize the output array with precomputed shapes
    encoded_seq = np.empty((len(sequence), event_eye.shape[1]))

    for i, feature_vector in enumerate(sequence):
        event = event_eye[feature_vector[0]]

        # Concatenate all features into a single feature vector
        encoded_seq[i] = np.concatenate((event, ))

    return encoded_seq

X_train = [ encode_features(x) for x in X_train ]
X_val = [ encode_features(x) for x in X_val ]
X_test = [ encode_features(x) for x in X_test ]

# %%
feature_vector_cardinality = X_train[0].shape[1]

print(f'Feature vector cardinality: {feature_vector_cardinality}')
# Out:
# Feature vector cardinality: 29

# %%
X_train, y_train = shuffle(X_train, y_train)
X_val, y_val = shuffle(X_val, y_val)
X_test, y_test = shuffle(X_test, y_test)

# %% [markdown]
# build model

# %%
model = Sequential(layers=[
    Input(shape=(None, feature_vector_cardinality)),
    SimpleRNN(64, return_sequences=True),
    SimpleRNN(64, return_sequences=True),
    SimpleRNN(64, return_sequences=False),
    Dense(labels_cardinality, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_6 (SimpleRNN)        │ (None, None, 64)       │         6,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_7 (SimpleRNN)        │ (None, None, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_8 (SimpleRNN)        │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 67)             │         4,355 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,883 (105.01 KB)
#  Trainable params: 26,883 (105.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1,
        mode='auto'
    ),
    ModelCheckpoint(
        filepath=model_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        verbose=1,
        mode='auto',
        min_lr=1e-7
    ),
    CSVLogger(
        filename=log_path,
        append=True
    )
]

loss = CategoricalCrossentropy()
optimizer = Adam(learning_rate=0.0001)

# class weights
y_train_int = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)
class_weights_dict = dict(enumerate(class_weights))

metrics = [
    CategoricalAccuracy(name='categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'top_{top_k}_categorical_accuracy'),
]

weighted_metrics = [
    CategoricalAccuracy(name='w_categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'w_top_{top_k}_categorical_accuracy'),
]

# 'categorical_focal_crossentropy'
# 'categorical_crossentropy'
model.compile(
    loss=loss,
    optimizer=optimizer,
    metrics=metrics,
    weighted_metrics=weighted_metrics,
)

# %% [markdown]
# train model

# %%
history = model.fit(
    x=Generator(X_train, y_train, 64, max_sequence_length),
    validation_data=Generator(X_val, y_val, 64, max_sequence_length),
    epochs=200,
    callbacks=callbacks,
    class_weight=class_weights_dict
)

# save history to file
with open(history_path, 'wb') as f:
    np.save(f, history.history)
# Out:
# Epoch 1/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.4922 - loss: 3.3646 - top_3_categorical_accuracy: 0.6131 - w_categorical_accuracy: 0.2974 - w_top_3_categorical_accuracy: 0.4212
# Epoch 1: val_loss improved from inf to 1.81850, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 146s 37ms/step - categorical_accuracy: 0.4923 - loss: 3.3643 - top_3_categorical_accuracy: 0.6132 - w_categorical_accuracy: 0.2975 - w_top_3_categorical_accuracy: 0.4213 - val_categorical_accuracy: 0.6604 - val_loss: 1.8185 - val_top_3_categorical_accuracy: 0.8121 - val_w_categorical_accuracy: 0.6604 - val_w_top_3_categorical_accuracy: 0.8121 - learning_rate: 1.0000e-04
# Epoch 2/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7222 - loss: 1.8518 - top_3_categorical_accuracy: 0.8740 - w_categorical_accuracy: 0.6042 - w_top_3_categorical_accuracy: 0.7536
# Epoch 2: val_loss improved from 1.81850 to 1.51507, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7222 - loss: 1.8517 - top_3_categorical_accuracy: 0.8740 - w_categorical_accuracy: 0.6042 - w_top_3_categorical_accuracy: 0.7536 - val_categorical_accuracy: 0.7404 - val_loss: 1.5151 - val_top_3_categorical_accuracy: 0.8338 - val_w_categorical_accuracy: 0.7404 - val_w_top_3_categorical_accuracy: 0.8338 - learning_rate: 1.0000e-04
# Epoch 3/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7717 - loss: 1.4481 - top_3_categorical_accuracy: 0.8914 - w_categorical_accuracy: 0.6911 - w_top_3_categorical_accuracy: 0.8244
# Epoch 3: val_loss improved from 1.51507 to 1.40050, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7717 - loss: 1.4481 - top_3_categorical_accuracy: 0.8914 - w_categorical_accuracy: 0.6911 - w_top_3_categorical_accuracy: 0.8244 - val_categorical_accuracy: 0.7727 - val_loss: 1.4005 - val_top_3_categorical_accuracy: 0.8447 - val_w_categorical_accuracy: 0.7727 - val_w_top_3_categorical_accuracy: 0.8447 - learning_rate: 1.0000e-04
# Epoch 4/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7545 - loss: 1.2117 - top_3_categorical_accuracy: 0.8946 - w_categorical_accuracy: 0.7111 - w_top_3_categorical_accuracy: 0.8562
# Epoch 4: val_loss improved from 1.40050 to 1.34804, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.7545 - loss: 1.2117 - top_3_categorical_accuracy: 0.8946 - w_categorical_accuracy: 0.7111 - w_top_3_categorical_accuracy: 0.8562 - val_categorical_accuracy: 0.7982 - val_loss: 1.3480 - val_top_3_categorical_accuracy: 0.8495 - val_w_categorical_accuracy: 0.7982 - val_w_top_3_categorical_accuracy: 0.8495 - learning_rate: 1.0000e-04
# Epoch 5/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7685 - loss: 1.1045 - top_3_categorical_accuracy: 0.9080 - w_categorical_accuracy: 0.7278 - w_top_3_categorical_accuracy: 0.8778
# Epoch 5: val_loss did not improve from 1.34804
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7685 - loss: 1.1045 - top_3_categorical_accuracy: 0.9080 - w_categorical_accuracy: 0.7278 - w_top_3_categorical_accuracy: 0.8778 - val_categorical_accuracy: 0.5218 - val_loss: 1.5312 - val_top_3_categorical_accuracy: 0.8525 - val_w_categorical_accuracy: 0.5218 - val_w_top_3_categorical_accuracy: 0.8525 - learning_rate: 1.0000e-04
# Epoch 6/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7439 - loss: 0.8802 - top_3_categorical_accuracy: 0.9103 - w_categorical_accuracy: 0.7534 - w_top_3_categorical_accuracy: 0.8904
# Epoch 6: val_loss did not improve from 1.34804
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7439 - loss: 0.8802 - top_3_categorical_accuracy: 0.9103 - w_categorical_accuracy: 0.7534 - w_top_3_categorical_accuracy: 0.8904 - val_categorical_accuracy: 0.6881 - val_loss: 1.3607 - val_top_3_categorical_accuracy: 0.8611 - val_w_categorical_accuracy: 0.6881 - val_w_top_3_categorical_accuracy: 0.8611 - learning_rate: 1.0000e-04
# Epoch 7/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7411 - loss: 0.8661 - top_3_categorical_accuracy: 0.9149 - w_categorical_accuracy: 0.7431 - w_top_3_categorical_accuracy: 0.9055
# Epoch 7: val_loss improved from 1.34804 to 1.27890, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7411 - loss: 0.8661 - top_3_categorical_accuracy: 0.9149 - w_categorical_accuracy: 0.7431 - w_top_3_categorical_accuracy: 0.9055 - val_categorical_accuracy: 0.8045 - val_loss: 1.2789 - val_top_3_categorical_accuracy: 0.8674 - val_w_categorical_accuracy: 0.8045 - val_w_top_3_categorical_accuracy: 0.8674 - learning_rate: 1.0000e-04
# Epoch 8/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7997 - loss: 0.7423 - top_3_categorical_accuracy: 0.9171 - w_categorical_accuracy: 0.7784 - w_top_3_categorical_accuracy: 0.9154
# Epoch 8: val_loss improved from 1.27890 to 1.20050, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.7997 - loss: 0.7423 - top_3_categorical_accuracy: 0.9171 - w_categorical_accuracy: 0.7784 - w_top_3_categorical_accuracy: 0.9154 - val_categorical_accuracy: 0.8010 - val_loss: 1.2005 - val_top_3_categorical_accuracy: 0.8664 - val_w_categorical_accuracy: 0.8010 - val_w_top_3_categorical_accuracy: 0.8664 - learning_rate: 1.0000e-04
# Epoch 9/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7872 - loss: 0.7745 - top_3_categorical_accuracy: 0.9230 - w_categorical_accuracy: 0.7728 - w_top_3_categorical_accuracy: 0.9074
# Epoch 9: val_loss did not improve from 1.20050
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.7872 - loss: 0.7745 - top_3_categorical_accuracy: 0.9230 - w_categorical_accuracy: 0.7728 - w_top_3_categorical_accuracy: 0.9074 - val_categorical_accuracy: 0.8048 - val_loss: 1.2055 - val_top_3_categorical_accuracy: 0.8767 - val_w_categorical_accuracy: 0.8048 - val_w_top_3_categorical_accuracy: 0.8767 - learning_rate: 1.0000e-04
# Epoch 10/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7806 - loss: 0.6976 - top_3_categorical_accuracy: 0.9241 - w_categorical_accuracy: 0.7536 - w_top_3_categorical_accuracy: 0.9188
# Epoch 10: val_loss improved from 1.20050 to 1.11914, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.7806 - loss: 0.6976 - top_3_categorical_accuracy: 0.9241 - w_categorical_accuracy: 0.7536 - w_top_3_categorical_accuracy: 0.9188 - val_categorical_accuracy: 0.8069 - val_loss: 1.1191 - val_top_3_categorical_accuracy: 0.8730 - val_w_categorical_accuracy: 0.8069 - val_w_top_3_categorical_accuracy: 0.8730 - learning_rate: 1.0000e-04
# Epoch 11/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7861 - loss: 0.6612 - top_3_categorical_accuracy: 0.9280 - w_categorical_accuracy: 0.7793 - w_top_3_categorical_accuracy: 0.9201
# Epoch 11: val_loss improved from 1.11914 to 1.11381, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.7861 - loss: 0.6612 - top_3_categorical_accuracy: 0.9280 - w_categorical_accuracy: 0.7793 - w_top_3_categorical_accuracy: 0.9201 - val_categorical_accuracy: 0.7143 - val_loss: 1.1138 - val_top_3_categorical_accuracy: 0.8788 - val_w_categorical_accuracy: 0.7143 - val_w_top_3_categorical_accuracy: 0.8788 - learning_rate: 1.0000e-04
# Epoch 12/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.7852 - loss: 0.6092 - top_3_categorical_accuracy: 0.9309 - w_categorical_accuracy: 0.7852 - w_top_3_categorical_accuracy: 0.9318
# Epoch 12: val_loss improved from 1.11381 to 1.08192, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.7852 - loss: 0.6092 - top_3_categorical_accuracy: 0.9309 - w_categorical_accuracy: 0.7852 - w_top_3_categorical_accuracy: 0.9318 - val_categorical_accuracy: 0.8082 - val_loss: 1.0819 - val_top_3_categorical_accuracy: 0.8813 - val_w_categorical_accuracy: 0.8082 - val_w_top_3_categorical_accuracy: 0.8813 - learning_rate: 1.0000e-04
# Epoch 13/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8054 - loss: 0.6208 - top_3_categorical_accuracy: 0.9333 - w_categorical_accuracy: 0.7791 - w_top_3_categorical_accuracy: 0.9268
# Epoch 13: val_loss did not improve from 1.08192
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8054 - loss: 0.6208 - top_3_categorical_accuracy: 0.9333 - w_categorical_accuracy: 0.7791 - w_top_3_categorical_accuracy: 0.9268 - val_categorical_accuracy: 0.7149 - val_loss: 1.1046 - val_top_3_categorical_accuracy: 0.8819 - val_w_categorical_accuracy: 0.7149 - val_w_top_3_categorical_accuracy: 0.8819 - learning_rate: 1.0000e-04
# Epoch 14/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8009 - loss: 0.5681 - top_3_categorical_accuracy: 0.9342 - w_categorical_accuracy: 0.8047 - w_top_3_categorical_accuracy: 0.9320
# Epoch 14: val_loss improved from 1.08192 to 1.05709, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8009 - loss: 0.5681 - top_3_categorical_accuracy: 0.9342 - w_categorical_accuracy: 0.8047 - w_top_3_categorical_accuracy: 0.9320 - val_categorical_accuracy: 0.8318 - val_loss: 1.0571 - val_top_3_categorical_accuracy: 0.8852 - val_w_categorical_accuracy: 0.8318 - val_w_top_3_categorical_accuracy: 0.8852 - learning_rate: 1.0000e-04
# Epoch 15/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7993 - loss: 0.5687 - top_3_categorical_accuracy: 0.9326 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9488
# Epoch 15: val_loss improved from 1.05709 to 1.05007, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.7993 - loss: 0.5687 - top_3_categorical_accuracy: 0.9326 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9488 - val_categorical_accuracy: 0.8164 - val_loss: 1.0501 - val_top_3_categorical_accuracy: 0.8859 - val_w_categorical_accuracy: 0.8164 - val_w_top_3_categorical_accuracy: 0.8859 - learning_rate: 1.0000e-04
# Epoch 16/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8075 - loss: 0.5481 - top_3_categorical_accuracy: 0.9366 - w_categorical_accuracy: 0.8073 - w_top_3_categorical_accuracy: 0.9440
# Epoch 16: val_loss improved from 1.05007 to 1.00989, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8075 - loss: 0.5481 - top_3_categorical_accuracy: 0.9366 - w_categorical_accuracy: 0.8073 - w_top_3_categorical_accuracy: 0.9440 - val_categorical_accuracy: 0.8222 - val_loss: 1.0099 - val_top_3_categorical_accuracy: 0.8924 - val_w_categorical_accuracy: 0.8222 - val_w_top_3_categorical_accuracy: 0.8924 - learning_rate: 1.0000e-04
# Epoch 17/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8275 - loss: 0.4914 - top_3_categorical_accuracy: 0.9394 - w_categorical_accuracy: 0.8209 - w_top_3_categorical_accuracy: 0.9542
# Epoch 17: val_loss did not improve from 1.00989
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8275 - loss: 0.4914 - top_3_categorical_accuracy: 0.9394 - w_categorical_accuracy: 0.8209 - w_top_3_categorical_accuracy: 0.9542 - val_categorical_accuracy: 0.6425 - val_loss: 1.1093 - val_top_3_categorical_accuracy: 0.8865 - val_w_categorical_accuracy: 0.6425 - val_w_top_3_categorical_accuracy: 0.8865 - learning_rate: 1.0000e-04
# Epoch 18/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.7923 - loss: 0.5417 - top_3_categorical_accuracy: 0.9401 - w_categorical_accuracy: 0.7987 - w_top_3_categorical_accuracy: 0.9299
# Epoch 18: val_loss did not improve from 1.00989
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.7923 - loss: 0.5416 - top_3_categorical_accuracy: 0.9401 - w_categorical_accuracy: 0.7987 - w_top_3_categorical_accuracy: 0.9299 - val_categorical_accuracy: 0.8237 - val_loss: 1.0314 - val_top_3_categorical_accuracy: 0.8922 - val_w_categorical_accuracy: 0.8237 - val_w_top_3_categorical_accuracy: 0.8922 - learning_rate: 1.0000e-04
# Epoch 19/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8130 - loss: 0.5180 - top_3_categorical_accuracy: 0.9434 - w_categorical_accuracy: 0.8143 - w_top_3_categorical_accuracy: 0.9430
# Epoch 19: val_loss did not improve from 1.00989
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8130 - loss: 0.5180 - top_3_categorical_accuracy: 0.9434 - w_categorical_accuracy: 0.8143 - w_top_3_categorical_accuracy: 0.9430 - val_categorical_accuracy: 0.8048 - val_loss: 1.1750 - val_top_3_categorical_accuracy: 0.8917 - val_w_categorical_accuracy: 0.8048 - val_w_top_3_categorical_accuracy: 0.8917 - learning_rate: 1.0000e-04
# Epoch 20/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8752 - loss: 0.5125 - top_3_categorical_accuracy: 0.9437 - w_categorical_accuracy: 0.8284 - w_top_3_categorical_accuracy: 0.9530
# Epoch 20: val_loss did not improve from 1.00989
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8752 - loss: 0.5125 - top_3_categorical_accuracy: 0.9437 - w_categorical_accuracy: 0.8284 - w_top_3_categorical_accuracy: 0.9530 - val_categorical_accuracy: 0.8282 - val_loss: 1.0214 - val_top_3_categorical_accuracy: 0.8975 - val_w_categorical_accuracy: 0.8282 - val_w_top_3_categorical_accuracy: 0.8975 - learning_rate: 1.0000e-05
# Epoch 21/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8506 - loss: 0.4367 - top_3_categorical_accuracy: 0.9461 - w_categorical_accuracy: 0.8343 - w_top_3_categorical_accuracy: 0.9493
# Epoch 21: val_loss improved from 1.00989 to 1.00703, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8506 - loss: 0.4367 - top_3_categorical_accuracy: 0.9461 - w_categorical_accuracy: 0.8343 - w_top_3_categorical_accuracy: 0.9493 - val_categorical_accuracy: 0.8289 - val_loss: 1.0070 - val_top_3_categorical_accuracy: 0.8996 - val_w_categorical_accuracy: 0.8289 - val_w_top_3_categorical_accuracy: 0.8996 - learning_rate: 1.0000e-05
# Epoch 22/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8585 - loss: 0.4162 - top_3_categorical_accuracy: 0.9480 - w_categorical_accuracy: 0.8421 - w_top_3_categorical_accuracy: 0.9559
# Epoch 22: val_loss improved from 1.00703 to 0.98292, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8585 - loss: 0.4162 - top_3_categorical_accuracy: 0.9480 - w_categorical_accuracy: 0.8421 - w_top_3_categorical_accuracy: 0.9559 - val_categorical_accuracy: 0.8326 - val_loss: 0.9829 - val_top_3_categorical_accuracy: 0.9021 - val_w_categorical_accuracy: 0.8326 - val_w_top_3_categorical_accuracy: 0.9021 - learning_rate: 1.0000e-05
# Epoch 23/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8223 - loss: 0.4057 - top_3_categorical_accuracy: 0.9500 - w_categorical_accuracy: 0.8385 - w_top_3_categorical_accuracy: 0.9550
# Epoch 23: val_loss improved from 0.98292 to 0.96560, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8223 - loss: 0.4057 - top_3_categorical_accuracy: 0.9500 - w_categorical_accuracy: 0.8385 - w_top_3_categorical_accuracy: 0.9550 - val_categorical_accuracy: 0.8352 - val_loss: 0.9656 - val_top_3_categorical_accuracy: 0.9047 - val_w_categorical_accuracy: 0.8352 - val_w_top_3_categorical_accuracy: 0.9047 - learning_rate: 1.0000e-05
# Epoch 24/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8780 - loss: 0.4522 - top_3_categorical_accuracy: 0.9515 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9254
# Epoch 24: val_loss improved from 0.96560 to 0.95782, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8780 - loss: 0.4521 - top_3_categorical_accuracy: 0.9515 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9254 - val_categorical_accuracy: 0.8351 - val_loss: 0.9578 - val_top_3_categorical_accuracy: 0.9068 - val_w_categorical_accuracy: 0.8351 - val_w_top_3_categorical_accuracy: 0.9068 - learning_rate: 1.0000e-05
# Epoch 25/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8845 - loss: 0.3976 - top_3_categorical_accuracy: 0.9538 - w_categorical_accuracy: 0.8385 - w_top_3_categorical_accuracy: 0.9455
# Epoch 25: val_loss did not improve from 0.95782
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8845 - loss: 0.3976 - top_3_categorical_accuracy: 0.9538 - w_categorical_accuracy: 0.8385 - w_top_3_categorical_accuracy: 0.9455 - val_categorical_accuracy: 0.7352 - val_loss: 0.9786 - val_top_3_categorical_accuracy: 0.9073 - val_w_categorical_accuracy: 0.7352 - val_w_top_3_categorical_accuracy: 0.9073 - learning_rate: 1.0000e-05
# Epoch 26/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8687 - loss: 0.4425 - top_3_categorical_accuracy: 0.9532 - w_categorical_accuracy: 0.8312 - w_top_3_categorical_accuracy: 0.9515
# Epoch 26: val_loss improved from 0.95782 to 0.95022, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8687 - loss: 0.4425 - top_3_categorical_accuracy: 0.9532 - w_categorical_accuracy: 0.8312 - w_top_3_categorical_accuracy: 0.9515 - val_categorical_accuracy: 0.7382 - val_loss: 0.9502 - val_top_3_categorical_accuracy: 0.9087 - val_w_categorical_accuracy: 0.7382 - val_w_top_3_categorical_accuracy: 0.9087 - learning_rate: 1.0000e-05
# Epoch 27/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8271 - loss: 0.4019 - top_3_categorical_accuracy: 0.9555 - w_categorical_accuracy: 0.8495 - w_top_3_categorical_accuracy: 0.9588
# Epoch 27: val_loss did not improve from 0.95022
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8271 - loss: 0.4019 - top_3_categorical_accuracy: 0.9555 - w_categorical_accuracy: 0.8495 - w_top_3_categorical_accuracy: 0.9588 - val_categorical_accuracy: 0.8386 - val_loss: 0.9513 - val_top_3_categorical_accuracy: 0.9085 - val_w_categorical_accuracy: 0.8386 - val_w_top_3_categorical_accuracy: 0.9085 - learning_rate: 1.0000e-05
# Epoch 28/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8852 - loss: 0.4157 - top_3_categorical_accuracy: 0.9557 - w_categorical_accuracy: 0.8305 - w_top_3_categorical_accuracy: 0.9550
# Epoch 28: val_loss did not improve from 0.95022
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8852 - loss: 0.4157 - top_3_categorical_accuracy: 0.9557 - w_categorical_accuracy: 0.8305 - w_top_3_categorical_accuracy: 0.9550 - val_categorical_accuracy: 0.7397 - val_loss: 0.9553 - val_top_3_categorical_accuracy: 0.9084 - val_w_categorical_accuracy: 0.7397 - val_w_top_3_categorical_accuracy: 0.9084 - learning_rate: 1.0000e-05
# Epoch 29/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8705 - loss: 0.3927 - top_3_categorical_accuracy: 0.9561 - w_categorical_accuracy: 0.8527 - w_top_3_categorical_accuracy: 0.9542
# Epoch 29: val_loss improved from 0.95022 to 0.94295, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8705 - loss: 0.3927 - top_3_categorical_accuracy: 0.9561 - w_categorical_accuracy: 0.8526 - w_top_3_categorical_accuracy: 0.9542 - val_categorical_accuracy: 0.8388 - val_loss: 0.9430 - val_top_3_categorical_accuracy: 0.9091 - val_w_categorical_accuracy: 0.8388 - val_w_top_3_categorical_accuracy: 0.9091 - learning_rate: 1.0000e-05
# Epoch 30/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8772 - loss: 0.4304 - top_3_categorical_accuracy: 0.9550 - w_categorical_accuracy: 0.8330 - w_top_3_categorical_accuracy: 0.9485
# Epoch 30: val_loss did not improve from 0.94295
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8772 - loss: 0.4304 - top_3_categorical_accuracy: 0.9550 - w_categorical_accuracy: 0.8330 - w_top_3_categorical_accuracy: 0.9485 - val_categorical_accuracy: 0.8412 - val_loss: 0.9461 - val_top_3_categorical_accuracy: 0.9096 - val_w_categorical_accuracy: 0.8412 - val_w_top_3_categorical_accuracy: 0.9096 - learning_rate: 1.0000e-05
# Epoch 31/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8724 - loss: 0.4017 - top_3_categorical_accuracy: 0.9550 - w_categorical_accuracy: 0.8412 - w_top_3_categorical_accuracy: 0.9623
# Epoch 31: val_loss improved from 0.94295 to 0.93320, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8724 - loss: 0.4017 - top_3_categorical_accuracy: 0.9550 - w_categorical_accuracy: 0.8412 - w_top_3_categorical_accuracy: 0.9623 - val_categorical_accuracy: 0.8419 - val_loss: 0.9332 - val_top_3_categorical_accuracy: 0.9117 - val_w_categorical_accuracy: 0.8419 - val_w_top_3_categorical_accuracy: 0.9117 - learning_rate: 1.0000e-05
# Epoch 32/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8882 - loss: 0.3967 - top_3_categorical_accuracy: 0.9560 - w_categorical_accuracy: 0.8418 - w_top_3_categorical_accuracy: 0.9613
# Epoch 32: val_loss improved from 0.93320 to 0.93298, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8882 - loss: 0.3967 - top_3_categorical_accuracy: 0.9560 - w_categorical_accuracy: 0.8418 - w_top_3_categorical_accuracy: 0.9613 - val_categorical_accuracy: 0.8407 - val_loss: 0.9330 - val_top_3_categorical_accuracy: 0.9099 - val_w_categorical_accuracy: 0.8407 - val_w_top_3_categorical_accuracy: 0.9099 - learning_rate: 1.0000e-05
# Epoch 33/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8676 - loss: 0.4018 - top_3_categorical_accuracy: 0.9560 - w_categorical_accuracy: 0.8472 - w_top_3_categorical_accuracy: 0.9522
# Epoch 33: val_loss did not improve from 0.93298
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8676 - loss: 0.4018 - top_3_categorical_accuracy: 0.9560 - w_categorical_accuracy: 0.8472 - w_top_3_categorical_accuracy: 0.9522 - val_categorical_accuracy: 0.8416 - val_loss: 0.9504 - val_top_3_categorical_accuracy: 0.9111 - val_w_categorical_accuracy: 0.8416 - val_w_top_3_categorical_accuracy: 0.9111 - learning_rate: 1.0000e-05
# Epoch 34/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8659 - loss: 0.4156 - top_3_categorical_accuracy: 0.9551 - w_categorical_accuracy: 0.8288 - w_top_3_categorical_accuracy: 0.9576
# Epoch 34: val_loss did not improve from 0.93298
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8659 - loss: 0.4156 - top_3_categorical_accuracy: 0.9551 - w_categorical_accuracy: 0.8288 - w_top_3_categorical_accuracy: 0.9576 - val_categorical_accuracy: 0.8429 - val_loss: 0.9416 - val_top_3_categorical_accuracy: 0.9120 - val_w_categorical_accuracy: 0.8429 - val_w_top_3_categorical_accuracy: 0.9120 - learning_rate: 1.0000e-05
# Epoch 35/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8640 - loss: 0.3731 - top_3_categorical_accuracy: 0.9578 - w_categorical_accuracy: 0.8616 - w_top_3_categorical_accuracy: 0.9633
# Epoch 35: val_loss improved from 0.93298 to 0.92326, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8640 - loss: 0.3731 - top_3_categorical_accuracy: 0.9578 - w_categorical_accuracy: 0.8616 - w_top_3_categorical_accuracy: 0.9633 - val_categorical_accuracy: 0.8437 - val_loss: 0.9233 - val_top_3_categorical_accuracy: 0.9129 - val_w_categorical_accuracy: 0.8437 - val_w_top_3_categorical_accuracy: 0.9129 - learning_rate: 1.0000e-05
# Epoch 36/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8670 - loss: 0.3962 - top_3_categorical_accuracy: 0.9582 - w_categorical_accuracy: 0.8383 - w_top_3_categorical_accuracy: 0.9540
# Epoch 36: val_loss improved from 0.92326 to 0.92091, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8670 - loss: 0.3962 - top_3_categorical_accuracy: 0.9582 - w_categorical_accuracy: 0.8383 - w_top_3_categorical_accuracy: 0.9540 - val_categorical_accuracy: 0.8447 - val_loss: 0.9209 - val_top_3_categorical_accuracy: 0.9132 - val_w_categorical_accuracy: 0.8447 - val_w_top_3_categorical_accuracy: 0.9132 - learning_rate: 1.0000e-05
# Epoch 37/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8820 - loss: 0.4031 - top_3_categorical_accuracy: 0.9596 - w_categorical_accuracy: 0.8306 - w_top_3_categorical_accuracy: 0.9674
# Epoch 37: val_loss did not improve from 0.92091
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 142s 37ms/step - categorical_accuracy: 0.8820 - loss: 0.4031 - top_3_categorical_accuracy: 0.9596 - w_categorical_accuracy: 0.8306 - w_top_3_categorical_accuracy: 0.9674 - val_categorical_accuracy: 0.7416 - val_loss: 0.9856 - val_top_3_categorical_accuracy: 0.9122 - val_w_categorical_accuracy: 0.7416 - val_w_top_3_categorical_accuracy: 0.9122 - learning_rate: 1.0000e-05
# Epoch 38/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8162 - loss: 0.3847 - top_3_categorical_accuracy: 0.9576 - w_categorical_accuracy: 0.8450 - w_top_3_categorical_accuracy: 0.9657
# Epoch 38: val_loss did not improve from 0.92091
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8162 - loss: 0.3847 - top_3_categorical_accuracy: 0.9576 - w_categorical_accuracy: 0.8450 - w_top_3_categorical_accuracy: 0.9657 - val_categorical_accuracy: 0.8445 - val_loss: 0.9661 - val_top_3_categorical_accuracy: 0.9133 - val_w_categorical_accuracy: 0.8445 - val_w_top_3_categorical_accuracy: 0.9133 - learning_rate: 1.0000e-05
# Epoch 39/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8677 - loss: 0.3800 - top_3_categorical_accuracy: 0.9637 - w_categorical_accuracy: 0.8463 - w_top_3_categorical_accuracy: 0.9663
# Epoch 39: val_loss improved from 0.92091 to 0.91917, saving model to saves/baseline/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8677 - loss: 0.3800 - top_3_categorical_accuracy: 0.9637 - w_categorical_accuracy: 0.8463 - w_top_3_categorical_accuracy: 0.9663 - val_categorical_accuracy: 0.8465 - val_loss: 0.9192 - val_top_3_categorical_accuracy: 0.9137 - val_w_categorical_accuracy: 0.8465 - val_w_top_3_categorical_accuracy: 0.9137 - learning_rate: 1.0000e-05
# Epoch 40/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8808 - loss: 0.3933 - top_3_categorical_accuracy: 0.9597 - w_categorical_accuracy: 0.8339 - w_top_3_categorical_accuracy: 0.9417
# Epoch 40: val_loss did not improve from 0.91917
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8808 - loss: 0.3933 - top_3_categorical_accuracy: 0.9597 - w_categorical_accuracy: 0.8339 - w_top_3_categorical_accuracy: 0.9417 - val_categorical_accuracy: 0.7463 - val_loss: 0.9438 - val_top_3_categorical_accuracy: 0.9143 - val_w_categorical_accuracy: 0.7463 - val_w_top_3_categorical_accuracy: 0.9143 - learning_rate: 1.0000e-05
# Epoch 41/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8508 - loss: 0.4002 - top_3_categorical_accuracy: 0.9602 - w_categorical_accuracy: 0.8349 - w_top_3_categorical_accuracy: 0.9567
# Epoch 41: val_loss did not improve from 0.91917
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8508 - loss: 0.4002 - top_3_categorical_accuracy: 0.9602 - w_categorical_accuracy: 0.8349 - w_top_3_categorical_accuracy: 0.9567 - val_categorical_accuracy: 0.8459 - val_loss: 0.9292 - val_top_3_categorical_accuracy: 0.9153 - val_w_categorical_accuracy: 0.8459 - val_w_top_3_categorical_accuracy: 0.9153 - learning_rate: 1.0000e-05
# Epoch 42/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8351 - loss: 0.3511 - top_3_categorical_accuracy: 0.9577 - w_categorical_accuracy: 0.8559 - w_top_3_categorical_accuracy: 0.9639
# Epoch 42: val_loss did not improve from 0.91917
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 36ms/step - categorical_accuracy: 0.8351 - loss: 0.3511 - top_3_categorical_accuracy: 0.9577 - w_categorical_accuracy: 0.8558 - w_top_3_categorical_accuracy: 0.9639 - val_categorical_accuracy: 0.8476 - val_loss: 0.9272 - val_top_3_categorical_accuracy: 0.9149 - val_w_categorical_accuracy: 0.8476 - val_w_top_3_categorical_accuracy: 0.9149 - learning_rate: 1.0000e-05
# Epoch 43/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.8982 - loss: 0.3553 - top_3_categorical_accuracy: 0.9602 - w_categorical_accuracy: 0.8622 - w_top_3_categorical_accuracy: 0.9632
# Epoch 43: val_loss did not improve from 0.91917
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 141s 37ms/step - categorical_accuracy: 0.8982 - loss: 0.3553 - top_3_categorical_accuracy: 0.9602 - w_categorical_accuracy: 0.8622 - w_top_3_categorical_accuracy: 0.9632 - val_categorical_accuracy: 0.8477 - val_loss: 0.9319 - val_top_3_categorical_accuracy: 0.9149 - val_w_categorical_accuracy: 0.8477 - val_w_top_3_categorical_accuracy: 0.9149 - learning_rate: 1.0000e-06
# Epoch 44/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - categorical_accuracy: 0.8949 - loss: 0.3731 - top_3_categorical_accuracy: 0.9610 - w_categorical_accuracy: 0.8548 - w_top_3_categorical_accuracy: 0.9657
# Epoch 44: val_loss did not improve from 0.91917
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 140s 36ms/step - categorical_accuracy: 0.8949 - loss: 0.3731 - top_3_categorical_accuracy: 0.9610 - w_categorical_accuracy: 0.8548 - w_top_3_categorical_accuracy: 0.9657 - val_categorical_accuracy: 0.8476 - val_loss: 0.9312 - val_top_3_categorical_accuracy: 0.9148 - val_w_categorical_accuracy: 0.8476 - val_w_top_3_categorical_accuracy: 0.9148 - learning_rate: 1.0000e-06
# Epoch 44: early stopping

# %%
log = pd.read_csv(log_path)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20*cm, 15*cm))

ax1.plot(log['epoch'], log['categorical_accuracy'], label='categorical_accuracy', color='red')
ax1.plot(log['epoch'], log['val_categorical_accuracy'], label='val_categorical_accuracy', color='orange')
ax1.plot(log['epoch'], log[f'top_{top_k}_categorical_accuracy'], label=f'top_{top_k}_categorical_accuracy', color='royalblue')
ax1.plot(log['epoch'], log[f'val_top_{top_k}_categorical_accuracy'], label=f'val_top_{top_k}_categorical_accuracy', color='navy')
ax1.set_title('training metrics')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1)  # Legend below the plot

ax2.plot(log['epoch'], log['loss'], label='loss')
ax2.plot(log['epoch'], log['val_loss'], label='val_loss')
ax2.set_title('loss')
ax2.set_xlabel('epoch')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)  # Legend below the plot

fig.tight_layout(rect=[0, 0.1, 1, 1])

plt.savefig(f'{checkpoint_path}/metrics_loss.svg')
plt.show()

# %%
# load old model, if needed
if model is None:
    model = load_model(model_path)

# %%
# evaluate model
score = model.evaluate(x=Generator(X_test, y_test, 128, max_sequence_length))
print(f'Test loss: {score[0]}')
print(f'Test accuracy: {score[1]}')
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - categorical_accuracy: 0.8818 - loss: 0.5472 - top_3_categorical_accuracy: 0.9554 - w_categorical_accuracy: 0.8818 - w_top_3_categorical_accuracy: 0.9554
# Test loss: 0.5466451048851013
# Test accuracy: 0.8844366669654846

# %%
# print classification report
y_pred = model.predict(x=Generator(X_test, y_test, 128, max_sequence_length))
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

report = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan)
report_dict = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan, output_dict=True)

print(report)

# save classification report to file
with open(f'{checkpoint_path}/classification_report.txt', 'w') as f:
    json.dump(report_dict, f)
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step
#                  precision    recall  f1-score   support
#
#       adjkerntz        nan      0.00      0.00        11
#          alpine       0.56      0.86      0.68       560
#           anvil       0.32      0.73      0.44       378
#           atrun       1.00      1.00      1.00       237
#             awk       1.00      1.00      1.00         5
#        basename        nan      0.00      0.00         2
#            bash       0.95      0.96      0.95     12512
#             cat       0.74      0.96      0.83        26
#         cleanup       0.42      0.67      0.52       276
#             cmp       1.00      1.00      1.00         5
#              cp       0.91      1.00      0.95        30
#            cron       1.00      1.00      1.00       624
#            date       1.00      1.00      1.00      1218
#              dd       1.00      0.99      1.00       125
#        dhclient       0.00      0.06      0.00        17
#           dmesg       1.00      1.00      1.00        15
#           egrep       0.50      0.50      0.50         2
#            expr        nan      0.00      0.00         2
#            find       1.00      0.99      1.00      4006
#         fortune       1.00      1.00      1.00        91
#            grep       0.02      0.60      0.04         5
#            head       1.00      1.00      1.00      1219
#        hostname       0.62      1.00      0.77        10
#           imapd       0.86      0.56      0.68      2469
#           inetd       1.00      1.00      1.00       291
#            kill       1.00      1.00      1.00         2
#            less       0.08      0.67      0.14         3
#           local       0.77      0.57      0.66       868
#           lockf       1.00      0.67      0.80         3
#              ls       0.24      0.50      0.32        12
#            lsof       0.98      0.96      0.97      8568
#            mail       0.17      0.50      0.25         2
#     mailwrapper       1.00      0.67      0.80         3
#          master       0.27      1.00      0.42       580
#           mkdir       1.00      1.00      1.00        18
#          mktemp       0.86      1.00      0.92         6
#           mlock       1.00      1.00      1.00       506
#           mount       0.33      1.00      0.50         2
#              mv       1.00      1.00      1.00       860
#         netstat       0.96      0.79      0.87        58
#       newsyslog       0.46      0.89      0.60        18
#          pickup       0.96      0.83      0.89       143
#             pkg       0.97      0.68      0.80      1701
#        proxymap       0.68      0.50      0.57       331
#              ps       0.31      1.00      0.48         5
#       python2.7       0.00      0.00      0.00       841
#       resizewin       1.00      1.00      1.00        91
#              rm       0.44      0.31      0.36        36
#           route       1.00      1.00      1.00         7
#             sed       0.00      0.00      0.00         2
#        sendmail       0.35      0.86      0.50        21
#              sh       0.98      0.28      0.43      1987
#           sleep       1.00      1.00      1.00      4889
#           smtpd       0.86      0.91      0.88       818
#            sort       0.33      1.00      0.50         1
#            sshd       0.99      1.00      0.99       427
#            sudo       0.47      0.92      0.62        26
#          sysctl       1.00      1.00      1.00       129
#             tee       0.29      0.83      0.43         6
#             top       1.00      0.99      1.00      1913
# trivial-rewrite       0.65      0.51      0.57       377
#             tty        nan      0.00      0.00         2
#          unlink       0.90      1.00      0.95       123
#          uptime       1.00      1.00      1.00        14
#          vmstat       1.00      1.00      1.00      2468
#              wc       0.47      1.00      0.64         7
#            wget       0.52      0.77      0.62        74
#
#        accuracy                           0.88     52084
#       macro avg       0.72      0.77      0.68     52084
#    weighted avg       0.92      0.88      0.89     52084

# %%
# print confusion matrix
# labels explicitly set, because current model may not predict all labels
conf_matrix = confusion_matrix(y_true, y_pred, labels=range(labels_cardinality), normalize='true')

# Replace all NaN values with 0
conf_matrix = np.nan_to_num(conf_matrix)

# Verify the distinct labels align correctly
distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(20*cm, 20*cm))

ax.matshow(conf_matrix, cmap='cividis', aspect='auto')

# Set class names on axes
ax.set_xticks(range(len(distinct_labels)))
ax.set_yticks(range(len(distinct_labels)))
ax.set_xticklabels(distinct_labels, rotation=90, fontsize=8)
ax.set_yticklabels(distinct_labels, fontsize=8)

# Set axis labels "predicted" and "actual"
ax.set_xlabel('predicted label')
ax.set_ylabel('true label')
# y-axis label right side
ax.yaxis.set_label_position('right')

# set figsize
plt.savefig(f'{checkpoint_path}/confusion_matrix.svg')
plt.show()

# %%
unique_in_y_pred = [ labels_map[i] for i in np.unique(y_pred) ]
#print("Unique labels in y_pred:", unique_in_y_pred)

unique_not_in_y_pred = [ label for label in distinct_labels if label not in unique_in_y_pred ]
print("Unique labels not in y_pred:", unique_not_in_y_pred)
# Out:
# Unique labels not in y_pred: ['adjkerntz', 'basename', 'expr', 'tty']
