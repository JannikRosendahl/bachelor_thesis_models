# %%
import os
import re
from collections import Counter
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cm = 1/2.54

# force GPU device
os.environ["CUDA_VISIBLE_DEVICES"]='1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

from keras.src.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.src.layers import SimpleRNN, LSTM, Dense, Dropout, Bidirectional
from keras import Sequential, Input
from keras.losses import CategoricalCrossentropy, CategoricalFocalCrossentropy
from keras.optimizers import Adam
from keras.models import load_model
from keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

from utils import *

# %%
max_sequence_length = 100
experiment_name = 'feature_obj_type_sizeincr'
top_k = 3

# %%
checkpoint_path = f'saves/{experiment_name}'
model_path = f'{checkpoint_path}/model.keras'
log_path = f'{checkpoint_path}/log.csv'
history_path = f'{checkpoint_path}/history.npy'

# ensure directory exists
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# %%
data_directory = '/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
unusable_threshold = 10
rare_threshold = 50
splits = (0.7, 0.15, 0.15)

max_sequence_length = 100

assert(sum(splits) == 1)

print(f'experiment parameters: \n{data_directory=} \n{unusable_threshold=} \n{rare_threshold=} \n{splits=} \n{max_sequence_length=}')
# Out:
# experiment parameters:
# data_directory='/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
# unusable_threshold=10
# rare_threshold=50
# splits=(0.7, 0.15, 0.15)
# max_sequence_length=100

# %%
total_classes = 0

# unusable classes will be removed from the dataset
unusable_classes = []
# rare classes will be oversampled
rare_classes = []

# all classes in training data (all classes - unusable classes)
classes = []

# walk all files, build unusable_classes, rare_classes
classes_occurrences = Counter()
for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    classes_occurrences[label] += 1

total_classes = len(classes_occurrences)
for label, count in classes_occurrences.items():
    if count < unusable_threshold:
        unusable_classes.append(label)
    elif count < rare_threshold:
        rare_classes.append(label)
        classes.append(label)
    else:
        classes.append(label)

print(f'Total classes: {total_classes}')
print(f'Unusable classes: {len(unusable_classes)}')
print(f'\t{unusable_classes}')
print(f'Rare classes: {len(rare_classes)}')
print(f'\t{rare_classes}')

labels_cardinality = len(set(classes))
print(f'Usable classes: {labels_cardinality}')
# Out:
# Total classes: 118
# Unusable classes: 51
# 	['ping', 'pwd_mkdb', 'vi', 'tr', 'uname', 'msgs', 'screen', 'pw', 'bzip2', 'bzcat', 'nginx', 'stat', 'tail', 'smtp', 'kenv', 'nawk', 'ssh', 'chown', 'cut', 'php-fpm', 'jot', 'xz', 'diff', 'bounce', 'links', 'ipfw', 'touch', 'env', 'pfctl', 'minions', 'csh', 'kldstat', 'su', 'nohup', 'stty', 'df', 'limits', 'id', 'postmap', 'ifconfig', 'chkgrp', 'ipfstat', 'locale', 'devd', 'uniq', 'XIM', 'getty', 'which', 'init', 'test', 'nice']
# Rare classes: 20
# 	['wc', 'grep', 'mktemp', 'less', 'tty', 'mailwrapper', 'kill', 'lockf', 'mount', 'tee', 'expr', 'ps', 'route', 'sed', 'cmp', 'egrep', 'sort', 'basename', 'awk', 'mail']
# Usable classes: 67

# %%
# split into train, validation, test
labels_set = set()

filenames_all = []

filenames_train = []
filenames_val = []
filenames_test = []

for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    if label in unusable_classes:
        continue
    labels_set.add(label)
    filenames_all.append(filename)

# stratisfied split
test_vs_val = splits[2] / (splits[1] + splits[2])
filenames_train, filenames_val_test = train_test_split(filenames_all, test_size=splits[1]+splits[2], stratify=[class_from_filename(f) for f in filenames_all])
filenames_val, filenames_test = train_test_split(filenames_val_test, test_size=test_vs_val, stratify=[class_from_filename(f) for f in filenames_val_test])

print(f'Train: {len(filenames_train)}')
print(f'Validation: {len(filenames_val)}')
print(f'Test: {len(filenames_test)}')

# build labels_map in alphabetical order
labels_map = {}
for i, label in enumerate(sorted(labels_set)):
    labels_map[label] = i
# Out:
# Train: 150475
# Validation: 32245
# Test: 32245

# %%
# load data
count_files_read = 0
count_sequences_split = 0
count_splits = 0

preprocessor = Preprocessor(['TYPE', 'PRED_OBJ_TYPES'])

def parse_file(filename) -> tuple[list[int], list[list[int]]]:
    """
    Parse a file and return the vectorized data. Not a pure function (calls parse_line)!
    """
    global count_files_read, count_sequences_split, count_splits

    y_list: list[int] = []
    X_list: list[list[int]] = []
    y = class_from_filename(filename)
    y = labels_map[y]
    with open(os.path.join(data_directory, filename), 'r') as f:
        lines = f.readlines()
        count_files_read += 1
    if count_files_read % 50000 == 0:
        print(f'Files read: {count_files_read}')
    X = []
    for line in lines:
        line_res = preprocessor.process(line)
        event = line_res['TYPE']
        ob1_type = line_res['PRED_OBJ1_TYPE']
        ob2_type = line_res['PRED_OBJ2_TYPE']
        X.append((event, ob1_type, ob2_type))

    # check if sequence needs to be split
    if len(X) > max_sequence_length:
        count_sequences_split += 1
        count_splits += len(X) // max_sequence_length
        for i in range(0, len(X), max_sequence_length):
            y_list.append(y)
            X_list.append(X[i:i+max_sequence_length])
        assert len(X_list[0]) == max_sequence_length
    else:
        y_list.append(y)
        X_list.append(X)

    # transform elements to numpy arrays
    y_list = np.array(y_list)
    X_list = [np.array(x) for x in X_list]

    assert len(y_list) == len(X_list)
    return y_list, X_list


y_train = []
X_train = []
y_val = []
X_val = []
y_test = []
X_test = []

for filename in filenames_train:
    try:
        y_list, X_list = parse_file(filename)
    except Exception as e:
        print(f'Error parsing file: {filename}')
        raise e
    y_train.extend(y_list)
    X_train.extend(X_list)

for filename in filenames_val:
    y_list, X_list = parse_file(filename)
    y_val.extend(y_list)
    X_val.extend(X_list)

for filename in filenames_test:
    y_list, X_list = parse_file(filename)
    y_test.extend(y_list)
    X_test.extend(X_list)

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)

print(f'Files read: {count_files_read}')
print(f'Sequences split: {count_sequences_split}')
print(f'Splits: {count_splits}')


event_types_map = preprocessor.event_types_map
filetypes_map = preprocessor.filetypes_map

event_types_cardinality = len(event_types_map)
filetypes_cardinality = len(filetypes_map)

print(f'Event types: {event_types_cardinality}')
print(f'Filetypes: {filetypes_cardinality}')


# print lengths
print(f'Train: {len(y_train)}')
print(f'Validation: {len(y_val)}')
print(f'Test: {len(y_test)}')
# Out:
# Files read: 50000
# Files read: 100000
# Files read: 150000
# Files read: 200000
# Files read: 214965
# Sequences split: 22897
# Splits: 132960
# Event types: 29
# Filetypes: 7
# Train: 247249
# Validation: 48541
# Test: 52084

# %%
# debug print all maps (sorted)
print('Event types:')
for k, v in sorted(event_types_map.items(), key=lambda x: x[1]):
    print(f'{v}: {k}', end=', ')
print()

print('Filetypes:')
for k, v in sorted(filetypes_map.items(), key=lambda x: x[1]):
    print(f'{v}: {k}', end=', ')
print()
# Out:
# Event types:
# 0: EVENT_EXECUTE, 1: EVENT_OPEN, 2: EVENT_READ, 3: EVENT_CLOSE, 4: EVENT_MMAP, 5: EVENT_WRITE, 6: EVENT_EXIT, 7: EVENT_CONNECT, 8: EVENT_SENDTO, 9: EVENT_LSEEK, 10: EVENT_CHANGE_PRINCIPAL, 11: EVENT_LOGIN, 12: EVENT_MODIFY_PROCESS, 13: EVENT_FCNTL, 14: EVENT_RECVFROM, 15: EVENT_MPROTECT, 16: EVENT_CREATE_OBJECT, 17: EVENT_ACCEPT, 18: EVENT_UNLINK, 19: EVENT_FORK, 20: EVENT_MODIFY_FILE_ATTRIBUTES, 21: EVENT_LINK, 22: EVENT_RENAME, 23: EVENT_TRUNCATE, 24: EVENT_SIGNAL, 25: EVENT_OTHER, 26: EVENT_SENDMSG, 27: EVENT_RECVMSG, 28: EVENT_BIND,
# Filetypes:
# 0: None, 1: FILE_OBJECT_FILE, 2: SUBJECT_PROCESS, 3: UNNAMEDPIPE, 4: FILE_OBJECT_UNIX_SOCKET, 5: FILE_OBJECT_DIR, 6: NETFLOW,

# %%
# turn labels map into bidirectional map
for k, v in labels_map.copy().items():
    labels_map[v] = k

# turn feature maps into bidirectional maps
for k, v in event_types_map.copy().items():
    event_types_map[v] = k

for k, v in filetypes_map.copy().items():
    filetypes_map[v] = k

# %%
# print distributions in all 3 sets
train_distribution = Counter(y_train)
val_distribution = Counter(y_val)
test_distribution = Counter(y_test)

# plot 3 pie plots, use same colors for same classes
colors = plt.cm.tab20.colors
colors = [ colors[i % 20] for i in range(labels_cardinality) ]

# sort labels by occurence in training set
sorted_labels = sorted(train_distribution, key=train_distribution.get, reverse=True)

# sort all distributions by sorted_labels
train_distribution = [train_distribution[label] for label in sorted_labels]
val_distribution = [val_distribution[label] for label in sorted_labels]
test_distribution = [test_distribution[label] for label in sorted_labels]

# transform labels to names
sorted_labels = [labels_map[label] for label in sorted_labels]

fig, axs = plt.subplots(1, 3, figsize=(30*cm, 10*cm))
axs[0].pie(train_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[0].set_title('Train')
axs[1].pie(val_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[1].set_title('Validation')
axs[2].pie(test_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[2].set_title('Test')
plt.savefig(f'{checkpoint_path}/distributions.png')
plt.show()

# %%
# one-hot encode labels
y_train = np.eye(labels_cardinality)[y_train]
y_val = np.eye(labels_cardinality)[y_val]
y_test = np.eye(labels_cardinality)[y_test]

# %%
# one-hot encode features
# at this point, X_* are lists of tuples of vectorized features
def encode_features(sequence: np.ndarray) -> np.ndarray:
    # Precompute identity matrices
    event_eye = np.eye(event_types_cardinality)
    filetype_eye = np.eye(filetypes_cardinality)

    # Initialize the output array with precomputed shapes
    encoded_seq = np.empty((len(sequence), event_eye.shape[1] + (2* filetype_eye.shape[1])))

    for i, feature_vector in enumerate(sequence):
        event = event_eye[feature_vector[0]]
        ob1_type = filetype_eye[feature_vector[1]]
        ob2_type = filetype_eye[feature_vector[2]]

        # Concatenate all features into a single feature vector
        encoded_seq[i] = np.concatenate((event, ob1_type, ob2_type))

    return encoded_seq

X_train = [ encode_features(x) for x in X_train ]
X_val = [ encode_features(x) for x in X_val ]
X_test = [ encode_features(x) for x in X_test ]

# %%
feature_vector_cardinality = X_train[0].shape[1]

print(f'Feature vector cardinality: {feature_vector_cardinality}')
# Out:
# Feature vector cardinality: 43

# %%
X_train, y_train = shuffle(X_train, y_train)
X_val, y_val = shuffle(X_val, y_val)
X_test, y_test = shuffle(X_test, y_test)

# %% [markdown]
# build model

# %%
model = Sequential(layers=[
    Input(shape=(None, feature_vector_cardinality)),
    SimpleRNN(128, return_sequences=True),
    SimpleRNN(128, return_sequences=True),
    SimpleRNN(128, return_sequences=False),
    Dense(labels_cardinality, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_3 (SimpleRNN)        │ (None, None, 64)       │         6,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_4 (SimpleRNN)        │ (None, None, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_5 (SimpleRNN)        │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 67)             │         4,355 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,779 (108.51 KB)
#  Trainable params: 27,779 (108.51 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=7,
        verbose=1,
        mode='auto'
    ),
    ModelCheckpoint(
        filepath=model_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        verbose=1,
        mode='auto',
        min_lr=1e-7
    ),
    CSVLogger(
        filename=log_path,
        append=True
    )
]

loss = CategoricalCrossentropy()
optimizer = Adam(learning_rate=0.0001)

# class weights
y_train_int = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)
class_weights_dict = dict(enumerate(class_weights))

metrics = [
    CategoricalAccuracy(name='categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'top_{top_k}_categorical_accuracy'),
]

weighted_metrics = [
    CategoricalAccuracy(name='w_categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'w_top_{top_k}_categorical_accuracy'),
]

# 'categorical_focal_crossentropy'
# 'categorical_crossentropy'
model.compile(
    loss=loss,
    optimizer=optimizer,
    metrics=metrics,
    weighted_metrics=weighted_metrics,
)

# %% [markdown]
# train model

# %%
history = model.fit(
    x=Generator(X_train, y_train, 64, max_sequence_length),
    validation_data=Generator(X_val, y_val, 64, max_sequence_length),
    epochs=200,
    callbacks=callbacks,
    class_weight=class_weights_dict
)

# save history to file
with open(history_path, 'wb') as f:
    np.save(f, history.history)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723911622.379820 2598147 service.cc:145] XLA service 0x21b32c90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1723911622.379909 2598147 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
#    5/3864 ━━━━━━━━━━━━━━━━━━━━ 2:00 31ms/step - categorical_accuracy: 6.2500e-04 - loss: 14.3372 - top_3_categorical_accuracy: 0.0037 - w_categorical_accuracy: 6.3736e-04 - w_top_3_categorical_accuracy: 0.0015
# I0000 00:00:1723911623.731129 2598147 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.4260 - loss: 3.5333 - top_3_categorical_accuracy: 0.5733 - w_categorical_accuracy: 0.2517 - w_top_3_categorical_accuracy: 0.3805
# Epoch 1: val_loss improved from inf to 1.71546, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 139s 35ms/step - categorical_accuracy: 0.4260 - loss: 3.5331 - top_3_categorical_accuracy: 0.5733 - w_categorical_accuracy: 0.2517 - w_top_3_categorical_accuracy: 0.3805 - val_categorical_accuracy: 0.7313 - val_loss: 1.7155 - val_top_3_categorical_accuracy: 0.8267 - val_w_categorical_accuracy: 0.7313 - val_w_top_3_categorical_accuracy: 0.8267 - learning_rate: 1.0000e-04
# Epoch 2/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7953 - loss: 1.9705 - top_3_categorical_accuracy: 0.8799 - w_categorical_accuracy: 0.5875 - w_top_3_categorical_accuracy: 0.7394
# Epoch 2: val_loss improved from 1.71546 to 1.54616, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.7953 - loss: 1.9705 - top_3_categorical_accuracy: 0.8799 - w_categorical_accuracy: 0.5875 - w_top_3_categorical_accuracy: 0.7394 - val_categorical_accuracy: 0.6068 - val_loss: 1.5462 - val_top_3_categorical_accuracy: 0.8546 - val_w_categorical_accuracy: 0.6068 - val_w_top_3_categorical_accuracy: 0.8546 - learning_rate: 1.0000e-04
# Epoch 3/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7861 - loss: 1.5042 - top_3_categorical_accuracy: 0.9029 - w_categorical_accuracy: 0.6738 - w_top_3_categorical_accuracy: 0.8478
# Epoch 3: val_loss improved from 1.54616 to 1.15293, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7861 - loss: 1.5041 - top_3_categorical_accuracy: 0.9029 - w_categorical_accuracy: 0.6738 - w_top_3_categorical_accuracy: 0.8478 - val_categorical_accuracy: 0.7794 - val_loss: 1.1529 - val_top_3_categorical_accuracy: 0.8613 - val_w_categorical_accuracy: 0.7794 - val_w_top_3_categorical_accuracy: 0.8613 - learning_rate: 1.0000e-04
# Epoch 4/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.7959 - loss: 1.1324 - top_3_categorical_accuracy: 0.9207 - w_categorical_accuracy: 0.7293 - w_top_3_categorical_accuracy: 0.8825
# Epoch 4: val_loss improved from 1.15293 to 1.11099, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.7959 - loss: 1.1324 - top_3_categorical_accuracy: 0.9207 - w_categorical_accuracy: 0.7293 - w_top_3_categorical_accuracy: 0.8825 - val_categorical_accuracy: 0.7860 - val_loss: 1.1110 - val_top_3_categorical_accuracy: 0.8694 - val_w_categorical_accuracy: 0.7860 - val_w_top_3_categorical_accuracy: 0.8694 - learning_rate: 1.0000e-04
# Epoch 5/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7986 - loss: 0.9091 - top_3_categorical_accuracy: 0.9272 - w_categorical_accuracy: 0.7735 - w_top_3_categorical_accuracy: 0.9193
# Epoch 5: val_loss improved from 1.11099 to 1.04994, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7986 - loss: 0.9091 - top_3_categorical_accuracy: 0.9272 - w_categorical_accuracy: 0.7735 - w_top_3_categorical_accuracy: 0.9193 - val_categorical_accuracy: 0.6859 - val_loss: 1.0499 - val_top_3_categorical_accuracy: 0.8787 - val_w_categorical_accuracy: 0.6859 - val_w_top_3_categorical_accuracy: 0.8787 - learning_rate: 1.0000e-04
# Epoch 6/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7911 - loss: 0.7939 - top_3_categorical_accuracy: 0.9317 - w_categorical_accuracy: 0.7892 - w_top_3_categorical_accuracy: 0.9297
# Epoch 6: val_loss improved from 1.04994 to 1.04597, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.7911 - loss: 0.7939 - top_3_categorical_accuracy: 0.9317 - w_categorical_accuracy: 0.7892 - w_top_3_categorical_accuracy: 0.9297 - val_categorical_accuracy: 0.7975 - val_loss: 1.0460 - val_top_3_categorical_accuracy: 0.8822 - val_w_categorical_accuracy: 0.7975 - val_w_top_3_categorical_accuracy: 0.8822 - learning_rate: 1.0000e-04
# Epoch 7/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7941 - loss: 0.6951 - top_3_categorical_accuracy: 0.9334 - w_categorical_accuracy: 0.7977 - w_top_3_categorical_accuracy: 0.9492
# Epoch 7: val_loss did not improve from 1.04597
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7941 - loss: 0.6951 - top_3_categorical_accuracy: 0.9334 - w_categorical_accuracy: 0.7977 - w_top_3_categorical_accuracy: 0.9492 - val_categorical_accuracy: 0.6826 - val_loss: 1.0534 - val_top_3_categorical_accuracy: 0.8965 - val_w_categorical_accuracy: 0.6826 - val_w_top_3_categorical_accuracy: 0.8965 - learning_rate: 1.0000e-04
# Epoch 8/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8008 - loss: 0.6789 - top_3_categorical_accuracy: 0.9303 - w_categorical_accuracy: 0.8095 - w_top_3_categorical_accuracy: 0.9433
# Epoch 8: val_loss did not improve from 1.04597
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 135s 35ms/step - categorical_accuracy: 0.8008 - loss: 0.6789 - top_3_categorical_accuracy: 0.9303 - w_categorical_accuracy: 0.8095 - w_top_3_categorical_accuracy: 0.9433 - val_categorical_accuracy: 0.7156 - val_loss: 1.0705 - val_top_3_categorical_accuracy: 0.8849 - val_w_categorical_accuracy: 0.7156 - val_w_top_3_categorical_accuracy: 0.8849 - learning_rate: 1.0000e-04
# Epoch 9/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7871 - loss: 0.6419 - top_3_categorical_accuracy: 0.9335 - w_categorical_accuracy: 0.8195 - w_top_3_categorical_accuracy: 0.9567
# Epoch 9: val_loss improved from 1.04597 to 0.95879, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7871 - loss: 0.6419 - top_3_categorical_accuracy: 0.9335 - w_categorical_accuracy: 0.8195 - w_top_3_categorical_accuracy: 0.9567 - val_categorical_accuracy: 0.7248 - val_loss: 0.9588 - val_top_3_categorical_accuracy: 0.8911 - val_w_categorical_accuracy: 0.7248 - val_w_top_3_categorical_accuracy: 0.8911 - learning_rate: 1.0000e-04
# Epoch 10/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7935 - loss: 0.5833 - top_3_categorical_accuracy: 0.9362 - w_categorical_accuracy: 0.8186 - w_top_3_categorical_accuracy: 0.9582
# Epoch 10: val_loss did not improve from 0.95879
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 35ms/step - categorical_accuracy: 0.7935 - loss: 0.5833 - top_3_categorical_accuracy: 0.9362 - w_categorical_accuracy: 0.8186 - w_top_3_categorical_accuracy: 0.9582 - val_categorical_accuracy: 0.5513 - val_loss: 1.0790 - val_top_3_categorical_accuracy: 0.8908 - val_w_categorical_accuracy: 0.5513 - val_w_top_3_categorical_accuracy: 0.8908 - learning_rate: 1.0000e-04
# Epoch 11/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7917 - loss: 0.5247 - top_3_categorical_accuracy: 0.9404 - w_categorical_accuracy: 0.8362 - w_top_3_categorical_accuracy: 0.9595
# Epoch 11: val_loss improved from 0.95879 to 0.92265, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7917 - loss: 0.5247 - top_3_categorical_accuracy: 0.9404 - w_categorical_accuracy: 0.8362 - w_top_3_categorical_accuracy: 0.9595 - val_categorical_accuracy: 0.7267 - val_loss: 0.9226 - val_top_3_categorical_accuracy: 0.8932 - val_w_categorical_accuracy: 0.7267 - val_w_top_3_categorical_accuracy: 0.8932 - learning_rate: 1.0000e-04
# Epoch 12/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7623 - loss: 0.5314 - top_3_categorical_accuracy: 0.9377 - w_categorical_accuracy: 0.8313 - w_top_3_categorical_accuracy: 0.9645
# Epoch 12: val_loss did not improve from 0.92265
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.7623 - loss: 0.5314 - top_3_categorical_accuracy: 0.9377 - w_categorical_accuracy: 0.8313 - w_top_3_categorical_accuracy: 0.9645 - val_categorical_accuracy: 0.5853 - val_loss: 1.2896 - val_top_3_categorical_accuracy: 0.8861 - val_w_categorical_accuracy: 0.5853 - val_w_top_3_categorical_accuracy: 0.8861 - learning_rate: 1.0000e-04
# Epoch 13/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7729 - loss: 0.5906 - top_3_categorical_accuracy: 0.9376 - w_categorical_accuracy: 0.8054 - w_top_3_categorical_accuracy: 0.9548
# Epoch 13: val_loss improved from 0.92265 to 0.85573, saving model to saves/obj_type/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.7729 - loss: 0.5906 - top_3_categorical_accuracy: 0.9376 - w_categorical_accuracy: 0.8054 - w_top_3_categorical_accuracy: 0.9548 - val_categorical_accuracy: 0.7316 - val_loss: 0.8557 - val_top_3_categorical_accuracy: 0.9013 - val_w_categorical_accuracy: 0.7316 - val_w_top_3_categorical_accuracy: 0.9013 - learning_rate: 1.0000e-04
# Epoch 14/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8050 - loss: 0.4879 - top_3_categorical_accuracy: 0.9424 - w_categorical_accuracy: 0.8243 - w_top_3_categorical_accuracy: 0.9640
# Epoch 14: val_loss did not improve from 0.85573
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.8050 - loss: 0.4879 - top_3_categorical_accuracy: 0.9424 - w_categorical_accuracy: 0.8243 - w_top_3_categorical_accuracy: 0.9640 - val_categorical_accuracy: 0.8347 - val_loss: 0.8648 - val_top_3_categorical_accuracy: 0.9181 - val_w_categorical_accuracy: 0.8347 - val_w_top_3_categorical_accuracy: 0.9181 - learning_rate: 1.0000e-04
# Epoch 15/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8043 - loss: 0.5360 - top_3_categorical_accuracy: 0.9441 - w_categorical_accuracy: 0.8333 - w_top_3_categorical_accuracy: 0.9585
# Epoch 15: val_loss did not improve from 0.85573
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 133s 34ms/step - categorical_accuracy: 0.8043 - loss: 0.5360 - top_3_categorical_accuracy: 0.9441 - w_categorical_accuracy: 0.8333 - w_top_3_categorical_accuracy: 0.9585 - val_categorical_accuracy: 0.8309 - val_loss: 0.9505 - val_top_3_categorical_accuracy: 0.9032 - val_w_categorical_accuracy: 0.8309 - val_w_top_3_categorical_accuracy: 0.9032 - learning_rate: 1.0000e-04
# Epoch 16/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.8184 - loss: 0.4828 - top_3_categorical_accuracy: 0.9490 - w_categorical_accuracy: 0.8393 - w_top_3_categorical_accuracy: 0.9622
# Epoch 16: val_loss did not improve from 0.85573
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.8184 - loss: 0.4828 - top_3_categorical_accuracy: 0.9490 - w_categorical_accuracy: 0.8393 - w_top_3_categorical_accuracy: 0.9622 - val_categorical_accuracy: 0.7307 - val_loss: 0.9581 - val_top_3_categorical_accuracy: 0.8974 - val_w_categorical_accuracy: 0.7307 - val_w_top_3_categorical_accuracy: 0.8974 - learning_rate: 1.0000e-04
# Epoch 17/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7654 - loss: 0.4577 - top_3_categorical_accuracy: 0.9470 - w_categorical_accuracy: 0.8553 - w_top_3_categorical_accuracy: 0.9695
# Epoch 17: val_loss did not improve from 0.85573
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.7654 - loss: 0.4577 - top_3_categorical_accuracy: 0.9470 - w_categorical_accuracy: 0.8553 - w_top_3_categorical_accuracy: 0.9695 - val_categorical_accuracy: 0.7366 - val_loss: 0.9248 - val_top_3_categorical_accuracy: 0.9055 - val_w_categorical_accuracy: 0.7366 - val_w_top_3_categorical_accuracy: 0.9055 - learning_rate: 1.0000e-05
# Epoch 18/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.7754 - loss: 0.3984 - top_3_categorical_accuracy: 0.9510 - w_categorical_accuracy: 0.8443 - w_top_3_categorical_accuracy: 0.9757
# Epoch 18: val_loss did not improve from 0.85573
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 134s 35ms/step - categorical_accuracy: 0.7754 - loss: 0.3984 - top_3_categorical_accuracy: 0.9510 - w_categorical_accuracy: 0.8443 - w_top_3_categorical_accuracy: 0.9757 - val_categorical_accuracy: 0.7420 - val_loss: 0.8705 - val_top_3_categorical_accuracy: 0.9107 - val_w_categorical_accuracy: 0.7420 - val_w_top_3_categorical_accuracy: 0.9107 - learning_rate: 1.0000e-05
# Epoch 18: early stopping

# %%
log = pd.read_csv(log_path)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20*cm, 15*cm))

ax1.plot(log['epoch'], log['categorical_accuracy'], label='categorical_accuracy', color='red')
ax1.plot(log['epoch'], log['val_categorical_accuracy'], label='val_categorical_accuracy', color='orange')
ax1.plot(log['epoch'], log[f'top_{top_k}_categorical_accuracy'], label=f'top_{top_k}_categorical_accuracy', color='royalblue')
ax1.plot(log['epoch'], log[f'val_top_{top_k}_categorical_accuracy'], label=f'val_top_{top_k}_categorical_accuracy', color='navy')
ax1.set_title('training metrics')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1)  # Legend below the plot

ax2.plot(log['epoch'], log['loss'], label='loss')
ax2.plot(log['epoch'], log['val_loss'], label='val_loss')
ax2.set_title('loss')
ax2.set_xlabel('epoch')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)  # Legend below the plot

fig.tight_layout(rect=[0, 0.1, 1, 1])

plt.savefig(f'{checkpoint_path}/metrics_loss.svg')
plt.show()

# %%
# load old model, if needed
if model is None:
    model = load_model(model_path)

# %%
# evaluate model
score = model.evaluate(x=Generator(X_test, y_test, 128, max_sequence_length))
print(f'Test loss: {score[0]}')
print(f'Test accuracy: {score[1]}')
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - categorical_accuracy: 0.7764 - loss: 0.6007 - top_3_categorical_accuracy: 0.9471 - w_categorical_accuracy: 0.7764 - w_top_3_categorical_accuracy: 0.9471
# Test loss: 0.5979681611061096
# Test accuracy: 0.778780460357666

# %%
# print classification report
y_pred = model.predict(x=Generator(X_test, y_test, 128, max_sequence_length))
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

report = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan)
report_dict = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan, output_dict=True)

print(report)

# save classification report to file
with open(f'{checkpoint_path}/classification_report.txt', 'w') as f:
    json.dump(report_dict, f)
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step
#                  precision    recall  f1-score   support
#
#       adjkerntz       0.00      1.00      0.00        11
#          alpine       0.45      0.85      0.58       560
#           anvil       0.20      0.46      0.28       378
#           atrun       1.00      1.00      1.00       237
#             awk       0.71      1.00      0.83         5
#        basename        nan      0.00      0.00         2
#            bash       0.95      0.96      0.95     12512
#             cat       0.67      0.92      0.77        26
#         cleanup       0.50      0.71      0.59       276
#             cmp       0.38      1.00      0.56         5
#              cp       0.91      1.00      0.95        30
#            cron       0.99      1.00      1.00       624
#            date       0.96      1.00      0.98      1218
#              dd       0.76      0.99      0.86       125
#        dhclient       0.00      0.00      0.00        17
#           dmesg       0.68      1.00      0.81        15
#           egrep       0.50      0.50      0.50         2
#            expr        nan      0.00      0.00         2
#            find       1.00      1.00      1.00      4006
#         fortune       0.98      1.00      0.99        91
#            grep       0.10      0.60      0.18         5
#            head       1.00      1.00      1.00      1219
#        hostname       0.71      1.00      0.83        10
#           imapd       0.91      0.52      0.67      2469
#           inetd       1.00      1.00      1.00       291
#            kill       0.67      1.00      0.80         2
#            less       0.00      0.33      0.01         3
#           local       0.87      0.56      0.69       868
#           lockf       1.00      0.67      0.80         3
#              ls       0.03      0.50      0.06        12
#            lsof       0.99      0.91      0.95      8568
#            mail       0.02      0.50      0.04         2
#     mailwrapper       0.67      0.67      0.67         3
#          master       0.27      1.00      0.42       580
#           mkdir       0.95      1.00      0.97        18
#          mktemp       0.21      1.00      0.34         6
#           mlock       1.00      1.00      1.00       506
#           mount       0.14      1.00      0.25         2
#              mv       1.00      1.00      1.00       860
#         netstat       0.58      0.79      0.67        58
#       newsyslog       0.80      0.89      0.84        18
#          pickup       0.91      0.83      0.87       143
#             pkg       1.00      0.72      0.84      1701
#        proxymap       0.96      0.45      0.61       331
#              ps       0.11      0.80      0.20         5
#       python2.7       0.00      0.00      0.00       841
#       resizewin       1.00      1.00      1.00        91
#              rm       0.17      0.31      0.22        36
#           route       0.70      1.00      0.82         7
#             sed       0.00      0.00      0.00         2
#        sendmail       0.17      0.76      0.27        21
#              sh       0.95      0.28      0.43      1987
#           sleep        nan      0.00      0.00      4889
#           smtpd       0.95      0.83      0.89       818
#            sort       0.06      1.00      0.12         1
#            sshd       0.95      0.99      0.97       427
#            sudo       0.64      0.88      0.74        26
#          sysctl       0.92      1.00      0.96       129
#             tee       0.20      0.83      0.32         6
#             top       0.98      0.99      0.98      1913
# trivial-rewrite       0.48      0.55      0.51       377
#             tty       0.50      1.00      0.67         2
#          unlink       0.88      1.00      0.94       123
#          uptime       1.00      1.00      1.00        14
#          vmstat       1.00      1.00      1.00      2468
#              wc       0.41      1.00      0.58         7
#            wget       0.44      0.78      0.56        74
#
#        accuracy                           0.78     52084
#       macro avg       0.62      0.77      0.62     52084
#    weighted avg       0.92      0.78      0.79     52084

# %%
# print confusion matrix
# labels explicitly set, because current model may not predict all labels
conf_matrix = confusion_matrix(y_true, y_pred, labels=range(labels_cardinality), normalize='true')

# Replace all NaN values with 0
conf_matrix = np.nan_to_num(conf_matrix)

# Verify the distinct labels align correctly
distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(20*cm, 20*cm))

ax.matshow(conf_matrix, cmap='cividis', aspect='auto')

# Set class names on axes
ax.set_xticks(range(len(distinct_labels)))
ax.set_yticks(range(len(distinct_labels)))
ax.set_xticklabels(distinct_labels, rotation=90, fontsize=8)
ax.set_yticklabels(distinct_labels, fontsize=8)

# Set axis labels "predicted" and "actual"
ax.set_xlabel('predicted label')
ax.set_ylabel('true label')
# y-axis label right side
ax.yaxis.set_label_position('right')

# set figsize
plt.savefig(f'{checkpoint_path}/confusion_matrix.svg')
plt.show()

# %%
unique_in_y_pred = [ labels_map[i] for i in np.unique(y_pred) ]
#print("Unique labels in y_pred:", unique_in_y_pred)

unique_not_in_y_pred = [ label for label in distinct_labels if label not in unique_in_y_pred ]
print("Unique labels not in y_pred:", unique_not_in_y_pred)
# Out:
# Unique labels not in y_pred: ['basename', 'expr', 'sleep']
