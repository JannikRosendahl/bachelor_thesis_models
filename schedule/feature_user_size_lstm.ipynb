# %%
import os
import re
from collections import Counter
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cm = 1/2.54

# force GPU device
os.environ["CUDA_VISIBLE_DEVICES"]='1'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

from keras.src.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, CSVLogger
from keras.src.layers import SimpleRNN, LSTM, Dense, Dropout, Bidirectional
from keras import Sequential, Input
from keras.losses import CategoricalCrossentropy, CategoricalFocalCrossentropy
from keras.optimizers import Adam
from keras.models import load_model
from keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

from utils import *

# %%
max_sequence_length = 100
experiment_name = 'feature_user_size_lstm'
top_k = 3

# %%
checkpoint_path = f'saves/{experiment_name}'
model_path = f'{checkpoint_path}/model.keras'
log_path = f'{checkpoint_path}/log.csv'
history_path = f'{checkpoint_path}/history.npy'

# ensure directory exists
if not os.path.exists(checkpoint_path):
    os.makedirs(checkpoint_path)

# %%
data_directory = '/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
unusable_threshold = 10
rare_threshold = 50
splits = (0.7, 0.15, 0.15)

max_sequence_length = 100

assert(sum(splits) == 1)

print(f'experiment parameters: \n{data_directory=} \n{unusable_threshold=} \n{rare_threshold=} \n{splits=} \n{max_sequence_length=}')
# Out:
# experiment parameters:
# data_directory='/home/jrosendahl/datasets/cadets/sequences_export_benign_filetypes_more/'
# unusable_threshold=10
# rare_threshold=50
# splits=(0.7, 0.15, 0.15)
# max_sequence_length=100

# %%
total_classes = 0

# unusable classes will be removed from the dataset
unusable_classes = []
# rare classes will be oversampled
rare_classes = []

# all classes in training data (all classes - unusable classes)
classes = []

# walk all files, build unusable_classes, rare_classes
classes_occurrences = Counter()
for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    classes_occurrences[label] += 1

total_classes = len(classes_occurrences)
for label, count in classes_occurrences.items():
    if count < unusable_threshold:
        unusable_classes.append(label)
    elif count < rare_threshold:
        rare_classes.append(label)
        classes.append(label)
    else:
        classes.append(label)

print(f'Total classes: {total_classes}')
print(f'Unusable classes: {len(unusable_classes)}')
print(f'\t{unusable_classes}')
print(f'Rare classes: {len(rare_classes)}')
print(f'\t{rare_classes}')

labels_cardinality = len(set(classes))
print(f'Usable classes: {labels_cardinality}')
# Out:
# Total classes: 118
# Unusable classes: 51
# 	['ping', 'pwd_mkdb', 'vi', 'tr', 'uname', 'msgs', 'screen', 'pw', 'bzip2', 'bzcat', 'nginx', 'stat', 'tail', 'smtp', 'kenv', 'nawk', 'ssh', 'chown', 'cut', 'php-fpm', 'jot', 'xz', 'diff', 'bounce', 'links', 'ipfw', 'touch', 'env', 'pfctl', 'minions', 'csh', 'kldstat', 'su', 'nohup', 'stty', 'df', 'limits', 'id', 'postmap', 'ifconfig', 'chkgrp', 'ipfstat', 'locale', 'devd', 'uniq', 'XIM', 'getty', 'which', 'init', 'test', 'nice']
# Rare classes: 20
# 	['wc', 'grep', 'mktemp', 'less', 'tty', 'mailwrapper', 'kill', 'lockf', 'mount', 'tee', 'expr', 'ps', 'route', 'sed', 'cmp', 'egrep', 'sort', 'basename', 'awk', 'mail']
# Usable classes: 67

# %%
# split into train, validation, test
labels_set = set()

filenames_all = []

filenames_train = []
filenames_val = []
filenames_test = []

for filename in os.listdir(data_directory):
    label = class_from_filename(filename)
    if label in unusable_classes:
        continue
    labels_set.add(label)
    filenames_all.append(filename)

# stratisfied split
test_vs_val = splits[2] / (splits[1] + splits[2])
filenames_train, filenames_val_test = train_test_split(filenames_all, test_size=splits[1]+splits[2], stratify=[class_from_filename(f) for f in filenames_all])
filenames_val, filenames_test = train_test_split(filenames_val_test, test_size=test_vs_val, stratify=[class_from_filename(f) for f in filenames_val_test])

print(f'Train: {len(filenames_train)}')
print(f'Validation: {len(filenames_val)}')
print(f'Test: {len(filenames_test)}')

# build labels_map in alphabetical order
labels_map = {}
for i, label in enumerate(sorted(labels_set)):
    labels_map[label] = i
# Out:
# Train: 150475
# Validation: 32245
# Test: 32245

# %%
# load data
count_files_read = 0
count_sequences_split = 0
count_splits = 0

preprocessor = Preprocessor(['TYPE', 'USERNAME'])

def parse_file(filename) -> tuple[list[int], list[list[int]]]:
    """
    Parse a file and return the vectorized data. Not a pure function (calls parse_line)!
    """
    global count_files_read, count_sequences_split, count_splits

    y_list: list[int] = []
    X_list: list[list[int]] = []
    y = class_from_filename(filename)
    y = labels_map[y]
    with open(os.path.join(data_directory, filename), 'r') as f:
        lines = f.readlines()
        count_files_read += 1
    if count_files_read % 50000 == 0:
        print(f'Files read: {count_files_read}')
    X = []
    for line in lines:
        line_res = preprocessor.process(line)
        event = line_res['TYPE']
        username = line_res['USERNAME']
        X.append((event, username))

    # check if sequence needs to be split
    if len(X) > max_sequence_length:
        count_sequences_split += 1
        count_splits += len(X) // max_sequence_length
        for i in range(0, len(X), max_sequence_length):
            y_list.append(y)
            X_list.append(X[i:i+max_sequence_length])
        assert len(X_list[0]) == max_sequence_length
    else:
        y_list.append(y)
        X_list.append(X)

    # transform elements to numpy arrays
    y_list = np.array(y_list)
    X_list = [np.array(x) for x in X_list]

    assert len(y_list) == len(X_list)
    return y_list, X_list


y_train = []
X_train = []
y_val = []
X_val = []
y_test = []
X_test = []

for filename in filenames_train:
    try:
        y_list, X_list = parse_file(filename)
    except Exception as e:
        print(f'Error parsing file: {filename}')
        raise e
    y_train.extend(y_list)
    X_train.extend(X_list)

for filename in filenames_val:
    y_list, X_list = parse_file(filename)
    y_val.extend(y_list)
    X_val.extend(X_list)

for filename in filenames_test:
    y_list, X_list = parse_file(filename)
    y_test.extend(y_list)
    X_test.extend(X_list)

assert len(X_train) == len(y_train)
assert len(X_val) == len(y_val)
assert len(X_test) == len(y_test)

print(f'Files read: {count_files_read}')
print(f'Sequences split: {count_sequences_split}')
print(f'Splits: {count_splits}')


event_types_map = preprocessor.event_types_map
users_map = preprocessor.users_map

event_types_cardinality = len(event_types_map)
username_cardinality = len(users_map)

print(f'Event types: {event_types_cardinality}')
print(f'Usernames: {username_cardinality}')

# print lengths
print(f'Train: {len(y_train)}')
print(f'Validation: {len(y_val)}')
print(f'Test: {len(y_test)}')
# Out:
# Files read: 50000
# Files read: 100000
# Files read: 150000
# Files read: 200000
# Files read: 214965
# Sequences split: 22897
# Splits: 132960
# Event types: 29
# Usernames: 16
# Train: 247249
# Validation: 48541
# Test: 52084

# %%
# debug print all maps (sorted)
print('Event types:')
for k, v in sorted(event_types_map.items(), key=lambda x: x[1]):
    print(f'{v}: {k}', end=', ')
print()

print('Usernames:')
for k, v in sorted(users_map.items(), key=lambda x: x[1]):
    print(f'{v}: {k}', end=', ')
print()
# Out:
# Event types:
# 0: EVENT_EXECUTE, 1: EVENT_OPEN, 2: EVENT_READ, 3: EVENT_CLOSE, 4: EVENT_MMAP, 5: EVENT_WRITE, 6: EVENT_EXIT, 7: EVENT_CONNECT, 8: EVENT_SENDTO, 9: EVENT_LSEEK, 10: EVENT_CHANGE_PRINCIPAL, 11: EVENT_LOGIN, 12: EVENT_MODIFY_PROCESS, 13: EVENT_FCNTL, 14: EVENT_RECVFROM, 15: EVENT_MPROTECT, 16: EVENT_CREATE_OBJECT, 17: EVENT_ACCEPT, 18: EVENT_UNLINK, 19: EVENT_FORK, 20: EVENT_MODIFY_FILE_ATTRIBUTES, 21: EVENT_LINK, 22: EVENT_RENAME, 23: EVENT_TRUNCATE, 24: EVENT_SIGNAL, 25: EVENT_OTHER, 26: EVENT_SENDMSG, 27: EVENT_RECVMSG, 28: EVENT_BIND,
# Usernames:
# 0: operator, 1: darpa, 2: root, 3: frank, 4: user, 5: charles, 6: george, 7: bob, 8: smmsp, 9: admin, 10: henry, 11: irene, 12: david, 13: postfix, 14: nobody, 15: _dhcp,

# %%
# turn labels map into bidirectional map
for k, v in labels_map.copy().items():
    labels_map[v] = k

# turn feature maps into bidirectional maps
for k, v in event_types_map.copy().items():
    event_types_map[v] = k

for k, v in users_map.copy().items():
    users_map[v] = k

# %%
# print distributions in all 3 sets
train_distribution = Counter(y_train)
val_distribution = Counter(y_val)
test_distribution = Counter(y_test)

# plot 3 pie plots, use same colors for same classes
colors = plt.cm.tab20.colors
colors = [ colors[i % 20] for i in range(labels_cardinality) ]

# sort labels by occurence in training set
sorted_labels = sorted(train_distribution, key=train_distribution.get, reverse=True)

# sort all distributions by sorted_labels
train_distribution = [train_distribution[label] for label in sorted_labels]
val_distribution = [val_distribution[label] for label in sorted_labels]
test_distribution = [test_distribution[label] for label in sorted_labels]

# transform labels to names
sorted_labels = [labels_map[label] for label in sorted_labels]

fig, axs = plt.subplots(1, 3, figsize=(30*cm, 10*cm))
axs[0].pie(train_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[0].set_title('Train')
axs[1].pie(val_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[1].set_title('Validation')
axs[2].pie(test_distribution, labels=sorted_labels, colors=colors, autopct='%1.1f%%')
axs[2].set_title('Test')
plt.savefig(f'{checkpoint_path}/distributions.png')
plt.show()

# %%
# one-hot encode labels
y_train = np.eye(labels_cardinality)[y_train]
y_val = np.eye(labels_cardinality)[y_val]
y_test = np.eye(labels_cardinality)[y_test]

# %%
# one-hot encode features
# at this point, X_* are lists of tuples of vectorized features
def encode_features(sequence: np.ndarray) -> np.ndarray:
    # Precompute identity matrices
    event_eye = np.eye(event_types_cardinality)
    username_eye = np.eye(username_cardinality)

    # Initialize the output array with precomputed shapes
    encoded_seq = np.empty((len(sequence), event_eye.shape[1] + username_eye.shape[1]))

    for i, feature_vector in enumerate(sequence):
        event = event_eye[feature_vector[0]]
        username = username_eye[feature_vector[1]]

        # Concatenate all features into a single feature vector
        encoded_seq[i] = np.concatenate((event, username))

    return encoded_seq

X_train = [ encode_features(x) for x in X_train ]
X_val = [ encode_features(x) for x in X_val ]
X_test = [ encode_features(x) for x in X_test ]

# %%
feature_vector_cardinality = X_train[0].shape[1]

print(f'Feature vector cardinality: {feature_vector_cardinality}')
# Out:
# Feature vector cardinality: 45

# %%
X_train, y_train = shuffle(X_train, y_train)
X_val, y_val = shuffle(X_val, y_val)
X_test, y_test = shuffle(X_test, y_test)

# %% [markdown]
# build model

# %%
model = Sequential(layers=[
    Input(shape=(None, feature_vector_cardinality)),
    LSTM(128, return_sequences=True),
    LSTM(128, return_sequences=True),
    LSTM(128, return_sequences=False),
    Dense(labels_cardinality, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, None, 64)       │         7,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, None, 64)       │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_2 (SimpleRNN)        │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 67)             │         4,355 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 27,907 (109.01 KB)
#  Trainable params: 27,907 (109.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss',
        patience=11,
        verbose=1,
        mode='auto'
    ),
    ModelCheckpoint(
        filepath=model_path,
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.1,
        patience=3,
        verbose=1,
        mode='auto',
        min_lr=1e-7
    ),
    CSVLogger(
        filename=log_path,
        append=True
    )
]

loss = CategoricalCrossentropy()
optimizer = Adam(learning_rate=0.0001)

# class weights
y_train_int = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_int),
    y=y_train_int
)
class_weights_dict = dict(enumerate(class_weights))

metrics = [
    CategoricalAccuracy(name='categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'top_{top_k}_categorical_accuracy'),
]

weighted_metrics = [
    CategoricalAccuracy(name='w_categorical_accuracy'),
    TopKCategoricalAccuracy(k=top_k, name=f'w_top_{top_k}_categorical_accuracy'),
]

# 'categorical_focal_crossentropy'
# 'categorical_crossentropy'
model.compile(
    loss=loss,
    optimizer=optimizer,
    metrics=metrics,
    weighted_metrics=weighted_metrics,
)

# %% [markdown]
# train model

# %%
history = model.fit(
    x=Generator(X_train, y_train, 64, max_sequence_length),
    validation_data=Generator(X_val, y_val, 64, max_sequence_length),
    epochs=200,
    callbacks=callbacks,
    class_weight=class_weights_dict
)

# save history to file
with open(history_path, 'wb') as f:
    np.save(f, history.history)
# Out:
# Epoch 1/200
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723902557.525020 2337141 service.cc:145] XLA service 0x79f89c00bd00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1723902557.525102 2337141 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
#    5/3864 ━━━━━━━━━━━━━━━━━━━━ 2:05 33ms/step - categorical_accuracy: 0.0418 - loss: 2.2840 - top_3_categorical_accuracy: 0.0771 - w_categorical_accuracy: 0.0257 - w_top_3_categorical_accuracy: 0.0655
# I0000 00:00:1723902558.853664 2337141 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.5382 - loss: 3.3194 - top_3_categorical_accuracy: 0.6635 - w_categorical_accuracy: 0.2863 - w_top_3_categorical_accuracy: 0.4299
# Epoch 1: val_loss improved from inf to 1.45680, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 138s 35ms/step - categorical_accuracy: 0.5383 - loss: 3.3192 - top_3_categorical_accuracy: 0.6636 - w_categorical_accuracy: 0.2864 - w_top_3_categorical_accuracy: 0.4299 - val_categorical_accuracy: 0.7577 - val_loss: 1.4568 - val_top_3_categorical_accuracy: 0.8210 - val_w_categorical_accuracy: 0.7577 - val_w_top_3_categorical_accuracy: 0.8210 - learning_rate: 1.0000e-04
# Epoch 2/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8386 - loss: 1.7796 - top_3_categorical_accuracy: 0.8908 - w_categorical_accuracy: 0.6377 - w_top_3_categorical_accuracy: 0.7883
# Epoch 2: val_loss improved from 1.45680 to 0.98655, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 130s 34ms/step - categorical_accuracy: 0.8386 - loss: 1.7795 - top_3_categorical_accuracy: 0.8908 - w_categorical_accuracy: 0.6377 - w_top_3_categorical_accuracy: 0.7883 - val_categorical_accuracy: 0.8179 - val_loss: 0.9865 - val_top_3_categorical_accuracy: 0.8552 - val_w_categorical_accuracy: 0.8179 - val_w_top_3_categorical_accuracy: 0.8552 - learning_rate: 1.0000e-04
# Epoch 3/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8765 - loss: 1.2423 - top_3_categorical_accuracy: 0.9132 - w_categorical_accuracy: 0.7319 - w_top_3_categorical_accuracy: 0.8554
# Epoch 3: val_loss did not improve from 0.98655
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.8765 - loss: 1.2423 - top_3_categorical_accuracy: 0.9132 - w_categorical_accuracy: 0.7319 - w_top_3_categorical_accuracy: 0.8554 - val_categorical_accuracy: 0.8240 - val_loss: 0.9955 - val_top_3_categorical_accuracy: 0.8538 - val_w_categorical_accuracy: 0.8240 - val_w_top_3_categorical_accuracy: 0.8538 - learning_rate: 1.0000e-04
# Epoch 4/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8885 - loss: 1.0592 - top_3_categorical_accuracy: 0.9217 - w_categorical_accuracy: 0.7558 - w_top_3_categorical_accuracy: 0.8797
# Epoch 4: val_loss improved from 0.98655 to 0.75058, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.8885 - loss: 1.0592 - top_3_categorical_accuracy: 0.9217 - w_categorical_accuracy: 0.7558 - w_top_3_categorical_accuracy: 0.8797 - val_categorical_accuracy: 0.8475 - val_loss: 0.7506 - val_top_3_categorical_accuracy: 0.8712 - val_w_categorical_accuracy: 0.8475 - val_w_top_3_categorical_accuracy: 0.8712 - learning_rate: 1.0000e-04
# Epoch 5/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8959 - loss: 0.8340 - top_3_categorical_accuracy: 0.9265 - w_categorical_accuracy: 0.7685 - w_top_3_categorical_accuracy: 0.9106
# Epoch 5: val_loss did not improve from 0.75058
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 130s 34ms/step - categorical_accuracy: 0.8959 - loss: 0.8340 - top_3_categorical_accuracy: 0.9265 - w_categorical_accuracy: 0.7685 - w_top_3_categorical_accuracy: 0.9106 - val_categorical_accuracy: 0.8399 - val_loss: 0.7949 - val_top_3_categorical_accuracy: 0.8663 - val_w_categorical_accuracy: 0.8399 - val_w_top_3_categorical_accuracy: 0.8663 - learning_rate: 1.0000e-04
# Epoch 6/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.8958 - loss: 0.7645 - top_3_categorical_accuracy: 0.9270 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9180
# Epoch 6: val_loss improved from 0.75058 to 0.70978, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.8958 - loss: 0.7645 - top_3_categorical_accuracy: 0.9270 - w_categorical_accuracy: 0.8119 - w_top_3_categorical_accuracy: 0.9180 - val_categorical_accuracy: 0.8508 - val_loss: 0.7098 - val_top_3_categorical_accuracy: 0.8784 - val_w_categorical_accuracy: 0.8508 - val_w_top_3_categorical_accuracy: 0.8784 - learning_rate: 1.0000e-04
# Epoch 7/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9036 - loss: 0.6468 - top_3_categorical_accuracy: 0.9325 - w_categorical_accuracy: 0.8219 - w_top_3_categorical_accuracy: 0.9120
# Epoch 7: val_loss improved from 0.70978 to 0.68921, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9036 - loss: 0.6468 - top_3_categorical_accuracy: 0.9325 - w_categorical_accuracy: 0.8219 - w_top_3_categorical_accuracy: 0.9120 - val_categorical_accuracy: 0.8567 - val_loss: 0.6892 - val_top_3_categorical_accuracy: 0.8856 - val_w_categorical_accuracy: 0.8567 - val_w_top_3_categorical_accuracy: 0.8856 - learning_rate: 1.0000e-04
# Epoch 8/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9055 - loss: 0.5870 - top_3_categorical_accuracy: 0.9327 - w_categorical_accuracy: 0.8438 - w_top_3_categorical_accuracy: 0.9283
# Epoch 8: val_loss did not improve from 0.68921
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9055 - loss: 0.5870 - top_3_categorical_accuracy: 0.9327 - w_categorical_accuracy: 0.8437 - w_top_3_categorical_accuracy: 0.9283 - val_categorical_accuracy: 0.8575 - val_loss: 0.7026 - val_top_3_categorical_accuracy: 0.8855 - val_w_categorical_accuracy: 0.8575 - val_w_top_3_categorical_accuracy: 0.8855 - learning_rate: 1.0000e-04
# Epoch 9/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9115 - loss: 0.5219 - top_3_categorical_accuracy: 0.9377 - w_categorical_accuracy: 0.8471 - w_top_3_categorical_accuracy: 0.9356
# Epoch 9: val_loss did not improve from 0.68921
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9115 - loss: 0.5219 - top_3_categorical_accuracy: 0.9377 - w_categorical_accuracy: 0.8471 - w_top_3_categorical_accuracy: 0.9356 - val_categorical_accuracy: 0.8370 - val_loss: 0.8015 - val_top_3_categorical_accuracy: 0.8744 - val_w_categorical_accuracy: 0.8370 - val_w_top_3_categorical_accuracy: 0.8744 - learning_rate: 1.0000e-04
# Epoch 10/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9089 - loss: 0.4940 - top_3_categorical_accuracy: 0.9390 - w_categorical_accuracy: 0.8470 - w_top_3_categorical_accuracy: 0.9466
# Epoch 10: val_loss improved from 0.68921 to 0.67821, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9089 - loss: 0.4940 - top_3_categorical_accuracy: 0.9390 - w_categorical_accuracy: 0.8470 - w_top_3_categorical_accuracy: 0.9466 - val_categorical_accuracy: 0.8520 - val_loss: 0.6782 - val_top_3_categorical_accuracy: 0.8776 - val_w_categorical_accuracy: 0.8520 - val_w_top_3_categorical_accuracy: 0.8776 - learning_rate: 1.0000e-04
# Epoch 11/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9103 - loss: 0.4856 - top_3_categorical_accuracy: 0.9390 - w_categorical_accuracy: 0.8525 - w_top_3_categorical_accuracy: 0.9485
# Epoch 11: val_loss did not improve from 0.67821
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9103 - loss: 0.4856 - top_3_categorical_accuracy: 0.9390 - w_categorical_accuracy: 0.8525 - w_top_3_categorical_accuracy: 0.9485 - val_categorical_accuracy: 0.8588 - val_loss: 0.6926 - val_top_3_categorical_accuracy: 0.8874 - val_w_categorical_accuracy: 0.8588 - val_w_top_3_categorical_accuracy: 0.8874 - learning_rate: 1.0000e-04
# Epoch 12/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9156 - loss: 0.4442 - top_3_categorical_accuracy: 0.9458 - w_categorical_accuracy: 0.8633 - w_top_3_categorical_accuracy: 0.9507
# Epoch 12: val_loss did not improve from 0.67821
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9156 - loss: 0.4442 - top_3_categorical_accuracy: 0.9458 - w_categorical_accuracy: 0.8633 - w_top_3_categorical_accuracy: 0.9507 - val_categorical_accuracy: 0.8635 - val_loss: 0.6837 - val_top_3_categorical_accuracy: 0.8910 - val_w_categorical_accuracy: 0.8635 - val_w_top_3_categorical_accuracy: 0.8910 - learning_rate: 1.0000e-04
# Epoch 13/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9158 - loss: 0.4313 - top_3_categorical_accuracy: 0.9465 - w_categorical_accuracy: 0.8702 - w_top_3_categorical_accuracy: 0.9535
# Epoch 13: val_loss improved from 0.67821 to 0.62881, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9158 - loss: 0.4313 - top_3_categorical_accuracy: 0.9465 - w_categorical_accuracy: 0.8702 - w_top_3_categorical_accuracy: 0.9535 - val_categorical_accuracy: 0.8701 - val_loss: 0.6288 - val_top_3_categorical_accuracy: 0.9040 - val_w_categorical_accuracy: 0.8701 - val_w_top_3_categorical_accuracy: 0.9040 - learning_rate: 1.0000e-04
# Epoch 14/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9136 - loss: 0.4864 - top_3_categorical_accuracy: 0.9455 - w_categorical_accuracy: 0.8355 - w_top_3_categorical_accuracy: 0.9381
# Epoch 14: val_loss improved from 0.62881 to 0.59959, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9136 - loss: 0.4864 - top_3_categorical_accuracy: 0.9455 - w_categorical_accuracy: 0.8355 - w_top_3_categorical_accuracy: 0.9381 - val_categorical_accuracy: 0.8737 - val_loss: 0.5996 - val_top_3_categorical_accuracy: 0.9029 - val_w_categorical_accuracy: 0.8737 - val_w_top_3_categorical_accuracy: 0.9029 - learning_rate: 1.0000e-04
# Epoch 15/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9230 - loss: 0.4108 - top_3_categorical_accuracy: 0.9512 - w_categorical_accuracy: 0.8647 - w_top_3_categorical_accuracy: 0.9561
# Epoch 15: val_loss did not improve from 0.59959
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9230 - loss: 0.4108 - top_3_categorical_accuracy: 0.9512 - w_categorical_accuracy: 0.8647 - w_top_3_categorical_accuracy: 0.9561 - val_categorical_accuracy: 0.8672 - val_loss: 0.7299 - val_top_3_categorical_accuracy: 0.8954 - val_w_categorical_accuracy: 0.8672 - val_w_top_3_categorical_accuracy: 0.8954 - learning_rate: 1.0000e-04
# Epoch 16/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9238 - loss: 0.3995 - top_3_categorical_accuracy: 0.9527 - w_categorical_accuracy: 0.8699 - w_top_3_categorical_accuracy: 0.9582
# Epoch 16: val_loss did not improve from 0.59959
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9238 - loss: 0.3995 - top_3_categorical_accuracy: 0.9527 - w_categorical_accuracy: 0.8699 - w_top_3_categorical_accuracy: 0.9582 - val_categorical_accuracy: 0.8712 - val_loss: 0.6505 - val_top_3_categorical_accuracy: 0.9055 - val_w_categorical_accuracy: 0.8712 - val_w_top_3_categorical_accuracy: 0.9055 - learning_rate: 1.0000e-04
# Epoch 17/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9238 - loss: 0.3912 - top_3_categorical_accuracy: 0.9522 - w_categorical_accuracy: 0.8666 - w_top_3_categorical_accuracy: 0.9639
# Epoch 17: val_loss did not improve from 0.59959
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9238 - loss: 0.3913 - top_3_categorical_accuracy: 0.9522 - w_categorical_accuracy: 0.8665 - w_top_3_categorical_accuracy: 0.9639 - val_categorical_accuracy: 0.8692 - val_loss: 0.6759 - val_top_3_categorical_accuracy: 0.8990 - val_w_categorical_accuracy: 0.8692 - val_w_top_3_categorical_accuracy: 0.8990 - learning_rate: 1.0000e-04
# Epoch 18/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9212 - loss: 0.4094 - top_3_categorical_accuracy: 0.9497 - w_categorical_accuracy: 0.8778 - w_top_3_categorical_accuracy: 0.9568
# Epoch 18: val_loss did not improve from 0.59959
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9212 - loss: 0.4094 - top_3_categorical_accuracy: 0.9497 - w_categorical_accuracy: 0.8778 - w_top_3_categorical_accuracy: 0.9568 - val_categorical_accuracy: 0.8800 - val_loss: 0.6071 - val_top_3_categorical_accuracy: 0.9088 - val_w_categorical_accuracy: 0.8800 - val_w_top_3_categorical_accuracy: 0.9088 - learning_rate: 1.0000e-05
# Epoch 19/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9303 - loss: 0.3256 - top_3_categorical_accuracy: 0.9552 - w_categorical_accuracy: 0.8827 - w_top_3_categorical_accuracy: 0.9639
# Epoch 19: val_loss improved from 0.59959 to 0.56741, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9303 - loss: 0.3256 - top_3_categorical_accuracy: 0.9552 - w_categorical_accuracy: 0.8827 - w_top_3_categorical_accuracy: 0.9639 - val_categorical_accuracy: 0.8844 - val_loss: 0.5674 - val_top_3_categorical_accuracy: 0.9159 - val_w_categorical_accuracy: 0.8844 - val_w_top_3_categorical_accuracy: 0.9159 - learning_rate: 1.0000e-05
# Epoch 20/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9328 - loss: 0.3180 - top_3_categorical_accuracy: 0.9594 - w_categorical_accuracy: 0.8897 - w_top_3_categorical_accuracy: 0.9548
# Epoch 20: val_loss improved from 0.56741 to 0.54663, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 130s 34ms/step - categorical_accuracy: 0.9328 - loss: 0.3180 - top_3_categorical_accuracy: 0.9594 - w_categorical_accuracy: 0.8896 - w_top_3_categorical_accuracy: 0.9548 - val_categorical_accuracy: 0.8873 - val_loss: 0.5466 - val_top_3_categorical_accuracy: 0.9165 - val_w_categorical_accuracy: 0.8873 - val_w_top_3_categorical_accuracy: 0.9165 - learning_rate: 1.0000e-05
# Epoch 21/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9356 - loss: 0.3315 - top_3_categorical_accuracy: 0.9653 - w_categorical_accuracy: 0.8785 - w_top_3_categorical_accuracy: 0.9507
# Epoch 21: val_loss improved from 0.54663 to 0.53470, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9356 - loss: 0.3315 - top_3_categorical_accuracy: 0.9653 - w_categorical_accuracy: 0.8785 - w_top_3_categorical_accuracy: 0.9507 - val_categorical_accuracy: 0.8898 - val_loss: 0.5347 - val_top_3_categorical_accuracy: 0.9213 - val_w_categorical_accuracy: 0.8898 - val_w_top_3_categorical_accuracy: 0.9213 - learning_rate: 1.0000e-05
# Epoch 22/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9376 - loss: 0.3238 - top_3_categorical_accuracy: 0.9678 - w_categorical_accuracy: 0.8761 - w_top_3_categorical_accuracy: 0.9524
# Epoch 22: val_loss improved from 0.53470 to 0.53046, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9376 - loss: 0.3237 - top_3_categorical_accuracy: 0.9678 - w_categorical_accuracy: 0.8761 - w_top_3_categorical_accuracy: 0.9524 - val_categorical_accuracy: 0.8917 - val_loss: 0.5305 - val_top_3_categorical_accuracy: 0.9220 - val_w_categorical_accuracy: 0.8917 - val_w_top_3_categorical_accuracy: 0.9220 - learning_rate: 1.0000e-05
# Epoch 23/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9393 - loss: 0.3152 - top_3_categorical_accuracy: 0.9686 - w_categorical_accuracy: 0.8832 - w_top_3_categorical_accuracy: 0.9623
# Epoch 23: val_loss improved from 0.53046 to 0.52458, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9393 - loss: 0.3152 - top_3_categorical_accuracy: 0.9686 - w_categorical_accuracy: 0.8832 - w_top_3_categorical_accuracy: 0.9623 - val_categorical_accuracy: 0.8942 - val_loss: 0.5246 - val_top_3_categorical_accuracy: 0.9235 - val_w_categorical_accuracy: 0.8942 - val_w_top_3_categorical_accuracy: 0.9235 - learning_rate: 1.0000e-05
# Epoch 24/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9403 - loss: 0.3010 - top_3_categorical_accuracy: 0.9702 - w_categorical_accuracy: 0.8841 - w_top_3_categorical_accuracy: 0.9687
# Epoch 24: val_loss improved from 0.52458 to 0.52061, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9403 - loss: 0.3010 - top_3_categorical_accuracy: 0.9702 - w_categorical_accuracy: 0.8841 - w_top_3_categorical_accuracy: 0.9687 - val_categorical_accuracy: 0.8957 - val_loss: 0.5206 - val_top_3_categorical_accuracy: 0.9233 - val_w_categorical_accuracy: 0.8957 - val_w_top_3_categorical_accuracy: 0.9233 - learning_rate: 1.0000e-05
# Epoch 25/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9423 - loss: 0.3000 - top_3_categorical_accuracy: 0.9682 - w_categorical_accuracy: 0.8792 - w_top_3_categorical_accuracy: 0.9473
# Epoch 25: val_loss improved from 0.52061 to 0.51315, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9423 - loss: 0.3000 - top_3_categorical_accuracy: 0.9682 - w_categorical_accuracy: 0.8792 - w_top_3_categorical_accuracy: 0.9473 - val_categorical_accuracy: 0.8969 - val_loss: 0.5132 - val_top_3_categorical_accuracy: 0.9246 - val_w_categorical_accuracy: 0.8969 - val_w_top_3_categorical_accuracy: 0.9246 - learning_rate: 1.0000e-05
# Epoch 26/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9434 - loss: 0.2655 - top_3_categorical_accuracy: 0.9697 - w_categorical_accuracy: 0.9015 - w_top_3_categorical_accuracy: 0.9662
# Epoch 26: val_loss improved from 0.51315 to 0.51146, saving model to saves/feature_user/model.keras
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9434 - loss: 0.2655 - top_3_categorical_accuracy: 0.9697 - w_categorical_accuracy: 0.9015 - w_top_3_categorical_accuracy: 0.9662 - val_categorical_accuracy: 0.8978 - val_loss: 0.5115 - val_top_3_categorical_accuracy: 0.9384 - val_w_categorical_accuracy: 0.8978 - val_w_top_3_categorical_accuracy: 0.9384 - learning_rate: 1.0000e-05
# Epoch 27/200
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9439 - loss: 0.3015 - top_3_categorical_accuracy: 0.9695 - w_categorical_accuracy: 0.8760 - w_top_3_categorical_accuracy: 0.9637
# Epoch 27: val_loss did not improve from 0.51146
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9439 - loss: 0.3015 - top_3_categorical_accuracy: 0.9695 - w_categorical_accuracy: 0.8760 - w_top_3_categorical_accuracy: 0.9637 - val_categorical_accuracy: 0.8972 - val_loss: 0.5233 - val_top_3_categorical_accuracy: 0.9252 - val_w_categorical_accuracy: 0.8972 - val_w_top_3_categorical_accuracy: 0.9252 - learning_rate: 1.0000e-05
# Epoch 28/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9439 - loss: 0.3015 - top_3_categorical_accuracy: 0.9727 - w_categorical_accuracy: 0.8759 - w_top_3_categorical_accuracy: 0.9597
# Epoch 28: val_loss did not improve from 0.51146
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9439 - loss: 0.3015 - top_3_categorical_accuracy: 0.9727 - w_categorical_accuracy: 0.8759 - w_top_3_categorical_accuracy: 0.9597 - val_categorical_accuracy: 0.8990 - val_loss: 0.5261 - val_top_3_categorical_accuracy: 0.9256 - val_w_categorical_accuracy: 0.8990 - val_w_top_3_categorical_accuracy: 0.9256 - learning_rate: 1.0000e-05
# Epoch 29/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9451 - loss: 0.2949 - top_3_categorical_accuracy: 0.9724 - w_categorical_accuracy: 0.8809 - w_top_3_categorical_accuracy: 0.9545
# Epoch 29: val_loss did not improve from 0.51146
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9451 - loss: 0.2949 - top_3_categorical_accuracy: 0.9724 - w_categorical_accuracy: 0.8809 - w_top_3_categorical_accuracy: 0.9545 - val_categorical_accuracy: 0.9010 - val_loss: 0.5157 - val_top_3_categorical_accuracy: 0.9260 - val_w_categorical_accuracy: 0.9010 - val_w_top_3_categorical_accuracy: 0.9260 - learning_rate: 1.0000e-05
# Epoch 30/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9467 - loss: 0.2685 - top_3_categorical_accuracy: 0.9685 - w_categorical_accuracy: 0.8967 - w_top_3_categorical_accuracy: 0.9675
# Epoch 30: val_loss did not improve from 0.51146
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 132s 34ms/step - categorical_accuracy: 0.9467 - loss: 0.2685 - top_3_categorical_accuracy: 0.9685 - w_categorical_accuracy: 0.8967 - w_top_3_categorical_accuracy: 0.9675 - val_categorical_accuracy: 0.9008 - val_loss: 0.5156 - val_top_3_categorical_accuracy: 0.9260 - val_w_categorical_accuracy: 0.9008 - val_w_top_3_categorical_accuracy: 0.9260 - learning_rate: 1.0000e-06
# Epoch 31/200
# 3863/3864 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - categorical_accuracy: 0.9460 - loss: 0.2799 - top_3_categorical_accuracy: 0.9684 - w_categorical_accuracy: 0.8900 - w_top_3_categorical_accuracy: 0.9710
# Epoch 31: val_loss did not improve from 0.51146
# 3864/3864 ━━━━━━━━━━━━━━━━━━━━ 131s 34ms/step - categorical_accuracy: 0.9460 - loss: 0.2799 - top_3_categorical_accuracy: 0.9684 - w_categorical_accuracy: 0.8900 - w_top_3_categorical_accuracy: 0.9710 - val_categorical_accuracy: 0.9009 - val_loss: 0.5159 - val_top_3_categorical_accuracy: 0.9259 - val_w_categorical_accuracy: 0.9009 - val_w_top_3_categorical_accuracy: 0.9259 - learning_rate: 1.0000e-06
# Epoch 31: early stopping

# %%
log = pd.read_csv(log_path)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20*cm, 15*cm))

ax1.plot(log['epoch'], log['categorical_accuracy'], label='categorical_accuracy', color='red')
ax1.plot(log['epoch'], log['val_categorical_accuracy'], label='val_categorical_accuracy', color='orange')
ax1.plot(log['epoch'], log[f'top_{top_k}_categorical_accuracy'], label=f'top_{top_k}_categorical_accuracy', color='royalblue')
ax1.plot(log['epoch'], log[f'val_top_{top_k}_categorical_accuracy'], label=f'val_top_{top_k}_categorical_accuracy', color='navy')
ax1.set_title('training metrics')
ax1.set_xlabel('epoch')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=1)  # Legend below the plot

ax2.plot(log['epoch'], log['loss'], label='loss')
ax2.plot(log['epoch'], log['val_loss'], label='val_loss')
ax2.set_title('loss')
ax2.set_xlabel('epoch')
ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2), ncol=2)  # Legend below the plot

fig.tight_layout(rect=[0, 0.1, 1, 1])

plt.savefig(f'{checkpoint_path}/metrics_loss.svg')
plt.show()

# %%
# load old model, if needed
if model is None:
    model = load_model(model_path)

# %%
# evaluate model
score = model.evaluate(x=Generator(X_test, y_test, 128, max_sequence_length))
print(f'Test loss: {score[0]}')
print(f'Test accuracy: {score[1]}')
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 8s 19ms/step - categorical_accuracy: 0.9307 - loss: 0.2477 - top_3_categorical_accuracy: 0.9585 - w_categorical_accuracy: 0.9307 - w_top_3_categorical_accuracy: 0.9585
# Test loss: 0.24655874073505402
# Test accuracy: 0.9311881065368652

# %%
# print classification report
y_pred = model.predict(x=Generator(X_test, y_test, 128, max_sequence_length))
y_pred = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

report = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan)
report_dict = classification_report(y_true, y_pred, target_names=distinct_labels, zero_division=np.nan, output_dict=True)

print(report)

# save classification report to file
with open(f'{checkpoint_path}/classification_report.txt', 'w') as f:
    json.dump(report_dict, f)
# Out:
# 407/407 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
#                  precision    recall  f1-score   support
#
#       adjkerntz       0.46      1.00      0.63        11
#          alpine       0.84      0.93      0.88       560
#           anvil       0.53      0.58      0.55       378
#           atrun       1.00      1.00      1.00       237
#             awk       1.00      1.00      1.00         5
#        basename        nan      0.00      0.00         2
#            bash       1.00      0.98      0.99     12512
#             cat       0.89      0.92      0.91        26
#         cleanup       0.25      0.94      0.40       276
#             cmp       0.83      1.00      0.91         5
#              cp       0.81      1.00      0.90        30
#            cron       1.00      1.00      1.00       624
#            date       0.99      1.00      1.00      1218
#              dd       0.99      0.99      0.99       125
#        dhclient       0.00      0.00      0.00        17
#           dmesg       0.88      1.00      0.94        15
#           egrep       1.00      0.50      0.67         2
#            expr        nan      0.00      0.00         2
#            find       1.00      1.00      1.00      4006
#         fortune       1.00      1.00      1.00        91
#            grep       0.44      0.80      0.57         5
#            head       0.99      1.00      1.00      1219
#        hostname       0.56      1.00      0.71        10
#           imapd       0.98      0.83      0.90      2469
#           inetd       1.00      1.00      1.00       291
#            kill       1.00      1.00      1.00         2
#            less       0.01      0.33      0.03         3
#           local       0.93      0.57      0.71       868
#           lockf       0.33      1.00      0.50         3
#              ls       0.29      0.58      0.39        12
#            lsof       1.00      0.98      0.99      8568
#            mail       1.00      0.50      0.67         2
#     mailwrapper       0.67      0.67      0.67         3
#          master       0.78      1.00      0.88       580
#           mkdir       0.90      1.00      0.95        18
#          mktemp       0.55      1.00      0.71         6
#           mlock       1.00      1.00      1.00       506
#           mount       0.50      1.00      0.67         2
#              mv       0.99      1.00      1.00       860
#         netstat       0.73      0.93      0.82        58
#       newsyslog       0.94      0.89      0.91        18
#          pickup       0.45      0.83      0.58       143
#             pkg       0.98      0.72      0.83      1701
#        proxymap       0.92      0.49      0.64       331
#              ps       0.31      1.00      0.48         5
#       python2.7       0.00      0.00      0.00       841
#       resizewin       0.98      1.00      0.99        91
#              rm       0.31      0.64      0.41        36
#           route       0.64      1.00      0.78         7
#             sed       0.00      0.00      0.00         2
#        sendmail       0.25      0.86      0.39        21
#              sh       0.99      0.89      0.94      1987
#           sleep       1.00      1.00      1.00      4889
#           smtpd       0.91      0.81      0.86       818
#            sort       0.14      1.00      0.25         1
#            sshd       0.95      0.99      0.97       427
#            sudo       0.51      1.00      0.68        26
#          sysctl       0.99      1.00      1.00       129
#             tee       0.60      1.00      0.75         6
#             top       0.99      0.99      0.99      1913
# trivial-rewrite       0.34      0.51      0.41       377
#             tty        nan      0.00      0.00         2
#          unlink       0.96      1.00      0.98       123
#          uptime       1.00      1.00      1.00        14
#          vmstat       1.00      1.00      1.00      2468
#              wc       0.54      1.00      0.70         7
#            wget       0.61      0.96      0.74        74
#
#        accuracy                           0.93     52084
#       macro avg       0.73      0.82      0.72     52084
#    weighted avg       0.95      0.93      0.94     52084

# %%
# print confusion matrix
# labels explicitly set, because current model may not predict all labels
conf_matrix = confusion_matrix(y_true, y_pred, labels=range(labels_cardinality), normalize='true')

# Replace all NaN values with 0
conf_matrix = np.nan_to_num(conf_matrix)

# Verify the distinct labels align correctly
distinct_labels = [labels_map[i] for i in range(labels_cardinality)]

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(20*cm, 20*cm))

ax.matshow(conf_matrix, cmap='cividis', aspect='auto')

# Set class names on axes
ax.set_xticks(range(len(distinct_labels)))
ax.set_yticks(range(len(distinct_labels)))
ax.set_xticklabels(distinct_labels, rotation=90, fontsize=8)
ax.set_yticklabels(distinct_labels, fontsize=8)

# Set axis labels "predicted" and "actual"
ax.set_xlabel('predicted label')
ax.set_ylabel('true label')
# y-axis label right side
ax.yaxis.set_label_position('right')

# set figsize
plt.savefig(f'{checkpoint_path}/confusion_matrix.svg')
plt.show()

# %%
unique_in_y_pred = [ labels_map[i] for i in np.unique(y_pred) ]
#print("Unique labels in y_pred:", unique_in_y_pred)

unique_not_in_y_pred = [ label for label in distinct_labels if label not in unique_in_y_pred ]
print("Unique labels not in y_pred:", unique_not_in_y_pred)
# Out:
# Unique labels not in y_pred: ['basename', 'expr', 'tty']
