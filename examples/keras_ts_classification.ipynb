# %% [markdown]
# https://keras.io/examples/timeseries/timeseries_classification_from_scratch/

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2024-06-07 11:30:37.312210: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-07 11:30:38.107309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %%
num_classes = len(np.unique(y_train))
num_classes
# Out:
# 2

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# 2024-06-07 11:30:39.941893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 641 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:17:00.0, compute capability: 7.5
# 2024-06-07 11:30:39.942636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9504 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:65:00.0, compute capability: 7.5
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.virtualenvs/models/lib/python3.12/site-packages/pydot/core.py:1753, in Dot.create(self, prog, format, encoding)
#    1752 try:
# -> 1753     stdout_data, stderr_data, process = call_graphviz(
#    1754         program=prog,
#    1755         arguments=arguments,
#    1756         working_dir=tmp_dir,
#    1757     )
#    1758 except OSError as e:
#
# File ~/.virtualenvs/models/lib/python3.12/site-packages/pydot/core.py:133, in call_graphviz(program, arguments, working_dir, **kwargs)
#     131 program_with_args = [program] + arguments
# --> 133 process = subprocess.Popen(
#     134     program_with_args,
#     135     env=env,
#     136     cwd=working_dir,
#     137     shell=False,
#     138     stderr=subprocess.PIPE,
#     139     stdout=subprocess.PIPE,
#     140     **kwargs,
#     141 )
#     142 stdout_data, stderr_data = process.communicate()
#
# File /usr/lib/python3.12/subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.12/subprocess.py:1955, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1954 if err_filename is not None:
# -> 1955     raise child_exception_type(errno_num, err_msg, err_filename)
#    1956 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dot'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/.virtualenvs/models/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:37, in check_graphviz()
#      34 try:
#      35     # Attempt to create an image of a blank graph
#      36     # to check the pydot/graphviz installation.
# ---> 37     pydot.Dot.create(pydot.Dot())
#      38     return True
#
# File ~/.virtualenvs/models/lib/python3.12/site-packages/pydot/core.py:1762, in Dot.create(self, prog, format, encoding)
#    1761     args[1] = '"{prog}" not found in path.'.format(prog=prog)
# -> 1762     raise OSError(*args)
#    1763 else:
#
# FileNotFoundError: [Errno 2] "dot" not found in path.
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 24
#      20     return keras.models.Model(inputs=input_layer, outputs=output_layer)
#      23 model = make_model(input_shape=x_train.shape[1:])
# ---> 24 keras.utils.plot_model(model, show_shapes=True)
#
# File ~/.virtualenvs/models/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:416, in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, show_layer_activations, show_trainable, **kwargs)
#     414     else:
#     415         raise ImportError(message)
# --> 416 if not check_graphviz():
#     417     message = (
#     418         "You must install graphviz "
#     419         "(see instructions at https://graphviz.gitlab.io/download/) "
#     420         "for `plot_model` to work."
#     421     )
#     422     if "IPython.core.magics.namespace" in sys.modules:
#     423         # We don't raise an exception here in order to avoid crashing
#     424         # notebook tests where graphviz is not available.
#
# File ~/.virtualenvs/models/lib/python3.12/site-packages/keras/src/utils/model_visualization.py:39, in check_graphviz()
#      37     pydot.Dot.create(pydot.Dot())
#      38     return True
# ---> 39 except (OSError, pydot.InvocationException):
#      40     return False
#
# AttributeError: module 'pydot' has no attribute 'InvocationException'

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1717752689.045921  141205 service.cc:145] XLA service 0x748618005930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1717752689.045949  141205 service.cc:153]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# I0000 00:00:1717752689.045952  141205 service.cc:153]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2024-06-07 11:31:29.093084: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-06-07 11:31:29.299667: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8902
# 33/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6609 - sparse_categorical_accuracy: 0.6108
# I0000 00:00:1717752690.678975  141205 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - loss: 0.6187 - sparse_categorical_accuracy: 0.6551 - val_loss: 0.8066 - val_sparse_categorical_accuracy: 0.4951 - learning_rate: 0.0010
# Epoch 2/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4571 - sparse_categorical_accuracy: 0.7772 - val_loss: 0.8925 - val_sparse_categorical_accuracy: 0.4951 - learning_rate: 0.0010
# Epoch 3/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4279 - sparse_categorical_accuracy: 0.8015 - val_loss: 0.8128 - val_sparse_categorical_accuracy: 0.4951 - learning_rate: 0.0010
# Epoch 4/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3998 - sparse_categorical_accuracy: 0.8058 - val_loss: 0.7109 - val_sparse_categorical_accuracy: 0.5589 - learning_rate: 0.0010
# Epoch 5/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4154 - sparse_categorical_accuracy: 0.7907 - val_loss: 0.6178 - val_sparse_categorical_accuracy: 0.5881 - learning_rate: 0.0010
# Epoch 6/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3899 - sparse_categorical_accuracy: 0.8018 - val_loss: 0.5551 - val_sparse_categorical_accuracy: 0.6560 - learning_rate: 0.0010
# Epoch 7/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4001 - sparse_categorical_accuracy: 0.7960 - val_loss: 0.4398 - val_sparse_categorical_accuracy: 0.7864 - learning_rate: 0.0010
# Epoch 8/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3684 - sparse_categorical_accuracy: 0.8138 - val_loss: 0.5077 - val_sparse_categorical_accuracy: 0.7434 - learning_rate: 0.0010
# Epoch 9/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3963 - sparse_categorical_accuracy: 0.7998 - val_loss: 0.3967 - val_sparse_categorical_accuracy: 0.8058 - learning_rate: 0.0010
# Epoch 10/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3760 - sparse_categorical_accuracy: 0.8067 - val_loss: 0.3825 - val_sparse_categorical_accuracy: 0.8225 - learning_rate: 0.0010
# Epoch 11/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3603 - sparse_categorical_accuracy: 0.8266 - val_loss: 0.3659 - val_sparse_categorical_accuracy: 0.8225 - learning_rate: 0.0010
# Epoch 12/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3679 - sparse_categorical_accuracy: 0.8248 - val_loss: 0.4628 - val_sparse_categorical_accuracy: 0.7393 - learning_rate: 0.0010
# Epoch 13/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3607 - sparse_categorical_accuracy: 0.8341 - val_loss: 0.4854 - val_sparse_categorical_accuracy: 0.7309 - learning_rate: 0.0010
# Epoch 14/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3541 - sparse_categorical_accuracy: 0.8277 - val_loss: 0.3518 - val_sparse_categorical_accuracy: 0.8447 - learning_rate: 0.0010
# Epoch 15/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3581 - sparse_categorical_accuracy: 0.8290 - val_loss: 0.5193 - val_sparse_categorical_accuracy: 0.7240 - learning_rate: 0.0010
# Epoch 16/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3514 - sparse_categorical_accuracy: 0.8359 - val_loss: 0.3665 - val_sparse_categorical_accuracy: 0.8183 - learning_rate: 0.0010
# Epoch 17/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8308 - val_loss: 0.4274 - val_sparse_categorical_accuracy: 0.7836 - learning_rate: 0.0010
# Epoch 18/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3366 - sparse_categorical_accuracy: 0.8415 - val_loss: 0.4387 - val_sparse_categorical_accuracy: 0.7725 - learning_rate: 0.0010
# Epoch 19/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3410 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.3369 - val_sparse_categorical_accuracy: 0.8488 - learning_rate: 0.0010
# Epoch 20/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3213 - sparse_categorical_accuracy: 0.8546 - val_loss: 0.3242 - val_sparse_categorical_accuracy: 0.8641 - learning_rate: 0.0010
# Epoch 21/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3332 - sparse_categorical_accuracy: 0.8532 - val_loss: 0.3266 - val_sparse_categorical_accuracy: 0.8641 - learning_rate: 0.0010
# Epoch 22/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3108 - sparse_categorical_accuracy: 0.8527 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.8128 - learning_rate: 0.0010
# Epoch 23/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3141 - sparse_categorical_accuracy: 0.8636 - val_loss: 0.3075 - val_sparse_categorical_accuracy: 0.8571 - learning_rate: 0.0010
# Epoch 24/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3022 - sparse_categorical_accuracy: 0.8689 - val_loss: 0.3323 - val_sparse_categorical_accuracy: 0.8641 - learning_rate: 0.0010
# Epoch 25/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3069 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.3046 - val_sparse_categorical_accuracy: 0.8877 - learning_rate: 0.0010
# Epoch 26/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2945 - sparse_categorical_accuracy: 0.8767 - val_loss: 0.4167 - val_sparse_categorical_accuracy: 0.7809 - learning_rate: 0.0010
# Epoch 27/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2862 - sparse_categorical_accuracy: 0.8787 - val_loss: 0.2968 - val_sparse_categorical_accuracy: 0.8627 - learning_rate: 0.0010
# Epoch 28/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2928 - sparse_categorical_accuracy: 0.8686 - val_loss: 0.3834 - val_sparse_categorical_accuracy: 0.7933 - learning_rate: 0.0010
# Epoch 29/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2915 - sparse_categorical_accuracy: 0.8784 - val_loss: 0.3294 - val_sparse_categorical_accuracy: 0.8391 - learning_rate: 0.0010
# Epoch 30/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2825 - sparse_categorical_accuracy: 0.8833 - val_loss: 0.5671 - val_sparse_categorical_accuracy: 0.7060 - learning_rate: 0.0010
# Epoch 31/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3024 - sparse_categorical_accuracy: 0.8611 - val_loss: 0.4089 - val_sparse_categorical_accuracy: 0.7906 - learning_rate: 0.0010
# Epoch 32/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2621 - sparse_categorical_accuracy: 0.8968 - val_loss: 0.2811 - val_sparse_categorical_accuracy: 0.8904 - learning_rate: 0.0010
# Epoch 33/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2587 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.6687 - val_sparse_categorical_accuracy: 0.6865 - learning_rate: 0.0010
# Epoch 34/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2926 - sparse_categorical_accuracy: 0.8797 - val_loss: 0.4436 - val_sparse_categorical_accuracy: 0.7684 - learning_rate: 0.0010
# Epoch 35/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.9100 - val_loss: 0.4378 - val_sparse_categorical_accuracy: 0.7795 - learning_rate: 0.0010
# Epoch 36/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2516 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.2796 - val_sparse_categorical_accuracy: 0.8849 - learning_rate: 0.0010
# Epoch 37/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2518 - sparse_categorical_accuracy: 0.9004 - val_loss: 0.2914 - val_sparse_categorical_accuracy: 0.8738 - learning_rate: 0.0010
# Epoch 38/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2552 - sparse_categorical_accuracy: 0.8931 - val_loss: 0.2570 - val_sparse_categorical_accuracy: 0.8890 - learning_rate: 0.0010
# Epoch 39/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2750 - sparse_categorical_accuracy: 0.8846 - val_loss: 0.5126 - val_sparse_categorical_accuracy: 0.7448 - learning_rate: 0.0010
# Epoch 40/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2777 - sparse_categorical_accuracy: 0.8772 - val_loss: 0.3269 - val_sparse_categorical_accuracy: 0.8530 - learning_rate: 0.0010
# Epoch 41/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2437 - sparse_categorical_accuracy: 0.9019 - val_loss: 0.4142 - val_sparse_categorical_accuracy: 0.7920 - learning_rate: 0.0010
# Epoch 42/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2582 - sparse_categorical_accuracy: 0.8907 - val_loss: 0.4650 - val_sparse_categorical_accuracy: 0.7920 - learning_rate: 0.0010
# Epoch 43/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2514 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.2824 - val_sparse_categorical_accuracy: 0.8696 - learning_rate: 0.0010
# Epoch 44/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2358 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.8863 - learning_rate: 0.0010
# Epoch 45/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2411 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3480 - val_sparse_categorical_accuracy: 0.8266 - learning_rate: 0.0010
# Epoch 46/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2544 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.2515 - val_sparse_categorical_accuracy: 0.8849 - learning_rate: 0.0010
# Epoch 47/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2318 - sparse_categorical_accuracy: 0.9098 - val_loss: 0.2559 - val_sparse_categorical_accuracy: 0.8890 - learning_rate: 0.0010
# Epoch 48/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2452 - sparse_categorical_accuracy: 0.9032 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8405 - learning_rate: 0.0010
# Epoch 49/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2558 - sparse_categorical_accuracy: 0.8921 - val_loss: 0.2733 - val_sparse_categorical_accuracy: 0.8669 - learning_rate: 0.0010
# Epoch 50/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2218 - sparse_categorical_accuracy: 0.9048 - val_loss: 0.2324 - val_sparse_categorical_accuracy: 0.9112 - learning_rate: 0.0010
# Epoch 51/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2239 - sparse_categorical_accuracy: 0.9150 - val_loss: 0.3947 - val_sparse_categorical_accuracy: 0.7975 - learning_rate: 0.0010
# Epoch 52/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2390 - sparse_categorical_accuracy: 0.9048 - val_loss: 0.3008 - val_sparse_categorical_accuracy: 0.8571 - learning_rate: 0.0010
# Epoch 53/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.2304 - val_sparse_categorical_accuracy: 0.9196 - learning_rate: 0.0010
# Epoch 54/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2334 - sparse_categorical_accuracy: 0.9113 - val_loss: 0.3006 - val_sparse_categorical_accuracy: 0.8516 - learning_rate: 0.0010
# Epoch 55/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2391 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.5960 - val_sparse_categorical_accuracy: 0.7531 - learning_rate: 0.0010
# Epoch 56/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2311 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.3725 - val_sparse_categorical_accuracy: 0.8239 - learning_rate: 0.0010
# Epoch 57/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2257 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.2435 - val_sparse_categorical_accuracy: 0.8849 - learning_rate: 0.0010
# Epoch 58/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9092 - val_loss: 0.2673 - val_sparse_categorical_accuracy: 0.8585 - learning_rate: 0.0010
# Epoch 59/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2178 - sparse_categorical_accuracy: 0.9101 - val_loss: 0.2197 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 0.0010
# Epoch 60/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2180 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.3783 - val_sparse_categorical_accuracy: 0.8169 - learning_rate: 0.0010
# Epoch 61/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2205 - sparse_categorical_accuracy: 0.9130 - val_loss: 0.2394 - val_sparse_categorical_accuracy: 0.8877 - learning_rate: 0.0010
# Epoch 62/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2180 - sparse_categorical_accuracy: 0.9061 - val_loss: 0.2459 - val_sparse_categorical_accuracy: 0.8849 - learning_rate: 0.0010
# Epoch 63/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2029 - sparse_categorical_accuracy: 0.9219 - val_loss: 0.2507 - val_sparse_categorical_accuracy: 0.8974 - learning_rate: 0.0010
# Epoch 64/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2116 - sparse_categorical_accuracy: 0.9106 - val_loss: 0.2331 - val_sparse_categorical_accuracy: 0.9071 - learning_rate: 0.0010
# Epoch 65/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1910 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.2128 - val_sparse_categorical_accuracy: 0.9182 - learning_rate: 0.0010
# Epoch 66/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1864 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.6871 - val_sparse_categorical_accuracy: 0.7032 - learning_rate: 0.0010
# Epoch 67/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1805 - sparse_categorical_accuracy: 0.9338 - val_loss: 0.2641 - val_sparse_categorical_accuracy: 0.8863 - learning_rate: 0.0010
# Epoch 68/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1842 - sparse_categorical_accuracy: 0.9309 - val_loss: 0.2360 - val_sparse_categorical_accuracy: 0.8974 - learning_rate: 0.0010
# Epoch 69/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1572 - sparse_categorical_accuracy: 0.9424 - val_loss: 0.1977 - val_sparse_categorical_accuracy: 0.9417 - learning_rate: 0.0010
# Epoch 70/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1837 - sparse_categorical_accuracy: 0.9284 - val_loss: 0.2962 - val_sparse_categorical_accuracy: 0.8447 - learning_rate: 0.0010
# Epoch 71/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1859 - sparse_categorical_accuracy: 0.9324 - val_loss: 0.1697 - val_sparse_categorical_accuracy: 0.9445 - learning_rate: 0.0010
# Epoch 72/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1640 - sparse_categorical_accuracy: 0.9378 - val_loss: 0.1630 - val_sparse_categorical_accuracy: 0.9487 - learning_rate: 0.0010
# Epoch 73/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1404 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.6858 - val_sparse_categorical_accuracy: 0.6976 - learning_rate: 0.0010
# Epoch 74/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1436 - sparse_categorical_accuracy: 0.9545 - val_loss: 0.7397 - val_sparse_categorical_accuracy: 0.7254 - learning_rate: 0.0010
# Epoch 75/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1496 - sparse_categorical_accuracy: 0.9525 - val_loss: 0.1576 - val_sparse_categorical_accuracy: 0.9473 - learning_rate: 0.0010
# Epoch 76/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1353 - sparse_categorical_accuracy: 0.9467 - val_loss: 0.7719 - val_sparse_categorical_accuracy: 0.7198 - learning_rate: 0.0010
# Epoch 77/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9586 - val_loss: 2.1678 - val_sparse_categorical_accuracy: 0.6463 - learning_rate: 0.0010
# Epoch 78/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1233 - sparse_categorical_accuracy: 0.9633 - val_loss: 1.3468 - val_sparse_categorical_accuracy: 0.6255 - learning_rate: 0.0010
# Epoch 79/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1361 - sparse_categorical_accuracy: 0.9490 - val_loss: 0.4034 - val_sparse_categorical_accuracy: 0.8155 - learning_rate: 0.0010
# Epoch 80/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1288 - sparse_categorical_accuracy: 0.9522 - val_loss: 0.3834 - val_sparse_categorical_accuracy: 0.8141 - learning_rate: 0.0010
# Epoch 81/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.1970 - val_sparse_categorical_accuracy: 0.9154 - learning_rate: 0.0010
# Epoch 82/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1156 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.1333 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 0.0010
# Epoch 83/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1094 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.4889 - val_sparse_categorical_accuracy: 0.7490 - learning_rate: 0.0010
# Epoch 84/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1182 - sparse_categorical_accuracy: 0.9599 - val_loss: 0.1508 - val_sparse_categorical_accuracy: 0.9501 - learning_rate: 0.0010
# Epoch 85/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1058 - sparse_categorical_accuracy: 0.9621 - val_loss: 0.1422 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 0.0010
# Epoch 86/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.2033 - val_sparse_categorical_accuracy: 0.9126 - learning_rate: 0.0010
# Epoch 87/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1077 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.7248 - val_sparse_categorical_accuracy: 0.7240 - learning_rate: 0.0010
# Epoch 88/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1074 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.1130 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 0.0010
# Epoch 89/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1230 - sparse_categorical_accuracy: 0.9595 - val_loss: 0.2902 - val_sparse_categorical_accuracy: 0.8710 - learning_rate: 0.0010
# Epoch 90/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9731 - val_loss: 0.5977 - val_sparse_categorical_accuracy: 0.7490 - learning_rate: 0.0010
# Epoch 91/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1108 - sparse_categorical_accuracy: 0.9596 - val_loss: 0.3297 - val_sparse_categorical_accuracy: 0.8599 - learning_rate: 0.0010
# Epoch 92/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1233 - sparse_categorical_accuracy: 0.9498 - val_loss: 0.1525 - val_sparse_categorical_accuracy: 0.9501 - learning_rate: 0.0010
# Epoch 93/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.1997 - val_sparse_categorical_accuracy: 0.9237 - learning_rate: 0.0010
# Epoch 94/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9630 - val_loss: 2.9187 - val_sparse_categorical_accuracy: 0.5215 - learning_rate: 0.0010
# Epoch 95/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1131 - sparse_categorical_accuracy: 0.9643 - val_loss: 0.4304 - val_sparse_categorical_accuracy: 0.8197 - learning_rate: 0.0010
# Epoch 96/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1067 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.3651 - val_sparse_categorical_accuracy: 0.8516 - learning_rate: 0.0010
# Epoch 97/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.8070 - val_sparse_categorical_accuracy: 0.6921 - learning_rate: 0.0010
# Epoch 98/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0979 - sparse_categorical_accuracy: 0.9641 - val_loss: 0.1079 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 0.0010
# Epoch 99/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0901 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.2764 - val_sparse_categorical_accuracy: 0.8779 - learning_rate: 0.0010
# Epoch 100/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9616 - val_loss: 0.7476 - val_sparse_categorical_accuracy: 0.7295 - learning_rate: 0.0010
# Epoch 101/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.1305 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 0.0010
# Epoch 102/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9682 - val_loss: 0.1417 - val_sparse_categorical_accuracy: 0.9515 - learning_rate: 0.0010
# Epoch 103/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.1041 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 0.0010
# Epoch 104/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0994 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.2933 - val_sparse_categorical_accuracy: 0.8752 - learning_rate: 0.0010
# Epoch 105/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0925 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.1905 - val_sparse_categorical_accuracy: 0.9265 - learning_rate: 0.0010
# Epoch 106/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1078 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.1562 - val_sparse_categorical_accuracy: 0.9459 - learning_rate: 0.0010
# Epoch 107/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1060 - sparse_categorical_accuracy: 0.9612 - val_loss: 0.3595 - val_sparse_categorical_accuracy: 0.8558 - learning_rate: 0.0010
# Epoch 108/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0849 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.1107 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 0.0010
# Epoch 109/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0982 - sparse_categorical_accuracy: 0.9645 - val_loss: 0.1351 - val_sparse_categorical_accuracy: 0.9501 - learning_rate: 0.0010
# Epoch 110/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0965 - sparse_categorical_accuracy: 0.9652 - val_loss: 1.3378 - val_sparse_categorical_accuracy: 0.6810 - learning_rate: 0.0010
# Epoch 111/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0997 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.1536 - val_sparse_categorical_accuracy: 0.9362 - learning_rate: 0.0010
# Epoch 112/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0855 - sparse_categorical_accuracy: 0.9695 - val_loss: 0.1476 - val_sparse_categorical_accuracy: 0.9431 - learning_rate: 0.0010
# Epoch 113/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1340 - val_sparse_categorical_accuracy: 0.9515 - learning_rate: 0.0010
# Epoch 114/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0895 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.1115 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 0.0010
# Epoch 115/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9673 - val_loss: 0.3979 - val_sparse_categorical_accuracy: 0.8350 - learning_rate: 0.0010
# Epoch 116/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9718 - val_loss: 1.4353 - val_sparse_categorical_accuracy: 0.6699 - learning_rate: 0.0010
# Epoch 117/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0888 - sparse_categorical_accuracy: 0.9694 - val_loss: 1.0768 - val_sparse_categorical_accuracy: 0.7198 - learning_rate: 0.0010
# Epoch 118/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0895 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1774 - val_sparse_categorical_accuracy: 0.9279 - learning_rate: 0.0010
# Epoch 119/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1083 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.1203 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 0.0010
# Epoch 120/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9724 - val_loss: 0.1360 - val_sparse_categorical_accuracy: 0.9459 - learning_rate: 0.0010
# Epoch 121/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0790 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.1220 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 0.0010
# Epoch 122/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0773 - sparse_categorical_accuracy: 0.9771 - val_loss: 0.2556 - val_sparse_categorical_accuracy: 0.8974 - learning_rate: 0.0010
# Epoch 123/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1066 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.1085 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 0.0010
# Epoch 124/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1551 - val_sparse_categorical_accuracy: 0.9459 - learning_rate: 5.0000e-04
# Epoch 125/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0657 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1427 - val_sparse_categorical_accuracy: 0.9376 - learning_rate: 5.0000e-04
# Epoch 126/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0937 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.1014 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 5.0000e-04
# Epoch 127/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0779 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 5.0000e-04
# Epoch 128/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0619 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.1008 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 5.0000e-04
# Epoch 129/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0755 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 5.0000e-04
# Epoch 130/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0798 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.1239 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 5.0000e-04
# Epoch 131/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0745 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9612 - learning_rate: 5.0000e-04
# Epoch 132/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 5.0000e-04
# Epoch 133/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9764 - learning_rate: 5.0000e-04
# Epoch 134/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9804 - val_loss: 0.1127 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 5.0000e-04
# Epoch 135/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9728 - val_loss: 0.1249 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 5.0000e-04
# Epoch 136/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0706 - sparse_categorical_accuracy: 0.9780 - val_loss: 0.1117 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 5.0000e-04
# Epoch 137/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0738 - sparse_categorical_accuracy: 0.9811 - val_loss: 0.1065 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 5.0000e-04
# Epoch 138/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0587 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.3957 - val_sparse_categorical_accuracy: 0.8530 - learning_rate: 5.0000e-04
# Epoch 139/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0750 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.1603 - val_sparse_categorical_accuracy: 0.9320 - learning_rate: 5.0000e-04
# Epoch 140/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9791 - val_loss: 0.1289 - val_sparse_categorical_accuracy: 0.9542 - learning_rate: 5.0000e-04
# Epoch 141/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0680 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.1119 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 5.0000e-04
# Epoch 142/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0829 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.1827 - val_sparse_categorical_accuracy: 0.9348 - learning_rate: 5.0000e-04
# Epoch 143/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1525 - val_sparse_categorical_accuracy: 0.9445 - learning_rate: 5.0000e-04
# Epoch 144/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0703 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 5.0000e-04
# Epoch 145/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0722 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.1193 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 5.0000e-04
# Epoch 146/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0793 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.1127 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 5.0000e-04
# Epoch 147/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0816 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.4112 - val_sparse_categorical_accuracy: 0.8294 - learning_rate: 5.0000e-04
# Epoch 148/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 5.0000e-04
# Epoch 149/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0828 - sparse_categorical_accuracy: 0.9699 - val_loss: 0.1755 - val_sparse_categorical_accuracy: 0.9209 - learning_rate: 5.0000e-04
# Epoch 150/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.1153 - val_sparse_categorical_accuracy: 0.9612 - learning_rate: 2.5000e-04
# Epoch 151/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0656 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.0983 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 2.5000e-04
# Epoch 152/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0688 - sparse_categorical_accuracy: 0.9772 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 153/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9756 - val_loss: 0.1357 - val_sparse_categorical_accuracy: 0.9515 - learning_rate: 2.5000e-04
# Epoch 154/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0578 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.1134 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 2.5000e-04
# Epoch 155/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 156/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.1336 - val_sparse_categorical_accuracy: 0.9528 - learning_rate: 2.5000e-04
# Epoch 157/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 158/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0777 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.0930 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 2.5000e-04
# Epoch 159/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0676 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 160/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0589 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.1665 - val_sparse_categorical_accuracy: 0.9196 - learning_rate: 2.5000e-04
# Epoch 161/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0525 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.1134 - val_sparse_categorical_accuracy: 0.9612 - learning_rate: 2.5000e-04
# Epoch 162/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0615 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0980 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 163/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0589 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.0893 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 2.5000e-04
# Epoch 164/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0665 - sparse_categorical_accuracy: 0.9769 - val_loss: 0.1357 - val_sparse_categorical_accuracy: 0.9528 - learning_rate: 2.5000e-04
# Epoch 165/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 166/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0677 - sparse_categorical_accuracy: 0.9751 - val_loss: 0.0984 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 167/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9801 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 2.5000e-04
# Epoch 168/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1003 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 169/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.1056 - val_sparse_categorical_accuracy: 0.9612 - learning_rate: 2.5000e-04
# Epoch 170/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0684 - sparse_categorical_accuracy: 0.9783 - val_loss: 0.0997 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 171/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 2.5000e-04
# Epoch 172/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.1003 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 173/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.1270 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 2.5000e-04
# Epoch 174/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0604 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 175/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0885 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 176/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0620 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 177/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9744 - val_loss: 0.0986 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 178/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0571 - sparse_categorical_accuracy: 0.9817 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 2.5000e-04
# Epoch 179/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 2.5000e-04
# Epoch 180/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0683 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0975 - val_sparse_categorical_accuracy: 0.9612 - learning_rate: 2.5000e-04
# Epoch 181/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0574 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.1462 - val_sparse_categorical_accuracy: 0.9431 - learning_rate: 2.5000e-04
# Epoch 182/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0917 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 183/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0558 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.1176 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 2.5000e-04
# Epoch 184/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0980 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 185/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0970 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 2.5000e-04
# Epoch 186/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0630 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.0896 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 2.5000e-04
# Epoch 187/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0590 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.1314 - val_sparse_categorical_accuracy: 0.9501 - learning_rate: 2.5000e-04
# Epoch 188/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 189/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0505 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.1027 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 2.5000e-04
# Epoch 190/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.1066 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 2.5000e-04
# Epoch 191/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0661 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.0887 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 192/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.0911 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 193/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.1042 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 194/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 2.5000e-04
# Epoch 195/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9849 - val_loss: 0.1013 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 2.5000e-04
# Epoch 196/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 2.5000e-04
# Epoch 197/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.1318 - val_sparse_categorical_accuracy: 0.9487 - learning_rate: 2.5000e-04
# Epoch 198/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0892 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 2.5000e-04
# Epoch 199/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0590 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0924 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 2.5000e-04
# Epoch 200/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0601 - sparse_categorical_accuracy: 0.9777 - val_loss: 0.0979 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 2.5000e-04
# Epoch 201/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0621 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1230 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 2.5000e-04
# Epoch 202/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.1096 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 2.5000e-04
# Epoch 203/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.1687 - val_sparse_categorical_accuracy: 0.9431 - learning_rate: 2.5000e-04
# Epoch 204/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0582 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0881 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 205/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0590 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0861 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 206/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.0878 - val_sparse_categorical_accuracy: 0.9778 - learning_rate: 2.5000e-04
# Epoch 207/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0681 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1073 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 2.5000e-04
# Epoch 208/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0595 - sparse_categorical_accuracy: 0.9789 - val_loss: 0.1495 - val_sparse_categorical_accuracy: 0.9473 - learning_rate: 2.5000e-04
# Epoch 209/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.0918 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 210/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9820 - val_loss: 0.0976 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 211/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 212/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9835 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 2.5000e-04
# Epoch 213/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0544 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1220 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 2.5000e-04
# Epoch 214/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9845 - val_loss: 0.0962 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 2.5000e-04
# Epoch 215/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0595 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.2364 - val_sparse_categorical_accuracy: 0.8988 - learning_rate: 2.5000e-04
# Epoch 216/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0659 - sparse_categorical_accuracy: 0.9723 - val_loss: 0.1238 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 2.5000e-04
# Epoch 217/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9810 - val_loss: 0.2145 - val_sparse_categorical_accuracy: 0.9057 - learning_rate: 2.5000e-04
# Epoch 218/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0622 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 2.5000e-04
# Epoch 219/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0593 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0907 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 2.5000e-04
# Epoch 220/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0926 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 2.5000e-04
# Epoch 221/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9832 - val_loss: 0.0931 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 2.5000e-04
# Epoch 222/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0526 - sparse_categorical_accuracy: 0.9848 - val_loss: 0.0998 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 2.5000e-04
# Epoch 223/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 2.5000e-04
# Epoch 224/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.1009 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 2.5000e-04
# Epoch 225/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0437 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0952 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 2.5000e-04
# Epoch 226/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0880 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 227/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.0866 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 228/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9871 - val_loss: 0.0872 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.2500e-04
# Epoch 229/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0387 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0919 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.2500e-04
# Epoch 230/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0702 - sparse_categorical_accuracy: 0.9745 - val_loss: 0.0878 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.2500e-04
# Epoch 231/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.1005 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 232/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0517 - sparse_categorical_accuracy: 0.9842 - val_loss: 0.1015 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 1.2500e-04
# Epoch 233/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9822 - val_loss: 0.1283 - val_sparse_categorical_accuracy: 0.9515 - learning_rate: 1.2500e-04
# Epoch 234/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9839 - val_loss: 0.0895 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.2500e-04
# Epoch 235/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0514 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.2500e-04
# Epoch 236/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0993 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.2500e-04
# Epoch 237/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0936 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 238/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.1078 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 1.2500e-04
# Epoch 239/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9825 - val_loss: 0.0893 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.2500e-04
# Epoch 240/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 241/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.0958 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 242/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0895 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.2500e-04
# Epoch 243/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9784 - val_loss: 0.0905 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.2500e-04
# Epoch 244/500
# ...
# Epoch 298/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0448 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0950 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 299/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.0866 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 300/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0428 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.0965 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 301/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0548 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.0858 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 302/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0888 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 303/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0478 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.0980 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 304/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0438 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0909 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 305/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0895 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 306/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.1142 - val_sparse_categorical_accuracy: 0.9598 - learning_rate: 1.0000e-04
# Epoch 307/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0415 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0947 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 308/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.0893 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 309/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.0865 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 310/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0439 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 311/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9886 - val_loss: 0.0949 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 312/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9883 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 1.0000e-04
# Epoch 313/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0855 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 314/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 315/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 316/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0524 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 317/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.0871 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 318/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9870 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 319/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 320/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 1.0000e-04
# Epoch 321/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 322/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 323/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0520 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.1046 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 1.0000e-04
# Epoch 324/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0420 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0867 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 325/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0880 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 326/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.0871 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 327/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 328/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.0838 - val_sparse_categorical_accuracy: 0.9736 - learning_rate: 1.0000e-04
# Epoch 329/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0516 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 1.0000e-04
# Epoch 330/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.0858 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 331/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0475 - sparse_categorical_accuracy: 0.9856 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 332/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.0915 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 333/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0430 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.1022 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 334/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0969 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 335/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.0988 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 1.0000e-04
# Epoch 336/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.1126 - val_sparse_categorical_accuracy: 0.9556 - learning_rate: 1.0000e-04
# Epoch 337/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0436 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0858 - val_sparse_categorical_accuracy: 0.9750 - learning_rate: 1.0000e-04
# Epoch 338/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0908 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 1.0000e-04
# Epoch 339/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0937 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 340/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.0907 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 341/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0365 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0897 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 342/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0488 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.0957 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 343/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0413 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0892 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 344/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9906 - val_loss: 0.0894 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 345/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0881 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 346/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0441 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.0934 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 347/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 348/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.1074 - val_sparse_categorical_accuracy: 0.9570 - learning_rate: 1.0000e-04
# Epoch 349/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0934 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 350/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0355 - sparse_categorical_accuracy: 0.9913 - val_loss: 0.0862 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 351/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0419 - sparse_categorical_accuracy: 0.9890 - val_loss: 0.0888 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 352/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.0887 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 353/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0874 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 354/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 355/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9884 - val_loss: 0.1090 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 1.0000e-04
# Epoch 356/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0408 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0871 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 357/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0442 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.0885 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 358/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0385 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 359/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0899 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 360/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.1300 - val_sparse_categorical_accuracy: 0.9487 - learning_rate: 1.0000e-04
# Epoch 361/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0902 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 362/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9928 - val_loss: 0.1288 - val_sparse_categorical_accuracy: 0.9487 - learning_rate: 1.0000e-04
# Epoch 363/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9805 - val_loss: 0.1011 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 364/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0445 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.0895 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 365/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.1024 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 366/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0454 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 367/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0434 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 368/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0403 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.0876 - val_sparse_categorical_accuracy: 0.9723 - learning_rate: 1.0000e-04
# Epoch 369/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0400 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.0863 - val_sparse_categorical_accuracy: 0.9695 - learning_rate: 1.0000e-04
# Epoch 370/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0391 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.0906 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 371/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0422 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0935 - val_sparse_categorical_accuracy: 0.9653 - learning_rate: 1.0000e-04
# Epoch 372/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0412 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.1221 - val_sparse_categorical_accuracy: 0.9584 - learning_rate: 1.0000e-04
# Epoch 373/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.0882 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 374/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0389 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.0914 - val_sparse_categorical_accuracy: 0.9709 - learning_rate: 1.0000e-04
# Epoch 375/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0401 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.0961 - val_sparse_categorical_accuracy: 0.9681 - learning_rate: 1.0000e-04
# Epoch 376/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.0889 - val_sparse_categorical_accuracy: 0.9667 - learning_rate: 1.0000e-04
# Epoch 377/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9897 - val_loss: 0.1027 - val_sparse_categorical_accuracy: 0.9639 - learning_rate: 1.0000e-04
# Epoch 378/500
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.0928 - val_sparse_categorical_accuracy: 0.9626 - learning_rate: 1.0000e-04
# Epoch 378: early stopping

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0957 - sparse_categorical_accuracy: 0.9665
# Test accuracy 0.9643939137458801
# Test loss 0.09262173622846603

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()
